# %%
import requests
import pandas as pd
import re #Para procesar texto

# %%
#Nos instalamos la libreria spotipy. 
#Solo se debe ejecutar una vez. Por eso lo dejo comentado.
#pip install spotipy
# Out:
# ...
#      |████████████████████████████████| 261 kB 3.0 MB/s eta 0:00:01
# ...
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.1
#     Uninstalling async-timeout-4.0.1:
#       Successfully uninstalled async-timeout-4.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Nos importamos la libreria spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Como accedemos a través de la libreria spotipy, necesitamos estos credenciales. 
client_id = '9f13200092714d0a868666486c7fe6dc'
api_key = '60c7756990384928a3521695221eccc2'

auth_manager = SpotifyClientCredentials( client_id, api_key)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos = sp.search(q="genre:rock year:2020", type="track", limit=50, offset=0)
len(datos["tracks"])
# Out:
# 7

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
# Out:
# <Response [200]>

# %%
respuesta.content
# Out:
# b'<!DOCTYPE html>\n<html class="writer-html5" lang="en" data-content_root="./">\n<head>\n  <meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1" />\n\n  <meta name="viewport" content="width=device-width, initial-scale=1.0" />\n  <title>Welcome to Spotipy! &mdash; spotipy 2.0 documentation</title>\n      <link rel="stylesheet" type="text/css" href="_static/pygments.css?v=fa44fd50" />\n      <link rel="stylesheet" type="text/css" href="_static/css/theme.css?v=19f00094" />\n\n  \n  <!--[if lt IE 9]>\n    <script src="_static/js/html5shiv.min.js"></script>\n  <![endif]-->\n  \n        <script src="_static/jquery.js?v=5d32c60e"></script>\n        <script src="_static/_sphinx_javascript_frameworks_compat.js?v=2cd50e6c"></script>\n        <script src="_static/documentation_options.js?v=60dbed4a"></script>\n        <script src="_static/doctools.js?v=9a2dae69"></script>\n        <script src="_static/sphinx_highlight.js?v=dc90522c"></script>\n        \n   
# ...

# %%
respuesta.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/requests/models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/anaconda3/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
