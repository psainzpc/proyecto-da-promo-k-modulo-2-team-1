# %%
import requests
import pandas as pd
import re #Para procesar texto

# %%
#Nos instalamos la libreria spotipy. 
#Solo se debe ejecutar una vez. Por eso lo dejo comentado.
#pip install spotipy
# Out:
# ...
#      |████████████████████████████████| 261 kB 3.0 MB/s eta 0:00:01
# ...
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.1
#     Uninstalling async-timeout-4.0.1:
#       Successfully uninstalled async-timeout-4.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Nos importamos la libreria spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Como accedemos a través de la libreria spotipy, necesitamos estos credenciales. 
client_id = '9f13200092714d0a868666486c7fe6dc'
api_key = '60c7756990384928a3521695221eccc2'



auth_manager = SpotifyClientCredentials( client_id, api_key)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
#para sacar el genero y crear lo de los datos
datos = sp.search(q="genre:corridos year:2018", type="track", limit=50, offset=0)
len(datos["tracks"])
# Out:
# 7

# %%
type(datos)
# Out:
# dict

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
print(datos)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=genre%3Aindie+year%3A2018&type=track&offset=0&limit=50', 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uwAm6vQy7kWPS2bciKWx9'}, 'href': 'https://api.spotify.com/v1/artists/3uwAm6vQy7kWPS2bciKWx9', 'id': '3uwAm6vQy7kWPS2bciKWx9', 'name': 'girl in red', 'type': 'artist', 'uri': 'spotify:artist:3uwAm6vQy7kWPS2bciKWx9'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME'
# ...

# %%
datos["tracks"]
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=genre%3Aindie+year%3A2018&type=track&offset=0&limit=50',
#  'items': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uwAm6vQy7kWPS2bciKWx9'},
#       'href': 'https://api.spotify.com/v1/artists/3uwAm6vQy7kWPS2bciKWx9',
#       'id': '3uwAm6vQy7kWPS2bciKWx9',
#       'name': 'girl in red',
#       'type': 'artist',
#       'uri': 'spotify:artist:3uwAm6vQy7kWPS2bciKWx9'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
# ...

# %%
#Para conseguir el nombre de la canción
datos["tracks"]["items"][0]["album"]["artists"][0]["name"]
# Out:
# 'girl in red'

# %%
# Para sacar el nombr de una canción
datos["tracks"]["items"][2]["name"]
# Out:
# 'Radicamos En South Central'

# %%
#Para sacar 50 canciones de un genero.
lista_tracks= []
for i in range(0,50):
    lista_tracks.append(datos["tracks"]["items"][i]["name"])

print(lista_tracks)    
len(lista_tracks)
# Out:
# ['Sigo Chambeando', 'Todos Hablan, Nada Saben', 'Radicamos En South Central', 'Ladeando (feat. Fuerza Regida)', 'Aerolínea Carrillo', 'La Escuela No Me Gustó', 'A Lo Lejos Me Veran', 'El Monstro 7', 'Mi Religión', 'Todavia No Se Me Olvida', 'Cosas De La Clica (feat. Legado 7)', 'El Triunfo y la Envidia', 'Platicame De Ti', 'Para Ti Papá', '18 Libras', 'En Menos de Un Minuto', 'Los Pasajes del Phoenix', 'F1', 'Con Finta De Cholo', 'Tiempos Mejores', 'El De Los Lentes Gucci', 'Yo Fui el Elegante', '18 Libras (feat. Hijos de Garcia)', 'Soy Alegre', 'Yo Quiero Fumar', 'Dos Plumas', 'Tinta y Plomo', 'Corrido de Barrera', 'Vida Peligrosa (feat. Arsenal Efectivo & Omar Ruiz)', 'Serenata en Mayo', 'Cuando los Necesité - Banda', 'En La Bola (feat. El De La Guitarra)', 'Lo Que Me Distingue', 'El Son De La Rabia - En Vivo', 'El Verde Es Vida', 'El Que Era Humillado', 'Empecé de Cero', 'Ni Mis Padres Saben Que Rollo', 'Radicamos En South Central', 'Se Ocupan Huevos', 'Mi Unico Camino', 'Loqueand
# ...

# %%
datos = sp.search(q="genre:corridos year:2018", type="track", limit=50, offset=0)

# %%
#Para sacar 50 canciones de un genero.
lista_tracks= []
for i in range(0,50,5):
    lista_tracks.append(datos["tracks"]["items"][i]["name"])

print(lista_tracks)    
len(lista_tracks)
# Out:
# ['Sigo Chambeando', 'La Escuela No Me Gustó', 'Cosas De La Clica (feat. Legado 7)', 'En Menos de Un Minuto', 'El De Los Lentes Gucci', 'Dos Plumas', 'Cuando los Necesité - Banda', 'El Que Era Humillado', 'Mi Unico Camino', 'Cambio de Papeles']
# 10

# %%
#Lista tr
lista_t_corridos_19= []
for offset in range(0,500,50):
    datos = sp.search(q="genre:corridos year:2019", type="track", limit=50, offset=offset)
    for i in range(0,50):
        lista_t_corridos_19.append(datos["tracks"]["items"][i]["name"])

print(lista_t_corridos_19)
len(lista_t_corridos_19)
# Out:
# ['Amor Tumbado', 'Ella', 'Un Suspiró', 'El de La Codeina', 'El Drip', 'Piel de Seda', 'Disfruto Lo Malo', 'Tirando la H', 'Seguimos Laborando', 'El Dinero Los Cambio', 'Hay Niveles', 'Compa Bladi', 'Te Apuesto - En vivo', 'El Muchacho Alegre', 'No Eh Cambiado', 'Es Dificil Ser Un Santo', 'Me Gusta Mi Vida', 'El Güero - En vivo', 'Soy El Diablo - Remix', 'Cosas De La Clika', 'El Muchacho Alegre', 'El Drip', 'Moreno 80', 'Disculpe Usted', 'Es Difícil Ser Un Santo', 'Maryjane y Blancanieves', 'En Boca de Todos', 'El AK', 'El Encargo', 'Videos y Fotos', 'Diablitos', 'Mi Nuevo Yo', 'La Yaquesita', 'La Torre NY', 'Fue un Error Amarte', 'Mi Gusto, Mi Dinero', 'El Can A Bis', 'Iniciales AL (Porte Fino)', 'Ya Te Supere - En Vivo', 'Hombre de 14 Años', 'Soy El Diablo', 'Mi Vida en un Cigarro', 'Soy de Michoacan', 'La Güera', 'Aquilesorganigrama', 'Que Me Falto - En vivo', 'El De Las Dos Pistolas', 'Corridos Tumbados', 'El de la Chevy', 'El de la H', 'Aunque Les Pese', 'Miami Vibe', 'Ladeando',
# ...

# %%
#para sacarlo del offset
lista_t_corridos_20= []
for offset in range(0,500,50):
    datos = sp.search(q="genre:corridos year:2020", type="track", limit=50, offset=offset)
    for i in range(0,50):
        lista_t_corridos_20.append(datos["tracks"]["items"][i]["name"])

print(lista_t_corridos_20)
len(lista_t_corridos_20)
# Out:
# ['Jugaste y Sufrí', 'Con Tus Besos', 'Intro', 'Se Amerita', 'Psicodelica', 'Dias Nublados', 'Mente Positiva', 'Labios Rojos', 'Clave Ali', 'Adueñarme', 'Me Matas', 'Atrapado en un Sueño', '1004 Kilómetros', 'Pacas Verdes', 'Baby', 'Ojitos de Miel', 'No Eres La Oficial', 'Ya No Me Preocupo', 'No Me Pesa', 'Seca Tus Lagrimas', 'La Vi Llorar', 'Dame Un Segundo', 'Jueves 10', 'Tu', 'Se Quedan Viendo', 'Tal Vez', 'La Mejor de Todas', 'Bajo Efecto Del Alcohol', 'Me Prendes', 'Diciembre', 'Suena', 'Catorce de Febrero', 'Mil Gracias Por Existir', 'Mi Historia Entre Tus Dedos', 'Que Te Vas', 'Por Si Acaso', 'La Barda', 'Desde Morro', 'Paso En Culiacan', 'Me Estoy Enamorando - en Vivo', 'Dame Tu Calor', 'Pienso en Ella', 'Siempre Clave', 'Te Extraño', 'No Cap', 'En Las Duronas', 'Mi Vicio', 'Lo Que Es', 'Ojos De Maniaco', 'Ojos Colorados', 'Se Murió', 'Arriba', 'Tengo Motivos', 'Alegre y Enamorado', '¿Donde Has Estado?', 'Ven Conmigo', 'Te Quiero a Ti', 'Piloto Filoso', 'Tentacion', 'El Black'
# ...

# %%
datos["tracks"] # Accedemos a los tracks. 
type(datos["tracks"]) # Vemos que tipo es 
#["items"][0]["artists"][0]["name"]
datos["tracks"].keys() #Vemos los keys que tenemos en el dicionario. Queremos entrar en ITEMS
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
type(datos["tracks"]["items"]) #Vemos que es. Una lista.
datos["tracks"]["items"]
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kjglpYGnl8dCHWVT0sHVS'},
#      'href': 'https://api.spotify.com/v1/artists/0kjglpYGnl8dCHWVT0sHVS',
#      'id': '0kjglpYGnl8dCHWVT0sHVS',
#      'name': 'Los Ahijados del Barranco',
#      'type': 'artist',
#      'uri': 'spotify:artist:0kjglpYGnl8dCHWVT0sHVS'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
# ...

# %% [markdown]
# Nombre canción:
#     - Artista
#     - Genero Musical
#     - Tipo (canción o album)
#     - Año de lanzamiento: date release

# %%
#nombre de una canción
datos["tracks"]["items"][1]["name"]
# Out:
# 'El Gordito - En vivo'

# %%
len(lista_tracks)
# Out:
# 500
