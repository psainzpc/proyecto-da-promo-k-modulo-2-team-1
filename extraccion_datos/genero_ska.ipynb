# %%
#%pip install spotipy

# %%
import requests
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = '9f13200092714d0a868666486c7fe6dc'
api_key = '60c7756990384928a3521695221eccc2'

auth_manager = SpotifyClientCredentials( client_id, api_key)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
canciones = sp.search(q="genre:ska year:2019", type="track", limit=50, offset=0)

# %%
canciones.keys()
# Out:
# dict_keys(['tracks'])

# %%
canciones["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
canciones["tracks"]["items"][0]["album"]["release_date"]
# Out:
# '2019-01-11'

# %%
canciones["tracks"]["items"][0]["artists"][0]["name"]
# Out:
# '88 Fingers Louie'

# %% [markdown]
# CANCIONES SKA 2019

# %%
dict_tracks_ska_2019={"canciones":[],"artistas": [], "género": "ska", "tipo": "track", "año lanzamiento": []}
for offset in range (0,500,50):
    canciones_ska_2019 = sp.search(q='genre:"ska" year:2019', type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_ska_2019["canciones"].append(canciones_ska_2019["tracks"]["items"][i]["name"])
        
print(dict_tracks_ska_2019)
len(dict_tracks_ska_2019)
# Out:
# {'canciones': ['100 Proof', 'Bad Guy', 'All My Friends Are Nobodies', 'Anna', 'Tomorrow Starts Today', "America (You're Freaking Me Out)", 'Say What - Pisk Electro Swing Remix', 'I’ve Won', 'Selfish Means', 'Strangers Forever', 'El Último Ska', 'My Sanity', 'Summer Photos', 'Strain Your Memory', 'Punk Rock Rulebook', 'I Hate Myself', 'The Perfect Crime', 'Outright Lies', 'High School Friend', 'Blink', 'Last To Know', 'Holding Back', 'Huellas - Live / Remastered', 'Chaos From Within', 'Worst Man Won', 'We’re Not Alright', 'Do The Paranoid Style', 'If I Could Only Listen to My Heart', 'State', 'Candidate', 'I Wanna Be a Dog', 'All My Friends Are Nobodies', 'Last Ride', "Tonight We're Gonna Give It 35%", 'The Approach', 'Hello Exile', 'Too Much Information', "Elmer's", "Can't Stop", 'Hauch mich mal an', 'When Both Sides Suck, We’re All Winners', 'Super Show (Theme Song!)', 'Portland', "You're Gonna Go Far, Kid", 'Beyond The Veil', "I Can't Stop Drinking", 'The Disco Before the Breakdown', 'Botellas', 'Drunk & Ugly', 'Kosmopolit', 'If Your Looking for Your Knife...I Think My Back Found It', 'You Don’t Know Anything About Me', 'Strawberry Mansion', 'All My Friends Are Nobodies', 'Farewell Youth', 'London Drugs', 'Mágico', 'Chasing the Sun', 'Lose Your Head', "When Both Sides Suck, We're All Winners", 'Valentina', 'Age of Unreason', 'End of History', 'SOS', 'Franco Un-American', 'The Lunatics', 'Las Seis', 'San Dimas High School Football Rules', "Get Movin' (Feet Don't Fail Me Now)", 'Another Love Song', 'Scratch Me Up', "Don't Have Time", 'The Past Will Always Be', 'Gave You Everything - Acoustic', 'Old Regime', '1113', 'Guava Jelly (Dub)', 'No Penance', 'Oscar Wilde', 'Sink, Florida, Sink', 'Paint the Night Red', 'Eyes Of The Night', 'Doing Science!', "If You're Looking for Your Knife...I Think My Back Found It", 'Here is the News (Papa´s Got a Brand New Pigbag)', 'Dippy Egg', 'What Tomorrow Brings', 'Losing Touch', 'Voy a Volver', 'La Joya Del Pacífico - Live / Remastered', 'Devil That You Don’t Know', 'Big Black Dog', 'Three Small Words', 'Nothing', 'Tuff Rudeboy', 'Infiernos', 'Se Va de Mí', 'Pound For Pound', 'Downfall', 'Amarte', 'Favorite Everything', 'Faces of Grief', 'Two-Faced Bastard', 'La Flor', 'I Know', 'Hero with a Death Ray', 'Since Now', "The Kids Aren't Alright", "When You Say It's Okay", "The Kids Aren't Alright", 'Stealing Light', "Tryin' & Stutterin'", 'Pretty Fly (For A White Guy)', 'Baby Baby', 'Aim High', 'Seven Seas', 'Bubble', "Here's To Us", 'Night of the Knuckleheads', 'No One Said It Was Easy', 'heart blue', 'Prefiero', 'Give Me a Little Sign Girl', 'Everything to Me', 'Something I Don’t Know', 'Theme of FSD', 'Horizontal Aggression', 'Revolution', 'You Used to Have a Garden', 'Eat the One Percent', 'Muia', 'Wild Hair (across My Ass)', 'Daggers', 'Vuela', 'Techno Guilt', 'Ulysses', 'Death Kart', 'Pädagogen', 'Sail Away', 'Too Much Information', 'The Boys of Summer - Re-Recorded', 'Our Great Divide', 'Mi Amor La Luna', 'Curse of the Unripe Pumpkin', 'High-Strung', 'Burger Rain!', 'Restless', 'Tu Meta', 'Precariat', 'Ready Now', 'Take Me Home, Country Road - Recorded at Spotify Studios NYC', "Druschba (You're Not Alone)", 'La Abundancia', 'Giving a Shit', 'La Naturaleza', 'Everyday Tomorrow', 'Tu Meta', 'Parable', 'Somebody That I Used to Know', 'B.L.M', 'Marchez', 'The Impression That I Get', "You Don't Get the Joke", 'Admission', 'Creature from the Black Metal Lagoon', 'Home Away from Home', 'Surviving California', 'Jini', 'Lilith', 'Ciggy', 'Ford Fiesta', 'Surviving California', 'Voy a Volver', 'Everyone I Look Up to Is Sad or Angry', 'Contrabando de Amor', 'Dangerous Animal', 'La Sirene', 'Kila', 'Vote For Me', 'The Suffering', 'Black Neon', 'Convaleciente', 'Newspaper', 'Sundown', '10 Commandments', 'Top of the World', 'Love Revolution', 'Everything to Me', 'Linda María', 'La Funa', 'Under the Western Sky', 'Shake Up The Shadows', 'For Yesterday', 'Yeah, Yeah, Yeah', 'Strippers on a Sunday', 'San Dim ...
# 5

# %% [markdown]
# ARTISTAS SKA 2019

# %%
for offset in range(0, 500, 50):
    canciones_ska_2019 = sp.search(q='genre:"ska" year:2019', type="track", limit=50, offset=offset)
    for track in canciones_ska_2019['tracks']['items']:
        dict_tracks_ska_2019["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_ska_2019)
len(dict_tracks_ska_2019)
# Out:
# {'canciones': ['100 Proof', 'Bad Guy', 'All My Friends Are Nobodies', 'Anna', 'Tomorrow Starts Today', "America (You're Freaking Me Out)", 'Say What - Pisk Electro Swing Remix', 'I’ve Won', 'Selfish Means', 'Strangers Forever', 'El Último Ska', 'My Sanity', 'Summer Photos', 'Strain Your Memory', 'Punk Rock Rulebook', 'I Hate Myself', 'The Perfect Crime', 'Outright Lies', 'High School Friend', 'Blink', 'Last To Know', 'Holding Back', 'Huellas - Live / Remastered', 'Chaos From Within', 'Worst Man Won', 'We’re Not Alright', 'Do The Paranoid Style', 'If I Could Only Listen to My Heart', 'State', 'Candidate', 'I Wanna Be a Dog', 'All My Friends Are Nobodies', 'Last Ride', "Tonight We're Gonna Give It 35%", 'The Approach', 'Hello Exile', 'Too Much Information', "Elmer's", "Can't Stop", 'Hauch mich mal an', 'When Both Sides Suck, We’re All Winners', 'Super Show (Theme Song!)', 'Portland', "You're Gonna Go Far, Kid", 'Beyond The Veil', "I Can't Stop Drinking", 'The Disco Before the Breakdown', 'Botellas', 'Drunk & Ugly', 'Kosmopolit', 'If Your Looking for Your Knife...I Think My Back Found It', 'You Don’t Know Anything About Me', 'Strawberry Mansion', 'All My Friends Are Nobodies', 'Farewell Youth', 'London Drugs', 'Mágico', 'Chasing the Sun', 'Lose Your Head', "When Both Sides Suck, We're All Winners", 'Valentina', 'Age of Unreason', 'End of History', 'SOS', 'Franco Un-American', 'The Lunatics', 'Las Seis', 'San Dimas High School Football Rules', "Get Movin' (Feet Don't Fail Me Now)", 'Another Love Song', 'Scratch Me Up', "Don't Have Time", 'The Past Will Always Be', 'Gave You Everything - Acoustic', 'Old Regime', '1113', 'Guava Jelly (Dub)', 'No Penance', 'Oscar Wilde', 'Sink, Florida, Sink', 'Paint the Night Red', 'Eyes Of The Night', 'Doing Science!', "If You're Looking for Your Knife...I Think My Back Found It", 'Here is the News (Papa´s Got a Brand New Pigbag)', 'Dippy Egg', 'What Tomorrow Brings', 'Losing Touch', 'Voy a Volver', 'La Joya Del Pacífico - Live / Remastered', 'Devil That You Don’t Know', 'Big Black Dog', 'Three Small Words', 'Nothing', 'Tuff Rudeboy', 'Infiernos', 'Se Va de Mí', 'Pound For Pound', 'Downfall', 'Amarte', 'Favorite Everything', 'Faces of Grief', 'Two-Faced Bastard', 'La Flor', 'I Know', 'Hero with a Death Ray', 'Since Now', "The Kids Aren't Alright", "When You Say It's Okay", "The Kids Aren't Alright", 'Stealing Light', "Tryin' & Stutterin'", 'Pretty Fly (For A White Guy)', 'Baby Baby', 'Aim High', 'Seven Seas', 'Bubble', "Here's To Us", 'Night of the Knuckleheads', 'No One Said It Was Easy', 'heart blue', 'Prefiero', 'Give Me a Little Sign Girl', 'Everything to Me', 'Something I Don’t Know', 'Theme of FSD', 'Horizontal Aggression', 'Revolution', 'You Used to Have a Garden', 'Eat the One Percent', 'Muia', 'Wild Hair (across My Ass)', 'Daggers', 'Vuela', 'Techno Guilt', 'Ulysses', 'Death Kart', 'Pädagogen', 'Sail Away', 'Too Much Information', 'The Boys of Summer - Re-Recorded', 'Our Great Divide', 'Mi Amor La Luna', 'Curse of the Unripe Pumpkin', 'High-Strung', 'Burger Rain!', 'Restless', 'Tu Meta', 'Precariat', 'Ready Now', 'Take Me Home, Country Road - Recorded at Spotify Studios NYC', "Druschba (You're Not Alone)", 'La Abundancia', 'Giving a Shit', 'La Naturaleza', 'Everyday Tomorrow', 'Tu Meta', 'Parable', 'Somebody That I Used to Know', 'B.L.M', 'Marchez', 'The Impression That I Get', "You Don't Get the Joke", 'Admission', 'Creature from the Black Metal Lagoon', 'Home Away from Home', 'Surviving California', 'Jini', 'Lilith', 'Ciggy', 'Ford Fiesta', 'Surviving California', 'Voy a Volver', 'Everyone I Look Up to Is Sad or Angry', 'Contrabando de Amor', 'Dangerous Animal', 'La Sirene', 'Kila', 'Vote For Me', 'The Suffering', 'Black Neon', 'Convaleciente', 'Newspaper', 'Sundown', '10 Commandments', 'Top of the World', 'Love Revolution', 'Everything to Me', 'Linda María', 'La Funa', 'Under the Western Sky', 'Shake Up The Shadows', 'For Yesterday', 'Yeah, Yeah, Yeah', 'Strippers on a Sunday', 'San Dim ...
# 5

# %% [markdown]
# AÑO DE LANZAMIENTO 2019

# %%
for offset in range(0, 500, 50):
    canciones_ska_2019 = sp.search(q='genre:"ska" year:2019', type='track', limit=50, offset=offset)
    for track in canciones_ska_2019['tracks']['items']:
        dict_tracks_ska_2019["año lanzamiento"].append(track["album"]['release_date'].split("-")[0])
print(dict_tracks_ska_2019)
len(dict_tracks_ska_2019)
# Out:
# {'canciones': ['100 Proof', 'Bad Guy', 'All My Friends Are Nobodies', 'Anna', 'Tomorrow Starts Today', "America (You're Freaking Me Out)", 'Say What - Pisk Electro Swing Remix', 'I’ve Won', 'Selfish Means', 'Strangers Forever', 'El Último Ska', 'My Sanity', 'Summer Photos', 'Strain Your Memory', 'Punk Rock Rulebook', 'I Hate Myself', 'The Perfect Crime', 'Outright Lies', 'High School Friend', 'Blink', 'Last To Know', 'Holding Back', 'Huellas - Live / Remastered', 'Chaos From Within', 'Worst Man Won', 'We’re Not Alright', 'Do The Paranoid Style', 'If I Could Only Listen to My Heart', 'State', 'Candidate', 'I Wanna Be a Dog', 'All My Friends Are Nobodies', 'Last Ride', "Tonight We're Gonna Give It 35%", 'The Approach', 'Hello Exile', 'Too Much Information', "Elmer's", "Can't Stop", 'Hauch mich mal an', 'When Both Sides Suck, We’re All Winners', 'Super Show (Theme Song!)', 'Portland', "You're Gonna Go Far, Kid", 'Beyond The Veil', "I Can't Stop Drinking", 'The Disco Before the Breakdown', 'Botellas', 'Drunk & Ugly', 'Kosmopolit', 'If Your Looking for Your Knife...I Think My Back Found It', 'You Don’t Know Anything About Me', 'Strawberry Mansion', 'All My Friends Are Nobodies', 'Farewell Youth', 'London Drugs', 'Mágico', 'Chasing the Sun', 'Lose Your Head', "When Both Sides Suck, We're All Winners", 'Valentina', 'Age of Unreason', 'End of History', 'SOS', 'Franco Un-American', 'The Lunatics', 'Las Seis', 'San Dimas High School Football Rules', "Get Movin' (Feet Don't Fail Me Now)", 'Another Love Song', 'Scratch Me Up', "Don't Have Time", 'The Past Will Always Be', 'Gave You Everything - Acoustic', 'Old Regime', '1113', 'Guava Jelly (Dub)', 'No Penance', 'Oscar Wilde', 'Sink, Florida, Sink', 'Paint the Night Red', 'Eyes Of The Night', 'Doing Science!', "If You're Looking for Your Knife...I Think My Back Found It", 'Here is the News (Papa´s Got a Brand New Pigbag)', 'Dippy Egg', 'What Tomorrow Brings', 'Losing Touch', 'Voy a Volver', 'La Joya Del Pacífico - Live / Remastered', 'Devil That You Don’t Know', 'Big Black Dog', 'Three Small Words', 'Nothing', 'Tuff Rudeboy', 'Infiernos', 'Se Va de Mí', 'Pound For Pound', 'Downfall', 'Amarte', 'Favorite Everything', 'Faces of Grief', 'Two-Faced Bastard', 'La Flor', 'I Know', 'Hero with a Death Ray', 'Since Now', "The Kids Aren't Alright", "When You Say It's Okay", "The Kids Aren't Alright", 'Stealing Light', "Tryin' & Stutterin'", 'Pretty Fly (For A White Guy)', 'Baby Baby', 'Aim High', 'Seven Seas', 'Bubble', "Here's To Us", 'Night of the Knuckleheads', 'No One Said It Was Easy', 'heart blue', 'Prefiero', 'Give Me a Little Sign Girl', 'Everything to Me', 'Something I Don’t Know', 'Theme of FSD', 'Horizontal Aggression', 'Revolution', 'You Used to Have a Garden', 'Eat the One Percent', 'Muia', 'Wild Hair (across My Ass)', 'Daggers', 'Vuela', 'Techno Guilt', 'Ulysses', 'Death Kart', 'Pädagogen', 'Sail Away', 'Too Much Information', 'The Boys of Summer - Re-Recorded', 'Our Great Divide', 'Mi Amor La Luna', 'Curse of the Unripe Pumpkin', 'High-Strung', 'Burger Rain!', 'Restless', 'Tu Meta', 'Precariat', 'Ready Now', 'Take Me Home, Country Road - Recorded at Spotify Studios NYC', "Druschba (You're Not Alone)", 'La Abundancia', 'Giving a Shit', 'La Naturaleza', 'Everyday Tomorrow', 'Tu Meta', 'Parable', 'Somebody That I Used to Know', 'B.L.M', 'Marchez', 'The Impression That I Get', "You Don't Get the Joke", 'Admission', 'Creature from the Black Metal Lagoon', 'Home Away from Home', 'Surviving California', 'Jini', 'Lilith', 'Ciggy', 'Ford Fiesta', 'Surviving California', 'Voy a Volver', 'Everyone I Look Up to Is Sad or Angry', 'Contrabando de Amor', 'Dangerous Animal', 'La Sirene', 'Kila', 'Vote For Me', 'The Suffering', 'Black Neon', 'Convaleciente', 'Newspaper', 'Sundown', '10 Commandments', 'Top of the World', 'Love Revolution', 'Everything to Me', 'Linda María', 'La Funa', 'Under the Western Sky', 'Shake Up The Shadows', 'For Yesterday', 'Yeah, Yeah, Yeah', 'Strippers on a Sunday', 'San Dim ...
# 5

# %%
df_2019 = pd.DataFrame(dict_tracks_ska_2019)
df_2019
# Out:
#                                       canciones          artistas género  \
# 0                                     100 Proof  88 Fingers Louie    ska
# 1                                       Bad Guy  The Interrupters    ska
# 2                   All My Friends Are Nobodies         zebrahead    ska
# 3                                          Anna    The Menzingers    ska
# 4                         Tomorrow Starts Today  88 Fingers Louie    ska
# ..                                          ...               ...    ...
# 495             Better Living Through Chemistry         zebrahead    ska
# 496                              Coffee & Sugar     The Magnetics    ska
# 497                           Diamonds and Gold        Strung Out    ska
# 498                                      Sooner     The Paranoias    ska
# 499  All My Friends Are Nobodies (Acoustic-Ish)         zebrahead    ska
#
#       tipo año lanzamiento
# 0    track            2019
# 1    track            2019
# 2    track            2019
# 3    track            2019
# 4    track            2019
# ..     ...             ...
# 495  track            2019
# 496  track            2019
# 497  track            2019
# 498  track            2019
# 499  track            2019
#
# [500 rows x 5 columns]

# %%
df_2019.to_csv("dict_tracks_ska_2019.csv", index=False)

# %%
df_2019.describe(include="object")
# Out:
#                           canciones   artistas género   tipo año lanzamiento
# count                           500        500    500    500             500
# unique                          458        116      1      1               1
# top     All My Friends Are Nobodies  zebrahead    ska  track            2019
# freq                              4         41    500    500             500

# %% [markdown]
# CANCIONES SKA 2020

# %%
dict_tracks_ska_2020={"canciones":[],"artistas": [], "género": "ska", "tipo": "track", "año lanzamiento": []}
for offset in range (0,500,50):
    canciones_ska_2020 = sp.search(q='genre:"ska" year:2020', type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_ska_2020["canciones"].append(canciones_ska_2019["tracks"]["items"][i]["name"])
        
print(dict_tracks_ska_2020)
len(dict_tracks_ska_2020)
# Out:
# {'canciones': ['裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Crossed - Live', 'Paramar (En Vivo) - 2019 Remasterizado', 'Billy V. Veronica', "What's in a Name - Live", 'Ichi, Ni, San, Shi', 'Old Town Road', 'Goron City', 'Soul Rebel (Instrumental)', 'No Case', 'Haffi Flow - Zapada', 'No Authority - Live', 'I Wanna Be a Dog', 'Disappearing City', 'Jamaica Ska', 'Gets on Top', "What's Going Down?", 'Lúcido - Lo Fi Vershan', 'Bridge over Troubled Squatter', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Diamonds and Gold', 'Sooner', 'All My Friends Are Nobodies (Acoustic-Ish)', '裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Crossed - Live', 'Paramar (En Vivo) - 2019 Remasterizado', 'Billy V. Veronica', "What's in a Name - Live", 'Ichi, Ni, San, Shi', 'Old Town Road', 'Goron City', 'Soul Rebel (Instrumental)', 'No Case', 'Haffi Flow - Zapada', 'No Authority - Live', 'I Wanna Be a Dog', 'Disappearing City', 'Jamaica Ska', 'Gets on Top', "What's Going Down?", 'Lúcido - Lo Fi Vershan', 'Bridge over Troubled Squatter', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Diamonds and Gold', 'Sooner', 'All My Friends Are Nobodies (Acoustic-Ish)', '裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Crossed - Live', 'Paramar (En Vivo) - 2019 Remasterizado', 'Billy V. Veronica', "What's in a Name - Live", 'Ichi, Ni, San, Shi', 'Old Town Road', 'Goron City', 'Soul Rebel (Instrumental)', 'No Case', 'Haffi Flow - Zapada', 'No Authority - Live', 'I Wanna Be a Dog', 'Disappearing City', 'Jamaica Ska', 'Gets on Top', "What's Going Down?", 'Lúcido - Lo Fi Vershan', 'Bridge over Troubled Squatter', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Diamonds and Gold', 'Sooner', 'All My Friends Are Nobodies (Acoustic-Ish)', '裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Cross ...
# 5

# %% [markdown]
# ARTISTAS SKA 2020

# %%
for offset in range(0, 500, 50):
    canciones_ska_2020 = sp.search(q='genre:"ska" year:2020', type="track", limit=50, offset=offset)
    for track in canciones_ska_2020['tracks']['items']:
        dict_tracks_ska_2020["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_ska_2020)
len(dict_tracks_ska_2020)
# Out:
# {'canciones': ['裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Crossed - Live', 'Paramar (En Vivo) - 2019 Remasterizado', 'Billy V. Veronica', "What's in a Name - Live", 'Ichi, Ni, San, Shi', 'Old Town Road', 'Goron City', 'Soul Rebel (Instrumental)', 'No Case', 'Haffi Flow - Zapada', 'No Authority - Live', 'I Wanna Be a Dog', 'Disappearing City', 'Jamaica Ska', 'Gets on Top', "What's Going Down?", 'Lúcido - Lo Fi Vershan', 'Bridge over Troubled Squatter', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Diamonds and Gold', 'Sooner', 'All My Friends Are Nobodies (Acoustic-Ish)', '裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Crossed - Live', 'Paramar (En Vivo) - 2019 Remasterizado', 'Billy V. Veronica', "What's in a Name - Live", 'Ichi, Ni, San, Shi', 'Old Town Road', 'Goron City', 'Soul Rebel (Instrumental)', 'No Case', 'Haffi Flow - Zapada', 'No Authority - Live', 'I Wanna Be a Dog', 'Disappearing City', 'Jamaica Ska', 'Gets on Top', "What's Going Down?", 'Lúcido - Lo Fi Vershan', 'Bridge over Troubled Squatter', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Diamonds and Gold', 'Sooner', 'All My Friends Are Nobodies (Acoustic-Ish)', '裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Crossed - Live', 'Paramar (En Vivo) - 2019 Remasterizado', 'Billy V. Veronica', "What's in a Name - Live", 'Ichi, Ni, San, Shi', 'Old Town Road', 'Goron City', 'Soul Rebel (Instrumental)', 'No Case', 'Haffi Flow - Zapada', 'No Authority - Live', 'I Wanna Be a Dog', 'Disappearing City', 'Jamaica Ska', 'Gets on Top', "What's Going Down?", 'Lúcido - Lo Fi Vershan', 'Bridge over Troubled Squatter', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Diamonds and Gold', 'Sooner', 'All My Friends Are Nobodies (Acoustic-Ish)', '裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Cross ...
# 5

# %% [markdown]
# AÑO LANZAMIENTO 2020

# %%
for offset in range(0, 500, 50):
    canciones_ska_2020 = sp.search(q='genre:"ska" year:2020', type='track', limit=50, offset=offset)
    for track in canciones_ska_2020['tracks']['items']:
        dict_tracks_ska_2020["año lanzamiento"].append(track["album"]['release_date'].split("-")[0])
print(dict_tracks_ska_2020)
len(dict_tracks_ska_2020)
# Out:
# {'canciones': ['裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Crossed - Live', 'Paramar (En Vivo) - 2019 Remasterizado', 'Billy V. Veronica', "What's in a Name - Live", 'Ichi, Ni, San, Shi', 'Old Town Road', 'Goron City', 'Soul Rebel (Instrumental)', 'No Case', 'Haffi Flow - Zapada', 'No Authority - Live', 'I Wanna Be a Dog', 'Disappearing City', 'Jamaica Ska', 'Gets on Top', "What's Going Down?", 'Lúcido - Lo Fi Vershan', 'Bridge over Troubled Squatter', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Diamonds and Gold', 'Sooner', 'All My Friends Are Nobodies (Acoustic-Ish)', '裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Crossed - Live', 'Paramar (En Vivo) - 2019 Remasterizado', 'Billy V. Veronica', "What's in a Name - Live", 'Ichi, Ni, San, Shi', 'Old Town Road', 'Goron City', 'Soul Rebel (Instrumental)', 'No Case', 'Haffi Flow - Zapada', 'No Authority - Live', 'I Wanna Be a Dog', 'Disappearing City', 'Jamaica Ska', 'Gets on Top', "What's Going Down?", 'Lúcido - Lo Fi Vershan', 'Bridge over Troubled Squatter', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Diamonds and Gold', 'Sooner', 'All My Friends Are Nobodies (Acoustic-Ish)', '裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Crossed - Live', 'Paramar (En Vivo) - 2019 Remasterizado', 'Billy V. Veronica', "What's in a Name - Live", 'Ichi, Ni, San, Shi', 'Old Town Road', 'Goron City', 'Soul Rebel (Instrumental)', 'No Case', 'Haffi Flow - Zapada', 'No Authority - Live', 'I Wanna Be a Dog', 'Disappearing City', 'Jamaica Ska', 'Gets on Top', "What's Going Down?", 'Lúcido - Lo Fi Vershan', 'Bridge over Troubled Squatter', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Diamonds and Gold', 'Sooner', 'All My Friends Are Nobodies (Acoustic-Ish)', '裸足の果実', 'A Beautiful Mistake - Demo Version', 'Jump in the Line', "Who's That?", 'Haunted', "Let's Start Again", "Can't Hardly Wait - Acoustic Version", 'Fatlip', 'How You Remind Me', 'Trojan Night', 'So Jah Say (Dub)', 'From Here on In', 'No Safe Place', 'Devil in the Details', 'Phosphene', 'Shake a Tail Feather', 'The First Time That I Did Acid Was the Last Time That I Did Acid', 'Party on the Dancefloor', 'Cowboy Android Theme!', 'Healthy Body Sick Mind', 'Espremedors', 'Buried Alive', 'New Kind of Friend', 'Perro Chico', 'Just so You Know', 'Manant! Fight!', 'Don’t Let Me Down', 'Double Cross ...
# 5

# %%
df_2020 = pd.DataFrame(dict_tracks_ska_2020)
df_2020
# Out:
#                                       canciones           artistas género  \
# 0                                         裸足の果実        Alton Ellis    ska
# 1            A Beautiful Mistake - Demo Version         Goldfinger    ska
# 2                              Jump in the Line  Screeching Weasel    ska
# 3                                   Who's That?        The Wailers    ska
# 4                                       Haunted          Anti-Flag    ska
# ..                                          ...                ...    ...
# 495             Better Living Through Chemistry               MxPx    ska
# 496                              Coffee & Sugar              PEARS    ska
# 497                           Diamonds and Gold  Los Estramboticos    ska
# 498                                      Sooner       Korol i Shut    ska
# 499  All My Friends Are Nobodies (Acoustic-Ish)          zebrahead    ska
#
#       tipo año lanzamiento
# 0    track            2020
# 1    track            2020
# 2    track            2020
# 3    track            2020
# 4    track            2020
# ..     ...             ...
# 495  track            2020
# 496  track            2020
# 497  track            2020
# 498  track            2020
# 499  track            2020
#
# [500 rows x 5 columns]

# %%
df_2020.to_csv("dict_tracks_ska_2020.csv", index=False)

# %%
df_2020.describe(include="object")
# Out:
#        canciones           artistas género   tipo año lanzamiento
# count        500                500    500    500             500
# unique        50                115      1      1               1
# top        裸足の果実  Screeching Weasel    ska  track            2020
# freq          10                 34    500    500             500

# %% [markdown]
# MUSICBRAINZ

# %%
#!pip install musicbrainzngs

# %%
import musicbrainzngs

# %%
musicbrainzngs.set_useragent("MusicStream", "1.0", "martahh90@hotmail.com")

# %% [markdown]
# ARTISTAS SKA 2019

# %%
set_artistas_ska_2019 = set(dict_tracks_ska_2019['artistas'])  # Convertir el valor asociado a la clave 'artistas' en un set para limpiar los artistas repetidos
print(set_artistas_ska_2019)
# Out:
# {'Bracket', 'The Decline', 'Strung Out', 'Satanic Surfers', 'Los Chickléts', 'Bite Me Bambi', 'King Punch', 'The Offenders', 'Das Lumpenpack', '88 Fingers Louie', 'Kill Lincoln', 'Masked Intruder', 'Hot Water Music', 'La Fúmiga', 'Los Enanitos Verdes', 'Hooray for Our Side', 'The Bouncing Souls', 'Pulley', '10-FEET', 'The Skints', 'The Specials', 'Snuff', 'The Aquabats!', 'Rude Tins', 'Face To Face', 'Hans Gruber and the Die Hards', 'Joe Vasconcellos', 'The Menzingers', 'The Paranoias', 'Big D and the Kids Table', 'Tiger Army', 'The Planet Smashers', 'Panteon Rococo', 'Kameleba', 'FIVE STATE DRIVE', 'Omnigone', 'Be Like Max', 'Tommy Tornado', 'The Interrupters', 'The Holophonics', 'Stop the Presses', 'Inspector', 'Good Riddance', 'Riskee & The Ridicule', 'Codename Colin', 'Los Cafres', 'Stranger Cole', 'Ten Foot Pole', 'Bad Cop, Bad Cop', 'Los Skagaleros', 'The Magnetics', 'Los Caligaris', 'K-Man & The 45s', 'La Tremenda Korte', 'Tokyo Ska Paradise Orchestra', 'Out Of Control Army', 'King Prawn', 'Down By Law', 'The Vandals', 'No Such Noise', 'Just Say Nay', 'Hub City Stompers', 'Teenage Bottlerocket', 'CLUB SANDINISTA!', 'Jamaican Jazz Orchestra', 'Millencolin', 'The Bombpops', 'EGO-WRAPPIN’', 'Devon Kay & The Solutions', 'Russkaja', 'Tsunami Bomb', 'Antidoping', 'Joey Cape', 'Noise Complaint', 'Val Bennett', 'Lagwagon', 'БИРТМАН', 'The Mighty Mighty Bosstones', 'The Living End', 'Los Prisioneros', 'Boa Brass Band', 'The Beat', 'Buck-O-Nine', 'En Tol Sarmiento', 'Mest', 'Against Me!', 'Bruce Lee Band', '2 minutos', 'The Ataris', 'Much The Same', 'The Cat Empire', 'South Central Skankers', 'zebrahead', 'Quique Neira', 'Toots & The Maytals', 'The Offspring', 'Los De Abajo', 'Cigar', 'Sorry Sweetheart', 'MxPx', 'Catbite', 'Rehasher', 'Bad Religion', 'Byron Lee & The Dragonaires', '31 Minutos', 'The Aggrolites', '[spunge]', 'The Wailers', 'New York Ska-Jazz Ensemble', 'Half Past Two', 'Tunnel Vision', 'Sublime', 'Koers', 'H2O', 'Cut Capers', 'Owen Gray'}

# %%
lista_artistas_ska_2019 = list(set_artistas_ska_2019) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_ska_2019)
# Out:
# 116

# %%
#ejemplo de como muestra los resultados:
result = musicbrainzngs.search_artists(artist='Inspector')
print(result)
# Out:
# {'artist-list': [{'id': 'b8711241-bd87-4f6f-ab22-fcdc3743544b', 'type': 'Group', 'ext:score': '100', 'name': 'Inspector', 'sort-name': 'Inspector', 'country': 'MX', 'area': {'id': '3e08b2cd-69f3-317c-b1e4-e71be581839e', 'type': 'Country', 'name': 'Mexico', 'sort-name': 'Mexico', 'life-span': {'ended': 'false'}}, 'begin-area': {'id': 'cfd1e529-4ca0-4377-bb35-c1762b653d50', 'type': 'City', 'name': 'Monterrey', 'sort-name': 'Monterrey', 'life-span': {'ended': 'false'}}, 'isni-list': ['0000000102359162'], 'life-span': {'begin': '1995-11', 'ended': 'false'}, 'tag-list': [{'count': '2', 'name': 'ska'}, {'count': '1', 'name': 'latin'}]}, {'id': '2ba6ead4-14f4-4802-a32c-84afdf30a680', 'type': 'Person', 'ext:score': '89', 'name': 'I.N.S.P.E.C.T.O.R.', 'sort-name': 'I.N.S.P.E.C.T.O.R.', 'gender': 'male', 'country': 'DE', 'area': {'id': '85752fda-13c4-31a3-bee5-0e5cb1f51dad', 'type': 'Country', 'name': 'Germany', 'sort-name': 'Germany', 'life-span': {'ended': 'false'}}, 'disambiguation': 'Ben Elvis Mettin', 'life-span': {'ended': 'false'}}, {'id': '08ed2aa7-db30-4f00-bf56-2ab82a913cbf', 'type': 'Group', 'ext:score': '88', 'name': 'Inspector', 'sort-name': 'Inspector', 'country': 'US', 'area': {'id': '489ce91b-6658-3307-9877-795b68554c98', 'type': 'Country', 'name': 'United States', 'sort-name': 'United States', 'life-span': {'ended': 'false'}}, 'disambiguation': 'Late 80s AOR band, Minnesota', 'life-span': {'ended': 'false'}}, {'id': 'e460494c-7b29-4366-8716-0fcc39784034', 'ext:score': '88', 'name': 'Gadget Inspector', 'sort-name': 'Gadget Inspector', 'area': {'id': '1f40c6e1-47ba-4e35-996f-fe6ee5840e62', 'type': 'City', 'name': 'Los Angeles', 'sort-name': 'Los Angeles', 'life-span': {'ended': 'false'}}, 'begin-area': {'id': '1f40c6e1-47ba-4e35-996f-fe6ee5840e62', 'type': 'City', 'name': 'Los Angeles', 'sort-name': 'Los Angeles', 'life-span': {'ended': 'false'}}, 'disambiguation': 'LA Synthwave/DnB', 'life-span': {'begin': '2015', 'ended': 'false'}, 'tag-list': [{'count': '1', 'name': 'synthpop'}, {'count': '1', 'name': 'synthwave'}, {'count': '1', 'name': 'dark synth'}]}, {'id': '791564ac-90f2-409e-b623-eef85c721ef4', 'type': 'Group', 'ext:score': '87', 'name': 'The Inspector Cluzo', 'sort-name': 'Inspector Cluzo, The', 'country': 'FR', 'area': {'id': '08310658-51eb-3801-80de-5a0739207115', 'type': 'Country', 'name': 'France', 'sort-name': 'France', 'life-span': {'ended': 'false'}}, 'begin-area': {'id': 'b8b12fb4-cba4-491a-9694-c6c8f7473385', 'type': 'City', 'name': 'Mont-de-Marsan', 'sort-name': 'Mont-de-Marsan', 'life-span': {'ended': 'false'}}, 'disambiguation': 'French rock band', 'isni-list': ['0000000090348801'], 'life-span': {'begin': '2008', 'ended': 'false'}}, {'id': 'ec817cce-cab0-42fd-a587-6cc0e5c10708', 'type': 'Group', 'ext:score': '84', 'name': 'Inspector 22', 'sort-name': 'Inspector 22', 'life-span': {'ended': 'false'}}, {'id': 'ae44f3db-6211-4e1b-89ad-fea6b9aed1fb', 'type': 'Person', 'ext:score': '83', 'name': 'Inspector K', 'sort-name': 'Inspector K', 'gender': 'male', 'country': 'US', 'area': {'id': '489ce91b-6658-3307-9877-795b68554c98', 'type': 'Country', 'name': 'United States', 'sort-name': 'United States', 'life-span': {'ended': 'false'}}, 'life-span': {'ended': 'false'}}, {'id': 'bab68153-bbb8-44b1-9439-b4e3a52c0f61', 'type': 'Group', 'ext:score': '83', 'name': 'Inspector Owl', 'sort-name': 'Inspector Owl', 'life-span': {'ended': 'false'}}, {'id': '2a0b1ce7-915a-4f1c-aa73-5752d141111b', 'ext:score': '83', 'name': 'Inspector Vector', 'sort-name': 'Inspector Vector', 'life-span': {'ended': 'false'}}, {'id': '7316f666-34a3-40a8-9095-33fd58865988', 'ext:score': '83', 'name': 'The Inspector', 'sort-name': 'Inspector, The', 'life-span': {'ended': 'false'}}, {'id': '3ec943b9-c209-4e1b-bb17-6609e61331d6', 'type': 'Group', 'ext:score': '83', 'name': 'Inspector Gadje', 'sort-name': 'Inspector Gadje', 'area': {'id': '83f22bb6-4631-443c-bace-9fae8540362a', 'type': 'City', 'name': 'San Francisco', 'sort-name': 'San Francisco' ...

# %%
artistas_ska_2019_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_ska_2019:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_ska_2019_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_ska_2019_mb["artista"].append("no data")
    try:
        artistas_ska_2019_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_ska_2019_mb["pais de origen"].append("no data")
    try:
        artistas_ska_2019_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_ska_2019_mb["area de origen"].append("no data") 
    try:
        artistas_ska_2019_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"])
    except:
        artistas_ska_2019_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_ska_2019_mb["fin de actividad"].append("no activo")
        else:
            artistas_ska_2019_mb["fin de actividad"].append("activo")
    except:
        artistas_ska_2019_mb["fin de actividad"].append("no data")

# %%
df_mb_2019 = pd.DataFrame(artistas_ska_2019_mb)
df_mb_2019
# Out:
#              artista      pais de origen area de origen  \
# 0            Bracket       United States    Forestville
# 1        The Beatles      United Kingdom      Liverpool
# 2         Strung Out       United States    Simi Valley
# 3    Satanic Surfers              Sweden           Lund
# 4      Los Chickléts  Cuautitlán Izcalli        no data
# ..               ...                 ...            ...
# 111          Sublime          Long Beach     Long Beach
# 112            Koers              Lleida         Lleida
# 113              H2O       United States        no data
# 114       Cut Capers      United Kingdom        no data
# 115        Owen Gray             Jamaica       Kingston
#
#     fecha inicio actividad fin de actividad
# 0                     1992           activo
# 1                     1960           activo
# 2                     1992           activo
# 3                     1989           activo
# 4                  no data           activo
# ..                     ...              ...
# 111                   1986           activo
# 112                   2014           activo
# 113                no data           activo
# 114                no data           activo
# 115             1939-07-05           activo
#
# [116 rows x 5 columns]

# %%
df_mb_2019.to_csv("artistas_ska_2019_mb.csv", index=False)

# %%
artistas_ska_2019_mb
# Out:
# {'artista': ['Bracket',
#   'The Beatles',
#   'Strung Out',
#   'Satanic Surfers',
#   'Los Chickléts',
#   'Bite Me Bambi',
#   'Stephen King',
#   'The Beatles',
#   'Das Lumpenpack',
#   '88 Fingers Louie',
#   'Kill Lincoln',
#   'Masked Intruder',
#   'Hot Water Music',
#   'La Fúmiga',
#   'Los Enanitos Verdes',
#   'Hooray For Our Side',
#   'The Bouncing Souls',
#   'Pulley',
#   '10-FEET',
#   'The Beatles',
#   'The Beatles',
#   'Snuff',
#   'The Beatles',
#   'Rude Tins',
#   'face to face',
#   'Hans Gruber and the Die Hards',
#   'Joe Vasconcellos',
#   'The Beatles',
#   'The Beatles',
#   'Big D and the Kids Table',
#   'Tiger Army',
#   'The Planet Smashers',
#   'Panteón Rococó',
#   'Kameleba',
#   'Five State Drive',
#   'Omnigone',
#   'Be Like Max',
#   'Tommy Dorsey',
#   'The Beatles',
#   'The Beatles',
#   'Stop The Presses',
#   'Inspector',
#   'Good Riddance',
#   'Riskee and The Ridicule',
#   'Codename Colin',
#   'Los Cafres',
#   'Nat King Cole',
#   'Ten Foot Pole',
#   'Bad Cop/Bad Cop',
#   'Los Lobos',
#   'The Beatles',
#   'Los Caligaris',
#   'K-Man & The 45s',
#   'La Tremenda Korte',
#   'Duke Ellington and His Orchestra',
#   'Out of Control Army',
#   'Stephen King',
#   'Down by Law',
#   'The Beatles',
#   'No Such Noise',
#   'Just Say Nay',
#   'Hub City Stompers',
#   'Teenage Bottlerocket',
#   'Club Sandinista!',
#   'Jamaican Jazz Orchestra',
#   'Millencolin',
#   'The Beatles',
#   'EGO-WRAPPIN’',
#   'Devon Kay & the Solutions',
#   'Russkaja',
#   'Tsunami Bomb',
#   'Antidoping',
#   'Joey Cape',
#   'Noise Complaint',
#   'Tony Bennett',
#   'Lagwagon',
#   'Биртман',
#   'The Mighty Mighty Bosstones',
#   'The Living End',
#   'Los Prisioneros',
#   'Boa Brass Band',
#   'The Beatles',
#   'Nine Inch Nails',
#   'En Tol Sarmiento',
#   'Mest',
#   'Against Me!',
#   'The Bruce Lee Band',
#   '2 Minutos',
#   'The Beatles',
#   'Much the Same',
#   'The Cat Empire',
#   'South Central Skankers',
#   'Zebrahead',
#   'Quique Neira',
#   'Toots & The Maytals',
#   'The Offspring',
#   'Los de Abajo',
#   'Cigar',
#   'Sorry Sweetheart',
#   'MxPx',
#   'Catbite',
#   'Rehasher',
#   'Bad Religion',
#   'Byron Lee and the Dragonaires',
#   '31 Minutos',
#   'The Beatles',
#   '[spunge]',
#   'Bob Marley & The Wailers',
#   'New York Ska-Jazz Ensemble',
#   'Half Past Two',
#   'Sound Vision library',
#   'Sublime',
#   'Koers',
#   'H2O',
#   'Cut Capers',
#   'Owen Gray'],
#  'pais de origen': ['United States',
#   'United Kingdom',
#   'United States',
#   'Sweden',
#   'Cuautitlán Izcalli',
#   'Orange County',
#   'United States',
#   'United Kingdom',
#   'Germany',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Comunidad Valenciana',
#   'Argentina',
#   'Orange County',
#   'United States',
#   'United States',
#   'Japan',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Brugg',
#   'United States',
#   'Austin',
#   'Chile',
#   'United Kingdom',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'Canada',
#   'Mexico',
#   'Argentina',
#   'Nagoya',
#   'California',
#   'Las Vegas',
#   'United States',
#   'United Kingdom',
#   'United Kingdom',
#   'Brooklyn',
#   'Mexico',
#   'United States',
#   'no data',
#   'Hemel Hempstead',
#   'Argentina',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'Argentina',
#   'Canada',
#   'Mexico',
#   'United States',
#   'Mexico',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'no data',
#   'London',
#   'United States',
#   'United States',
#   'no data',
#   'Belgium',
#   'Sweden',
#   'United Kingdom',
#   'Japan',
#   'Chicago',
#   'Austria',
#   'United States',
#   'no data',
#   'United States',
#   'Chino',
#   'United States',
#   'United States',
#   'Russia',
#   'United States',
#   'Australia',
#   'Chile',
#   'France',
#   'United Kingdom',
#   'United States',
#   'País Vasco',
#   'United States',
#   'United States',
#   'United States',
#   'Argentina',
#   'United Kingdom',
#   'United States',
#   'Australia',
#   'United States',
#   'Orange County',
#   'Chile',
#   'Jamaica',
#   'United States',
#   'Ciudad de México',
#   'United States',
#   'Denver',
#   'United States',
#   'Philadelphia',
#   'United States',
#   'United States',
#   'Jamaica',
#   'Chile',
#   'United Kingdom',
#   'United Kingdom',
#   'Jamaica',
#   'United States',
#   'California',
#   'no data',
#   'Long Beach',
#   'Lleida',
#   'United States',
#   'United Kingdom',
#   'Jamaica'],
#  'area de origen': ['Forestville',
#   'Liverpool',
#   'Simi Valley',
#   'Lund',
#   'no data',
#   'no data',
#   'Portland',
#   'Liverpool',
#   'Germany',
#   'Chicago',
#   'no data',
#   'Madison',
#   'Gainesville',
#   'Alzira',
#   'Mendoza',
#   'Anaheim',
#   'New Brunswick',
#   'Simi Valley',
#   'no data',
#   'Liverpool',
#   'Liverpool',
#   'Hendon',
#   'Liverpool',
#   'no data',
#   'Victorville',
#   'no data',
#   'Santiago',
#   'Liverpool',
#   'Liverpool',
#   'Boston',
#   'Berkeley',
#   'Montréal',
#   'no data',
#   'Villa Mercedes',
#   'no data',
#   'no data',
#   'Las Vegas',
#   'Shenandoah',
#   'Liverpool',
#   'Liverpool',
#   'no data',
#   'Monterrey',
#   'Santa Cruz',
#   'no data',
#   'Stevenage',
#   'Buenos Aires',
#   'Montgomery',
#   'Simi Valley',
#   'Los Angeles',
#   'Los Angeles',
#   'Liverpool',
#   'Córdoba',
#   'no data',
#   'Ciudad de México',
#   'Harlem',
#   'Mexico',
#   'Portland',
#   'Los Angeles',
#   'Liverpool',
#   'no data',
#   'no data',
#   'no data',
#   'Laramie',
#   'no data',
#   'Ghent',
#   'Örebro',
#   'Liverpool',
#   'Osaka',
#   'Chicago',
#   'Wien',
#   'Petaluma',
#   'no data',
#   'Santa Barbara',
#   'no data',
#   'Long Island City',
#   'Goleta',
#   'Sankt-Peterburg',
#   'Boston',
#   'Melbourne',
#   'Chile',
#   'no data',
#   'Liverpool',
#   'Cleveland',
#   'Yécora/Iekora',
#   'Blue Island',
#   'Gainesville',
#   'San Jose',
#   'Valentín Alsina',
#   'Liverpool',
#   'Chicago',
#   'Melbourne',
#   'Los Angeles',
#   'La Habra',
#   'no data',
#   'Kingston',
#   'Huntington Beach',
#   'no data',
#   'Eugene',
#   'no data',
#   'Bremerton',
#   'no data',
#   'Gainesville',
#   'Los Angeles',
#   'Kingston',
#   'no data',
#   'Liverpool',
#   'Tewkesbury',
#   'Kingston',
#   'New York',
#   'no data',
#   '[Worldwide]',
#   'Long Beach',
#   'Lleida',
#   'no data',
#   'no data',
#   'Kingston'],
#  'fecha inicio actividad': ['1992',
#   '1960',
#   '1992',
#   '1989',
#   'no data',
#   '2018-07-14',
#   '1947-09-21',
#   '1960',
#   '2013-03',
#   '1993',
#   '2008',
#   '2010',
#   '1994-10',
#   'no data',
#   '1979',
#   '2010-11-27',
#   '1988',
#   '1994',
#   '1997',
#   '1960',
#   '1960',
#   '1986',
#   '1960',
#   '2003',
#   '1991',
#   'no data',
#   '1959-03-09',
#   '1960',
#   '1960',
#   '1995-10',
#   '1995',
#   '1994',
#   '1995',
#   '2001',
#   'no data',
#   'no data',
#   '2010',
#   '1905-11-19',
#   '1960',
#   '1960',
#   'no data',
#   '1995-11',
#   '1986',
#   'no data',
#   '2016-02-01',
#   '1987',
#   '1919-03-17',
#   '1993',
#   '2011',
#   '1973',
#   '1960',
#   '1997-08-24',
#   'no data',
#   '1994',
#   '1927',
#   '2015',
#   '1947-09-21',
#   '1989',
#   '1960',
#   'no data',
#   '2015',
#   '2002',
#   '2001',
#   'no data',
#   '2012',
#   '1992-10-12',
#   '1960',
#   '1996',
#   '2011',
#   '2005',
#   '1998',
#   'no data',
#   '1966-11-16',
#   'no data',
#   '1926-08-03',
#   '1990',
#   '2015',
#   '1983',
#   '1994',
#   '1982',
#   'no data',
#   '1960',
#   '1988',
#   '2005',
#   '1996',
#   '1997',
#   '1995',
#   '1987-07',
#   '1960',
#   '1999-05',
#   '1999',
#   'no data',
#   '1996',
#   '1973-04-11',
#   '1963',
#   '1984',
#   '1992',
#   '1996',
#   'no data',
#   '1992-06-30',
#   '2018-05',
#   '2002',
#   '1980',
#   '1950',
#   '2003-03',
#   '1960',
#   '1997',
#   '1970-12',
#   '1994',
#   'no data',
#   '2004-01-01',
#   '1986',
#   '2014',
#   'no data',
#   'no data',
#   '1939-07-05'],
#  'fin de actividad': ['activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo']}

# %%
set_artistas_ska_2020 = set(dict_tracks_ska_2020['artistas'])  # Convertir el valor asociado a la clave 'artistas' en un set para limpiar los artistas repetidos
print(set_artistas_ska_2020)
# Out:
# {'Bracket', 'PEARS', 'The Players Band', 'Faintest Idea', 'Lord Creator', 'The Silvertones', 'Bite Me Bambi', 'Left Alone', 'Los Abuelos De La Nada', 'HEY-SMITH', 'Kill Lincoln', 'NOFX', 'Masked Intruder', 'La Fúmiga', 'Лампасы', 'Los Enanitos Verdes', 'The Bouncing Souls', 'Goldfinger', 'The Skints', 'Chaser', 'Get Dead', 'Strike Anywhere', 'We Are The Union', 'Death By Stereo', 'Crazy Baldhead', 'La Mosca Tse-Tse', 'The Aquabats!', 'Bersuit Vergarabat', 'The Bandulus', 'Adhesivo', 'The Ethiopians', 'The Gritty End', 'Derrick Morgan', 'Alton Ellis', 'Tequila & The Sunrise Gang', 'Face To Face', 'The Menzingers', 'Kameleba', 'Western Standard Time Ska Orchestra', 'Panteon Rococo', 'Rico Rodriguez', 'Omnigone', 'The Holophonics', 'The Distillers', 'Desmond Dekker', 'Inspector', 'Riskee & The Ridicule', 'Slick Shoes', 'Mango Wood', 'Los Cafres', 'Screeching Weasel', 'Hightime', 'Bad Cop, Bad Cop', 'Alpheus', 'Cosmic Shuffling', 'Anti-Flag', 'The Lawrence Arms', 'Los Caligaris', 'Tokyo Ska Paradise Orchestra', "Swingin' Utters", 'Alkaline Trio', 'The Vandals', 'Just Say Nay', 'The Suicide Machines', 'BAD OPERATION', 'Korol i Shut', 'Grey Matter', 'Kotardo', 'The Bombpops', "The Steady 45's", 'Tsunami Bomb', 'The JB Conspiracy', 'Dr. Ring Ding', 'Less Than Jake', 'Dope Times', 'The Inevitables', 'Los Prisioneros', 'Mephiskapheles', 'The Chinkees', 'Mest', 'Kapanga', 'Chencha Berrinches', 'Victor Rice', 'The English Beat', 'El Natty Combo', 'Millie Manders and the Shutup', 'zebrahead', 'Something To Do', 'Toots & The Maytals', 'Victims of Circumstance', 'Balkan Paradise Orchestra', 'The Offspring', 'Los Auténticos Decadentes', 'Mad Caddies', 'Begoña Bang-Matu', 'Voodoo Glow Skulls', 'Call Me Malcolm', 'MxPx', 'Rehasher', 'Bad Religion', 'Juantxo Skalari & La Rude Band', 'KLUB', 'The Aggrolites', 'Descendents', 'Nonpalidece', 'Maldita Vecindad Y Los Hijos Del 5to. Patio', '[spunge]', 'The Wailers', 'Half Past Two', 'Sekta Core', 'Sublime', 'Los Estramboticos', 'The Meddlers', 'The Best of the Worst', 'Cut Capers'}

# %%
lista_artistas_ska_2020 = list(set_artistas_ska_2020) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_ska_2020)
# Out:
# 115

# %%
result = musicbrainzngs.search_artists(artist='Rehasher')
print(result)
# Out:
# {'artist-list': [{'id': '09d346f5-5bff-4b75-aab8-2cc2ab646321', 'type': 'Group', 'ext:score': '100', 'name': 'Rehasher', 'sort-name': 'Rehasher', 'country': 'US', 'area': {'id': '489ce91b-6658-3307-9877-795b68554c98', 'type': 'Country', 'name': 'United States', 'sort-name': 'United States', 'life-span': {'ended': 'false'}}, 'begin-area': {'id': 'dbe53871-db21-47ea-a0c3-3ab58317a3ab', 'type': 'City', 'name': 'Gainesville', 'sort-name': 'Gainesville', 'life-span': {'ended': 'false'}}, 'isni-list': ['000000046898742X'], 'life-span': {'begin': '2002', 'ended': 'false'}}], 'artist-count': 1}

# %%
artistas_ska_2020_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_ska_2020:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_ska_2020_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_ska_2020_mb["artista"].append("no data")
    try:
        artistas_ska_2020_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_ska_2020_mb["pais de origen"].append("no data")
    try:
        artistas_ska_2020_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_ska_2020_mb["area de origen"].append("no data") 
    try:
        artistas_ska_2020_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"])
    except:
        artistas_ska_2020_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_ska_2020_mb["fin de actividad"].append("no activo")
        else:
            artistas_ska_2020_mb["fin de actividad"].append("activo")
    except:
        artistas_ska_2020_mb["fin de actividad"].append("no data")

# %%
df_mb_2020 = pd.DataFrame(artistas_ska_2020_mb)
df_mb_2020
# Out:
#                    artista  pais de origen area de origen  \
# 0                  Bracket   United States    Forestville
# 1                    PEARS     New Orleans    New Orleans
# 2         The Players Band   United States      Baltimore
# 3            Faintest Idea  United Kingdom    King's Lynn
# 4             Lord Creator         Jamaica   San Fernando
# ..                     ...             ...            ...
# 110                Sublime      Long Beach     Long Beach
# 111      Los Estrambóticos          Mexico        no data
# 112            The Beatles  United Kingdom      Liverpool
# 113  The Best of the Worst   United States        no data
# 114             Cut Capers  United Kingdom        no data
#
#     fecha inicio actividad fin de actividad
# 0                     1992           activo
# 1                     2014           activo
# 2                     1999           activo
# 3                  no data           activo
# 4               1935-08-21           activo
# ..                     ...              ...
# 110                   1986           activo
# 111                   1992           activo
# 112                   1960           activo
# 113                no data           activo
# 114                no data           activo
#
# [115 rows x 5 columns]

# %%
df_mb_2020.to_csv("artistas_ska_2020_mb.csv", index=False)

# %% [markdown]
# LAST_FM

# %%
Application_name = "proyecto2"
api_key = "b183c4bdba4f4de68df23d9b1570196e"
Shared_secret = "2ebdc456c22ea4b4eb81371b8561250f"

user =	"MartaH0322"

# %%
params_info = {
        'method': 'artist.getinfo',
        'artist': "Bad Religion",
        'api_key': api_key,
        'format': 'json'
    }

url = f"http://ws.audioscrobbler.com/2.0/"

# %%
respuesta = requests.get(url, params = params_info)

respuesta.status_code
# Out:
# 200

# %%
artista = respuesta.json()

artista
# Out:
# {'artist': {'name': 'Bad Religion',
#   'mbid': '149e6720-4e4a-41a4-afca-6d29083fc091',
#   'url': 'https://www.last.fm/music/Bad+Religion',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': ''}],
#   'streamable': '0',
#   'ontour': '0',
#   'stats': {'listeners': '1404669', 'playcount': '84746727'},
#   'similar': {'artist': [{'name': 'Pennywise',
#      'url': 'https://www.last.fm/music/Pennywise',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'NOFX',
#      'url': 'https://www.last.fm/music/NOFX',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'Lagwagon',
#      'url': 'https://www.last.fm/music/Lagwagon',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'Social Distortion',
#      'url': 'https://www.last.fm/music/Social+Distortion',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'Rancid',
#      'url': 'https://www.last.fm/music/Rancid',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]}]},
#   'tags': {'tag': [{'name': 'punk', 'url': 'https://www.last.fm/tag/punk'},
#     {'name': 'punk rock', 'url': 'https://www.last.fm/tag/punk+rock'},
#     {'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'},
#     {'name': 'political', 'url': 'https://www.last.fm/tag/political'},
#     {'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}]},
#   'bio': {'links': {'link': {'#text': '',
#      'rel': 'original',
#      'href': 'https://last.fm/music/Bad+Religion/+wiki'}},
#    'published': '11 Feb 2006, 20:04',
#    'summary': 'Bad Religion is a punk rock band from Los Angeles, California, known for the social commentary in their lyrics. The band was formed in 1979 by high school students Greg Graffin (vocals), Jay Bentley (bass guitar), Jay Ziskrout (drums), and Brett Gurewitz (guitar). In 1981, they released their eponymous debut EP on their own newly-formed label, Epitaph, managed and owned by Gurewitz. 1982 saw the release of their first full-length album, How Could Hell be Any Worse?, which gained them a sizable following. <a href="https://www.last.fm/music/Bad+Religion">Read more on Last.fm</a>',
#    'content': 'Bad Religion is a punk rock band from Los Angeles, California, known for the social commentary in their lyrics. The band was formed in 1979 by high school students Greg Graffin (vocals), Jay Bentley (bass guitar), Jay Ziskrout (drums), and Brett Gurewitz (guitar). In 1981, they released their eponymous debut EP on their own newly-formed label, Epitaph, managed and owned by Gurewitz. 1982 saw the release of their first full-length album, How Could Hell be Any Worse?, which gained them a sizable following. During the recording, Ziskrout left the band and was replaced by Peter Finestone.\n\nGreg Graffin, the band\'s frontman, holds a Master\'s degree in geology from UCLA and a Ph.D. in zoology from Cornell University. His dissertation for Cornell was a comprehensive study of how modern scientists, especially those who believe in strict Darwinism, view theism and religion, and how their own religious beliefs, if any, affect their study and work. He has since published it for fans of the band.\n\nIn 1983, Bad Religion released into the unknown, a keyboard-driven psychedelic rock album that was enormously unpopular among the band\'s core fan base. It is now out of print, and generally disowned by the band. However, in past years it has become a collectors item, and has gained some acceptance from fans. It now can be seen going for more than $100 on eBay, and is often pirated.\n\nIn 1984, Greg Hetson (Circle Jerks) replaced Gurewitz. Bad Religion returned to a somewhat mellower, rock and roll version of their original sound with the back to the known, but they disbanded soon after.\n\nThe band reformed in 1987 and released suffer in 1988, cementing their comeback in the punk community. Not only is this album considered one of their best by most fans, but it is often credited with "saving" the Southern Californian punk rock scene by fans and Bad Religion\'s contemporaries alike.\n\nno control (1989) and against the grain (1990) further increased the band\'s popularity, followed by generator (1992). Before the recording sessions for the latter album commenced, drummer Pete Finestone left the band in to focus on his other band, The Fishermen. Bobby Schayer joined the band as his replacement. recipe for hate (1993) followed shortly thereafter.\n\nWith alternative rock breaking into the mainstream, Bad Religion left Epitaph for major label Atlantic and quickly re-released Recipe for Hate on the major label. 1994\'s stranger than fiction followed, but shortly after its release Brett Gurewitz left the band again. Officially, he cited the increasing amount of time he was spending at Epitaph\'s offices as the Offspring (then a part of the Epitaph roster) became one of the biggest bands of the mid-1990s. But it was well-known that the departure was not on good terms, as he later accused the band of selling out for leaving Epitaph in favor of a major label. Gurewitz recorded a song with his new band The Daredevils entitled "Hate You," reportedly directed towards Jay Bentley. Gurewitz, moreover, was struggling more seriously with heroin and other addictions that had plagued him for years.\n\nGurewitz was replaced by Brian Baker, former member of bands such as Minor Threat and Dag Nasty. Previously, Graffin and Gurewitz had split songwriting duties, but Gurewitz\'s departure left Graffin as the band\'s lone songwriter.\n\nWhat followed were a series of moderately successful albums, the gray race (1996), no substance (1998), and the new america (2000). As their popularity waned, Bad Religion left Atlantic in 2001 and returned to Epitaph. Bobby Schayer left the band following a serious shoulder injury and was replaced by Brooks Wackerman (Suicidal Tendencies) and Brett Gurewitz rejoined the band in time to record the process of belief (2002). the empire strikes first was in June 2004. Both albums are widely regarded as a return to form for the band. \n\nIn 2004, the band released digitally-remastered versions of five of their early a ...

# %%
artista.keys()
# Out:
# dict_keys(['artist'])

# %%
artista["artist"].keys()
# Out:
# dict_keys(['name', 'mbid', 'url', 'image', 'streamable', 'ontour', 'stats', 'similar', 'tags', 'bio'])

# %%
artista["artist"]["bio"]
# Out:
# {'links': {'link': {'#text': '',
#    'rel': 'original',
#    'href': 'https://last.fm/music/Bad+Religion/+wiki'}},
#  'published': '11 Feb 2006, 20:04',
#  'summary': 'Bad Religion is a punk rock band from Los Angeles, California, known for the social commentary in their lyrics. The band was formed in 1979 by high school students Greg Graffin (vocals), Jay Bentley (bass guitar), Jay Ziskrout (drums), and Brett Gurewitz (guitar). In 1981, they released their eponymous debut EP on their own newly-formed label, Epitaph, managed and owned by Gurewitz. 1982 saw the release of their first full-length album, How Could Hell be Any Worse?, which gained them a sizable following. <a href="https://www.last.fm/music/Bad+Religion">Read more on Last.fm</a>',
#  'content': 'Bad Religion is a punk rock band from Los Angeles, California, known for the social commentary in their lyrics. The band was formed in 1979 by high school students Greg Graffin (vocals), Jay Bentley (bass guitar), Jay Ziskrout (drums), and Brett Gurewitz (guitar). In 1981, they released their eponymous debut EP on their own newly-formed label, Epitaph, managed and owned by Gurewitz. 1982 saw the release of their first full-length album, How Could Hell be Any Worse?, which gained them a sizable following. During the recording, Ziskrout left the band and was replaced by Peter Finestone.\n\nGreg Graffin, the band\'s frontman, holds a Master\'s degree in geology from UCLA and a Ph.D. in zoology from Cornell University. His dissertation for Cornell was a comprehensive study of how modern scientists, especially those who believe in strict Darwinism, view theism and religion, and how their own religious beliefs, if any, affect their study and work. He has since published it for fans of the band.\n\nIn 1983, Bad Religion released into the unknown, a keyboard-driven psychedelic rock album that was enormously unpopular among the band\'s core fan base. It is now out of print, and generally disowned by the band. However, in past years it has become a collectors item, and has gained some acceptance from fans. It now can be seen going for more than $100 on eBay, and is often pirated.\n\nIn 1984, Greg Hetson (Circle Jerks) replaced Gurewitz. Bad Religion returned to a somewhat mellower, rock and roll version of their original sound with the back to the known, but they disbanded soon after.\n\nThe band reformed in 1987 and released suffer in 1988, cementing their comeback in the punk community. Not only is this album considered one of their best by most fans, but it is often credited with "saving" the Southern Californian punk rock scene by fans and Bad Religion\'s contemporaries alike.\n\nno control (1989) and against the grain (1990) further increased the band\'s popularity, followed by generator (1992). Before the recording sessions for the latter album commenced, drummer Pete Finestone left the band in to focus on his other band, The Fishermen. Bobby Schayer joined the band as his replacement. recipe for hate (1993) followed shortly thereafter.\n\nWith alternative rock breaking into the mainstream, Bad Religion left Epitaph for major label Atlantic and quickly re-released Recipe for Hate on the major label. 1994\'s stranger than fiction followed, but shortly after its release Brett Gurewitz left the band again. Officially, he cited the increasing amount of time he was spending at Epitaph\'s offices as the Offspring (then a part of the Epitaph roster) became one of the biggest bands of the mid-1990s. But it was well-known that the departure was not on good terms, as he later accused the band of selling out for leaving Epitaph in favor of a major label. Gurewitz recorded a song with his new band The Daredevils entitled "Hate You," reportedly directed towards Jay Bentley. Gurewitz, moreover, was struggling more seriously with heroin and other addictions that had plagued him for years.\n\nGurewitz was replaced by Brian Baker, former member of bands such as Minor Threat and Dag Nasty. Previously, Graffin and Gurewitz had split songwriting duties, but Gurewitz\'s departure left Graffin as the band\'s lone songwriter.\n\nWhat followed were a series of moderately successful albums, the gray race (1996), no substance (1998), and the new america (2000). As their popularity waned, Bad Religion left Atlantic in 2001 and returned to Epitaph. Bobby Schayer left the band following a serious shoulder injury and was replaced by Brooks Wackerman (Suicidal Tendencies) and Brett Gurewitz rejoined the band in time to record the process of belief (2002). the empire strikes first was in June 2004. Both albums are widely regarded as a return to form for the band. \n\nIn 2004, the band released digitally-remastered versions of five of their early alb ...

# %%
artista["artist"]["bio"]["summary"]
# Out:
# 'Bad Religion is a punk rock band from Los Angeles, California, known for the social commentary in their lyrics. The band was formed in 1979 by high school students Greg Graffin (vocals), Jay Bentley (bass guitar), Jay Ziskrout (drums), and Brett Gurewitz (guitar). In 1981, they released their eponymous debut EP on their own newly-formed label, Epitaph, managed and owned by Gurewitz. 1982 saw the release of their first full-length album, How Could Hell be Any Worse?, which gained them a sizable following. <a href="https://www.last.fm/music/Bad+Religion">Read more on Last.fm</a>'

# %%
artista["artist"]
# Out:
# {'name': 'Bad Religion',
#  'mbid': '149e6720-4e4a-41a4-afca-6d29083fc091',
#  'url': 'https://www.last.fm/music/Bad+Religion',
#  'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'small'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'medium'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'large'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'extralarge'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'mega'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': ''}],
#  'streamable': '0',
#  'ontour': '0',
#  'stats': {'listeners': '1404669', 'playcount': '84746727'},
#  'similar': {'artist': [{'name': 'Pennywise',
#     'url': 'https://www.last.fm/music/Pennywise',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': ''}]},
#    {'name': 'NOFX',
#     'url': 'https://www.last.fm/music/NOFX',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': ''}]},
#    {'name': 'Lagwagon',
#     'url': 'https://www.last.fm/music/Lagwagon',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': ''}]},
#    {'name': 'Social Distortion',
#     'url': 'https://www.last.fm/music/Social+Distortion',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': ''}]},
#    {'name': 'Rancid',
#     'url': 'https://www.last.fm/music/Rancid',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': ''}]}]},
#  'tags': {'tag': [{'name': 'punk', 'url': 'https://www.last.fm/tag/punk'},
#    {'name': 'punk rock', 'url': 'https://www.last.fm/tag/punk+rock'},
#    {'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'},
#    {'name': 'political', 'url': 'https://www.last.fm/tag/political'},
#    {'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}]},
#  'bio': {'links': {'link': {'#text': '',
#     'rel': 'original',
#     'href': 'https://last.fm/music/Bad+Religion/+wiki'}},
#   'published': '11 Feb 2006, 20:04',
#   'summary': 'Bad Religion is a punk rock band from Los Angeles, California, known for the social commentary in their lyrics. The band was formed in 1979 by high school students Greg Graffin (vocals), Jay Bentley (bass guitar), Jay Ziskrout (drums), and Brett Gurewitz (guitar). In 1981, they released their eponymous debut EP on their own newly-formed label, Epitaph, managed and owned by Gurewitz. 1982 saw the release of their first full-length album, How Could Hell be Any Worse?, which gained them a sizable following. <a href="https://www.last.fm/music/Bad+Religion">Read more on Last.fm</a>',
#   'content': 'Bad Religion is a punk rock band from Los Angeles, California, known for the social commentary in their lyrics. The band was formed in 1979 by high school students Greg Graffin (vocals), Jay Bentley (bass guitar), Jay Ziskrout (drums), and Brett Gurewitz (guitar). In 1981, they released their eponymous debut EP on their own newly-formed label, Epitaph, managed and owned by Gurewitz. 1982 saw the release of their first full-length album, How Could Hell be Any Worse?, which gained them a sizable following. During the recording, Ziskrout left the band and was replaced by Peter Finestone.\n\nGreg Graffin, the band\'s frontman, holds a Master\'s degree in geology from UCLA and a Ph.D. in zoology from Cornell University. His dissertation for Cornell was a comprehensive study of how modern scientists, especially those who believe in strict Darwinism, view theism and religion, and how their own religious beliefs, if any, affect their study and work. He has since published it for fans of the band.\n\nIn 1983, Bad Religion released into the unknown, a keyboard-driven psychedelic rock album that was enormously unpopular among the band\'s core fan base. It is now out of print, and generally disowned by the band. However, in past years it has become a collectors item, and has gained some acceptance from fans. It now can be seen going for more than $100 on eBay, and is often pirated.\n\nIn 1984, Greg Hetson (Circle Jerks) replaced Gurewitz. Bad Religion returned to a somewhat mellower, rock and roll version of their original sound with the back to the known, but they disbanded soon after.\n\nThe band reformed in 1987 and released suffer in 1988, cementing their comeback in the punk community. Not only is this album considered one of their best by most fans, but it is often credited with "saving" the Southern Californian punk rock scene by fans and Bad Religion\'s contemporaries alike.\n\nno control (1989) and against the grain (1990) further increased the band\'s popularity, followed by generator (1992). Before the recording sessions for the latter album commenced, drummer Pete Finestone left the band in to focus on his other band, The Fishermen. Bobby Schayer joined the band as his replacement. recipe for hate (1993) followed shortly thereafter.\n\nWith alternative rock breaking into the mainstream, Bad Religion left Epitaph for major label Atlantic and quickly re-released Recipe for Hate on the major label. 1994\'s stranger than fiction followed, but shortly after its release Brett Gurewitz left the band again. Officially, he cited the increasing amount of time he was spending at Epitaph\'s offices as the Offspring (then a part of the Epitaph roster) became one of the biggest bands of the mid-1990s. But it was well-known that the departure was not on good terms, as he later accused the band of selling out for leaving Epitaph in favor of a major label. Gurewitz recorded a song with his new band The Daredevils entitled "Hate You," reportedly directed towards Jay Bentley. Gurewitz, moreover, was struggling more seriously with heroin and other addictions that had plagued him for years.\n\nGurewitz was replaced by Brian Baker, former member of bands such as Minor Threat and Dag Nasty. Previously, Graffin and Gurewitz had split songwriting duties, but Gurewitz\'s departure left Graffin as the band\'s lone songwriter.\n\nWhat followed were a series of moderately successful albums, the gray race (1996), no substance (1998), and the new america (2000). As their popularity waned, Bad Religion left Atlantic in 2001 and returned to Epitaph. Bobby Schayer left the band following a serious shoulder injury and was replaced by Brooks Wackerman (Suicidal Tendencies) and Brett Gurewitz rejoined the band in time to record the process of belief (2002). the empire strikes first was in June 2004. Both albums are widely regarded as a return to form for the band. \n\nIn 2004, the band released digitally-remastered versions of five of their early al ...

# %%
artista["artist"]["stats"]["listeners"]
# Out:
# '1404669'

# %%
artista["artist"]["stats"]["playcount"]
# Out:
# '84746727'

# %%
artista["artist"]["similar"]["artist"][0]["name"]
# Out:
# 'Pennywise'

# %%
dic_artistas_ska_2019_lfm = {"Artista":[], "Biografia":[], "Listeners":[], "Playcount":[], "Artistas Similares":[]}
for a in lista_artistas_ska_2019 :
    params_info = {
        'method': 'artist.getinfo',
        'artist': a,
        'api_key': api_key,
        'format': 'json'
        }
    url = f"http://ws.audioscrobbler.com/2.0/"
    respuesta = requests.get(url, params=params_info)
    artista = respuesta.json()
    try:
        dic_artistas_ska_2019_lfm['Artista'].append(artista["artist"]["name"])
    except:
        dic_artistas_ska_2019_lfm["Artista"].append(None)
    try:
        dic_artistas_ska_2019_lfm["Biografia"].append(artista["artist"]["bio"]["summary"])
    except:
        dic_artistas_ska_2019_lfm["Biografia"].append(None)
    try:
        dic_artistas_ska_2019_lfm["Listeners"].append(artista["artist"]["stats"]["listeners"])
    except:
        dic_artistas_ska_2019_lfm["Listeners"].append(None)
    try:
        dic_artistas_ska_2019_lfm["Playcount"].append(artista["artist"]["stats"]["playcount"])
    except:
        dic_artistas_ska_2019_lfm["Playcount"].append(None)
    try:
        dic_artistas_ska_2019_lfm["Artistas Similares"].append(artista["artist"]["similar"]["artist"][0]["name"])
    except:
        dic_artistas_ska_2019_lfm["Artistas Similares"].append(None)
print((dic_artistas_ska_2019_lfm["Artista"]))
print((dic_artistas_ska_2019_lfm["Biografia"]))
print((dic_artistas_ska_2019_lfm["Listeners"]))
print((dic_artistas_ska_2019_lfm["Playcount"]))
print((dic_artistas_ska_2019_lfm["Artistas Similares"]))
# Out:
# ['Bracket', 'The Decline', 'Strung Out', 'Satanic Surfers', 'Los Chickléts', 'Bite Me Bambi', 'King Punch', 'The Offenders', 'Das Lumpenpack', '88 Fingers Louie', 'Kill Lincoln', 'Masked Intruder', 'Hot Water Music', 'La Fúmiga', 'Los Enanitos Verdes', 'Hooray for Our Side', 'The Bouncing Souls', 'Pulley', '10-FEET', 'The Skints', 'The Specials', 'Snuff', 'The Aquabats!', 'Rude Tins', 'Face to Face', 'Hans Gruber And The Die Hards', 'Joe Vasconcellos', 'The Menzingers', 'The Paranoias', 'Big D And The Kids Table', 'Tiger Army', 'The Planet Smashers', 'panteon rococo', 'Kameleba', 'Five State Drive', 'OMNIGONE', 'Be Like Max', 'TOMMY TORNADO', 'The Interrupters', 'The Holophonics', 'Stop the Presses', 'Inspector', 'Good Riddance', 'Riskee & The Ridicule', 'Codename Colin', 'Los Cafres', 'Stranger Cole', 'Ten Foot Pole', 'Bad Cop, Bad Cop', 'Los Skagaleros', 'The Magnetics', 'Los Caligaris', 'K-Man & The 45s', 'La Tremenda Korte', 'Tokyo Ska Paradise Orchestra', 'Out of Control Army', 'King Prawn', 'Down By Law', 'The Vandals', 'No Such Noise', 'Just Say Nay', 'Hub City Stompers', 'Teenage Bottlerocket', 'Club Sandinista!', 'Jamaican Jazz Orchestra', 'Millencolin', 'The Bombpops', 'EGO-WRAPPIN’', 'Devon Kay & The Solutions', 'Russkaja', 'Tsunami Bomb', 'Antidoping', 'Joey Cape', 'Noise Complaint', 'Val Bennett', 'Lagwagon', 'БИРТМАН', 'The Mighty Mighty Bosstones', 'The Living End', 'Los Prisioneros', 'Boa Brass Band', 'The Beat', 'Buck-O-Nine', 'En Tol Sarmiento', 'Mest', 'Against Me!', 'Bruce Lee Band', '2 Minutos', 'The Ataris', 'Much the Same', 'The Cat Empire', 'South Central Skankers', 'Zebrahead', 'Quique Neira', 'Toots & The Maytals', 'The Offspring', 'Los de Abajo', 'Cigar', 'Sorry Sweetheart', 'MxPx', 'Catbite', 'Rehasher', 'Bad Religion', 'Byron Lee & The Dragonaires', '31 Minutos', 'The Aggrolites', '[spunge]', 'The Wailers', 'New York Ska-Jazz Ensemble', 'Half Past Two', 'Tunnel Vision', 'Sublime', 'Koers', 'H2O', 'Cut Capers', 'Owen Gray']
# ['There are two artists which use this name:\n1. A punk band from the United States\n2. A rap group from Nigeria\n\n1. Bracket is a melodic punk band from Forestville, California, originally signed to Caroline Records. Their original, smooth sound led them to associate with Fat Wreck Chords, producing several albums and EPs. In 2006, they debuted Requiem through Takeover Records.\n\n2. Bracket is a hiphop duo from Nigeria. Yori Yori is a hit from their album Yori Yori. Yori Yori means happiness, it describes a positive feeling. <a href="https://www.last.fm/music/Bracket">Read more on Last.fm</a>', 'For the French punk band, see The Decline!.\n\npunk rock from Perth, Western Australia\nThe Decline are a 90s style skate punk band from Perth, Western Australia. They formed in 2006 are heavily influenced by the likes of Frenzal Rhomb, NOFX, Lagwagon, Descendents, Less Than Jake & Propagandhi.\n\nOR\n\nHardcore from doylestown, PA\n\nOR\n\npunk band form Essex, UK\n\nOR \n\nhardcore/punk band from Saskatoon, Canada <a href="https://www.last.fm/music/The+Decline">Read more on Last.fm</a>', '\nStrung Out is a punk rock band from Simi Valley, California, USA, formed in 1992. They are known mainly for their musical style, which fuses aspects of punk rock and metal to form their primary sound. They have released nine albums on Fat Wreck Chords and appeared on numerous compilations and skate/surf videos. They have played on the Warped Tour and continue to tour internationally.\n\nThe original lineup consisted of vocalist Jason Cruz, guitarists Jake Kiley and Rob Ramos, bassist Jim Cherry and drummer Adam Austin. <a href="https://www.last.fm/music/Strung+Out">Read more on Last.fm</a>', 'First off, some history: Satanic Surfers played a major part in the Swedish melodic punk explosion that took place in the mid nineties. Combining strong melodies and fast paced punk with both personal and political lyrics, the band soon reached audiences all over the world. Early influences include bands such as SNFU, RKL and The Misfits. The band was originally founded by Rodrigo and Erik in high school back in 1989 in Lund, Sweden. After having gone through the usual line-up changes during its formative years <a href="https://www.last.fm/music/Satanic+Surfers">Read more on Last.fm</a>', ' <a href="https://www.last.fm/music/Los+Chickl%C3%A9ts">Read more on Last.fm</a>', 'Hailing from Southern California, Bite Me Bambi brings sounds reminiscent of British 2 Tone and 3rd wave ska into the 21st century. With energetic songs and pedigree musicianship, BMB gets the crowd on their feet and dancing. Comprised of members from some of your favorite ska bands (My Superhero, Save Ferris, Starpool). This new group breathes fresh life to a genre that may have originated in Jamaica, and honed in Britain, but perfected in the haze, blight, glamour, and beauty of the Southland.\n\nhttps://www.bitemebambi.com/ <a href="https://www.last.fm/music/Bite+Me+Bambi">Read more on Last.fm</a>', 'King Punch are a lively 7-piece ska-punk band hailing from London, England. Known for their energetic live shows, they are equally at home smashing together a blend of ska, punk, hard rock and swing in crushed London clubs or up on big festival stages - either way, everyone\'s going to be going home sweaty and happy. <a href="https://www.last.fm/music/King+Punch">Read more on Last.fm</a>', '1)  Italian 2Tone/Ska/Skinhead Reggae band formed in 2005 in Cosenza – Italy by vocalist/songwriter Valerio (as drummer in that time), The Offenders became popular in their local scene after the release of “Rudeboys In A Dancefloor” in February 2006. Many months later, their second single “Hooligan Reggae” gave them the chance to sign for the German label Conehead Records, on which they released their first full length in November 2007. <a href="https://www.last.fm/music/The+Offenders">Read more on Last.fm</a>', ' <a href="https://www.last.fm/music/Das+Lumpenpack">Read more on Last.fm</a>', '88 Fingers  ...
# ['70440', '20624', '343324', '124931', '505', '4743', '1046', '15550', '30901', '142544', '21183', '52944', '333796', '6441', '241745', '1968', '514043', '179430', '59390', '60037', '978662', '90952', '81903', '6143', '299818', '3568', '57448', '233414', '2861', '301056', '223533', '153039', '48565', '17983', '1892', '4448', '5463', '3242', '185225', '10956', '1918', '109093', '245832', '6583', '3941', '169545', '53190', '133627', '24988', '1216', '3201', '58447', '3741', '10650', '37658', '5064', '33727', '95553', '382252', '1250', '6419', '12323', '171840', '3051', '1346', '734690', '34515', '14055', '4852', '95084', '139945', '12006', '43557', '1667', '37136', '515590', '17627', '682450', '326805', '246724', '104', '258264', '133833', '4376', '293692', '742332', '16692', '62376', '830484', '62593', '480229', '4537', '840643', '24745', '180949', '3892934', '101640', '22080', '1753', '658519', '12785', '30254', '1404669', '59545', '65933', '125259', '56545', '611196', '74320', '8083', '8928', '2530887', '1590', '226275', '22907', '60145']
# ['806167', '428791', '9032652', '2784048', '2100', '63050', '10081', '274937', '968987', '2001548', '494734', '1819495', '14063677', '248001', '5046015', '21107', '14024854', '2720671', '1648316', '1568305', '16156922', '1514581', '1651521', '42189', '6209506', '70065', '875258', '15282594', '28425', '6463941', '7757466', '2784091', '967753', '247555', '16280', '83436', '88165', '22475', '4643877', '171997', '16877', '1655016', '5799345', '98669', '29190', '2982208', '250781', '1450622', '502534', '8221', '24701', '1295846', '16168', '156001', '541380', '36055', '526949', '868057', '6138756', '6807', '53548', '231154', '5448117', '12059', '8232', '28839011', '749133', '180052', '116114', '2015611', '2613646', '170403', '974597', '30803', '149896', '15967366', '468538', '11691410', '7281034', '7291456', '891', '2224379', '1223554', '111810', '4357910', '40267120', '277202', '2107193', '15128794', '1291644', '13678797', '38770', '25962576', '183138', '1917874', '169237482', '690660', '371589', '19745', '13779883', '250912', '421038', '84746727', '400041', '1975046', '2606737', '819607', '4915287', '1196656', '127607', '53098', '82873939', '14528', '7378262', '183548', '282922']
# ['Frenzal Rhomb', 'Chaser', 'Good Riddance', 'No Fun at All', 'Skapital Sound', 'Backyard Superheroes', 'Hooray for Our Side', 'The Valkyrians', 'Provinz', 'Good Riddance', 'We Are the Union', 'Teenage Bottlerocket', 'The Draft', 'Figa Flawas', None, 'The B Sharps', 'Face to Face', 'Ten Foot Pole', 'ELLEGARDEN', "Gentleman's Dub Club", 'The Selecter', 'Good Riddance', None, 'Just Say Nay', 'Lagwagon', 'Young Costello', 'Chico Trujillo', 'Spanish Love Songs', 'Los Shadows', 'Mustard Plug', 'Nekromantix', 'Big D And The Kids Table', None, 'Riddim', 'Kuzira', 'JOYstick!', 'Backyard Superheroes', 'Carlos Dingo', 'Rancid', 'The Planet Smashers', 'Hans Gruber And The Die Hards', 'Panteón Rococó', 'No Use for a Name', 'The Bar Stool Preachers', 'Just Say Nay', 'Nonpalidece', 'The Gaylads', 'Pulley', 'JOYstick!', 'Alla Spina', 'Es-Feiv', 'Inspector', 'Rude Tins', 'Nana Pancha', None, 'Skapital Sound', 'Random Hand', 'Pulley', 'Guttermouth', 'Behind Deadlines', 'Rude Tins', 'Inspecter 7', 'Not On Tour', 'The Ska Vengers', 'TOMMY TORNADO', 'Lagwagon', 'Bad Cop/Bad Cop', None, 'Hans Gruber And The Die Hards', 'Rotfront', 'The Distillers', 'Los Rastrillos', 'Tony Sly', 'The Upfux', 'Ken Parker', 'No Use for a Name', None, 'Big D And The Kids Table', 'Grinspoon', 'Los Tres', 'LALAO RABESON', 'The Selecter', 'Mustard Plug', 'ZetaK', 'Fenix TX', 'Laura Jane Grace', None, 'Flema', 'MxPx', 'Belvedere', 'The John Butler Trio', '8 Kalacas', 'Sum 41', 'Riddim', None, 'Sum 41', 'Los Estrambóticos', 'Ten Foot Pole', 'Younger Than Neil', 'Slick Shoes', 'BAD OPERATION', 'The Decline', 'Pennywise', 'Justin Hinds & The Dominoes', 'Los Bunkers', 'The Slackers', 'The Holophonics', 'Bob Marley & The Wailers', 'The Toasters', 'Catbite', 'X-O-DUS', 'Pepper', 'Adala', 'Ignite', 'Little Violet', 'Derrick Morgan']

# %%
df_lfm_2019 = pd.DataFrame(dic_artistas_ska_2019_lfm)
df_lfm_2019
# Out:
#              Artista                                          Biografia  \
# 0            Bracket  There are two artists which use this name:\n1....
# 1        The Decline  For the French punk band, see The Decline!.\n\...
# 2         Strung Out  \nStrung Out is a punk rock band from Simi Val...
# 3    Satanic Surfers  First off, some history: Satanic Surfers playe...
# 4      Los Chickléts   <a href="https://www.last.fm/music/Los+Chickl...
# ..               ...                                                ...
# 111          Sublime  Sublime was an American reggae rock and ska pu...
# 112            Koers   <a href="https://www.last.fm/music/Koers">Rea...
# 113              H2O  There are at least 10 groups with the name H2O...
# 114       Cut Capers  Cut Capers are a 9-piece Bristol band whose en...
# 115        Owen Gray  Owen Gray also known as Owen Grey (born 5 July...
#
#     Listeners Playcount Artistas Similares
# 0       70440    806167      Frenzal Rhomb
# 1       20624    428791             Chaser
# 2      343324   9032652      Good Riddance
# 3      124931   2784048      No Fun at All
# 4         505      2100     Skapital Sound
# ..        ...       ...                ...
# 111   2530887  82873939             Pepper
# 112      1590     14528              Adala
# 113    226275   7378262             Ignite
# 114     22907    183548      Little Violet
# 115     60145    282922     Derrick Morgan
#
# [116 rows x 5 columns]

# %%
df_lfm_2019.to_csv("dic_artistas_ska_2019_lfm.csv", index=False)

# %%
dic_artistas_ska_2020_lfm = {"Artista":[], "Biografia":[], "Listeners":[], "Playcount":[], "Artistas Similares":[]}
for a in lista_artistas_ska_2020 :
    params_info = {
        'method': 'artist.getinfo',
        'artist': a,
        'api_key': api_key,
        'format': 'json'
        }
    url = f"http://ws.audioscrobbler.com/2.0/"
    respuesta = requests.get(url, params=params_info)
    artista = respuesta.json()
    try:
        dic_artistas_ska_2020_lfm['Artista'].append(artista["artist"]["name"])
    except:
        dic_artistas_ska_2020_lfm["Artista"].append(None)
    try:
        dic_artistas_ska_2020_lfm["Biografia"].append(artista["artist"]["bio"]["summary"])
    except:
        dic_artistas_ska_2020_lfm["Biografia"].append(None)
    try:
        dic_artistas_ska_2020_lfm["Listeners"].append(artista["artist"]["stats"]["listeners"])
    except:
        dic_artistas_ska_2020_lfm["Listeners"].append(None)
    try:
        dic_artistas_ska_2020_lfm["Playcount"].append(artista["artist"]["stats"]["playcount"])
    except:
        dic_artistas_ska_2020_lfm["Playcount"].append(None)
    try:
        dic_artistas_ska_2020_lfm["Artistas Similares"].append(artista["artist"]["similar"]["artist"][0]["name"])
    except:
        dic_artistas_ska_2020_lfm["Artistas Similares"].append(None)
print((dic_artistas_ska_2020_lfm["Artista"]))
print((dic_artistas_ska_2020_lfm["Biografia"]))
print((dic_artistas_ska_2020_lfm["Listeners"]))
print((dic_artistas_ska_2020_lfm["Playcount"]))
print((dic_artistas_ska_2020_lfm["Artistas Similares"]))
# Out:
# ['Bracket', 'Pears', 'The Players Band', 'Faintest Idea', 'Lord Creator', 'The Silvertones', 'Bite Me Bambi', 'Left Alone', 'Los Abuelos de la Nada', 'HEY-SMITH', 'Kill Lincoln', 'NOFX', 'Masked Intruder', 'La Fúmiga', 'Лампасы', 'Los Enanitos Verdes', 'The Bouncing Souls', 'Goldfinger', 'The Skints', 'Chaser', 'get dead', 'Strike Anywhere', 'We Are The Union', 'Death By Stereo', 'Crazy Baldhead', 'La Mosca Tse-Tse', 'The Aquabats!', 'Bersuit Vergarabat', 'The Bandulus', 'Adhesivo', 'The Ethiopians', 'The Gritty End', 'Derrick Morgan', 'Alton Ellis', 'Tequila & The Sunrise Gang', 'Face to Face', 'The Menzingers', 'Kameleba', 'Western Standard Time Ska Orchestra', 'panteon rococo', 'Rico Rodriguez', 'OMNIGONE', 'The Holophonics', 'The Distillers', 'Desmond Dekker', 'Inspector', 'Riskee & The Ridicule', 'Slick Shoes', 'Mango Wood', 'Los Cafres', 'Screeching Weasel', 'Hightime', 'Bad Cop, Bad Cop', 'Alpheus', 'Cosmic Shuffling', 'Anti-Flag', 'The Lawrence Arms', 'Los Caligaris', 'Tokyo Ska Paradise Orchestra', "Swingin' Utters", 'Alkaline Trio', 'The Vandals', 'Just Say Nay', 'The Suicide Machines', 'BAD OPERATION', 'Korol I Shut', 'Grey Matter', 'Kotardo', 'The Bombpops', "The Steady 45's", 'Tsunami Bomb', 'The JB Conspiracy', 'Dr. Ring Ding', 'Less Than Jake', 'Dope Times', 'The Inevitables', 'Los Prisioneros', 'Mephiskapheles', 'The Chinkees', 'Mest', 'Kapanga', 'Chencha Berrinches', 'Victor Rice', 'The English Beat', 'El Natty Combo', 'Millie Manders and The Shutup', 'Zebrahead', 'Something to Do', 'Toots & The Maytals', 'Victims Of Circumstance', 'Balkan Paradise Orchestra', 'The Offspring', 'Los Auténticos Decadentes', 'Mad Caddies', 'Begoña Bang-Matu', 'Voodoo Glow Skulls', 'Call Me Malcolm', 'MxPx', 'Rehasher', 'Bad Religion', 'Juantxo Skalari & La Rude Band', 'Klub', 'The Aggrolites', 'Descendents', 'Nonpalidece', 'Maldita Vecindad Y Los Hijos Del 5to. Patio', '[spunge]', 'The Wailers', 'Half Past Two', 'Sekta Core', 'Sublime', 'Los Estramboticos', 'The Meddlers', 'The Best of the Worst', 'Cut Capers']
# ['There are two artists which use this name:\n1. A punk band from the United States\n2. A rap group from Nigeria\n\n1. Bracket is a melodic punk band from Forestville, California, originally signed to Caroline Records. Their original, smooth sound led them to associate with Fat Wreck Chords, producing several albums and EPs. In 2006, they debuted Requiem through Takeover Records.\n\n2. Bracket is a hiphop duo from Nigeria. Yori Yori is a hit from their album Yori Yori. Yori Yori means happiness, it describes a positive feeling. <a href="https://www.last.fm/music/Bracket">Read more on Last.fm</a>', 'At only 8 months old, PEARS (all caps, no "the") is New Orleans\' newest punk band, and have come from deep within the voodoo juju gris gris swamps of the French Quarter to give you fleas/scabies/bedbugs. Their mixture of hardcore riffs, pop-punk melodies, and sludgy breaks creates a sound that belongs to them, only them, shut up.\n\nPEARS released their critically acclaimed album, "Go To Prison", in June 2014, and was released on vinyl in September 2014 via Ryan Young\'s (Off With Their Heads) podcast/label <a href="https://www.last.fm/music/Pears">Read more on Last.fm</a>', 'The Players Band is an 8-piece ska band formed in Baltimore in 1999. The Players\' musical style combines ska, rock, and reggae, and is characterized by the use of upbeat horns and percussion. \n\nThe band is made up of:\n Dan Schneider (Guitar, Vocals)\nAndy Schneider (Drums,  Manager)\nMike Gorman (Sax)\nDave Blackstone (Trombone, back-up vocals)\nNick Reider (Trumpet, back up vocals)\nSelector Pablo Fiasco (Keyboard)\nJoe Ross (Bass guitar)\nMark Leary\n <a href="https://www.last.fm/music/The+Players+Band">Read more on Last.fm</a>', 'Playing anywhere and everywhere from squats to bars to festival main stages and drawing inspiration from bands such as The Specials, The Filaments & Operation Ivy this is angry political commentary that you can shout along to while stomping your feet.\nFaintest Idea take the bouncing beat of 2 Tone Ska and smash it over the head with fast, angry UK Punk. Hailing from the East Anglian region of Britain the rabble rousing political lyrics are shouted over layers of catchy brass lines and heavy boot stomping beats. <a href="https://www.last.fm/music/Faintest+Idea">Read more on Last.fm</a>', 'Lord Creator (born Kentrick Patrick in San Fernando, Trinidad and Tobago on 21 August 1935; died 30 June 2023) was a Trinidadian-born calypso, R&B, ska, and rocksteady artist who moved to Jamacica in 1959. Remembered for writing and recording the song "Kingston Town" (later recorded by British group UB40), Lord Creator was an important and positive "outside" influence during the early development of the Jamaican music scene. \n\nHe started as a calypso singer under the name Lord Creator. <a href="https://www.last.fm/music/Lord+Creator">Read more on Last.fm</a>', 'There are multiple artists with that name: \n1. The Silvertones is a Jamaican reggae group,\n2. The Silvertones is a Texas Blues band\n3. The Silvertones is a blues band from Cologne, Germany\n4. The Silvertones is the incorrect tag for the Singapore band The Silverstones. Unfortunately Last.fm automatically redirects the correct name tag for this band to the incorrect name tag The Silvertones.\n\n1. The Silvertones (who also recorded as The Musketeers and The Muskyteers) were a Jamaican reggae harmony group formed in 1964 <a href="https://www.last.fm/music/The+Silvertones">Read more on Last.fm</a>', 'Hailing from Southern California, Bite Me Bambi brings sounds reminiscent of British 2 Tone and 3rd wave ska into the 21st century. With energetic songs and pedigree musicianship, BMB gets the crowd on their feet and dancing. Comprised of members from some of your favorite ska bands (My Superhero, Save Ferris, Starpool). This new group breathes fresh life to a genre that may have originated in Jamaica, and honed in Britain, but perfected in the haze, blight, glamour, and beauty of the So ...
# ['70440', '31104', '500', '5615', '55249', '64969', '4743', '65259', '240226', '18986', '21183', '1278272', '52944', '6441', '34138', '241745', '514043', '1035662', '60037', '31028', '19650', '302672', '52278', '111845', '4601', '112739', '81903', '215546', '978', '2105', '231306', '261', '145884', '258750', '6968', '299818', '233414', '17983', '1779', '48565', '28905', '4448', '10956', '601975', '457440', '109093', '6583', '99528', '560', '169545', '251450', '4862', '24988', '3908', '799', '935205', '206941', '58447', '37658', '185732', '989232', '382252', '6419', '334582', '8402', '42593', '5701', '410', '34515', '2414', '139945', '28529', '11091', '780403', '1182', '2394', '246724', '30679', '34761', '293692', '48633', '7252', '13420', '205566', '11462', '2914', '840643', '4695', '180949', '5760', '5739', '3892934', '239917', '368102', '816', '191911', '12859', '658519', '30254', '1404669', '3402', '5260', '125259', '843502', '62446', '63848', '56545', '611196', '8083', '12029', '2530887', '10052', '915', '7900', '22907']
# ['806167', '606340', '4400', '118057', '234240', '283402', '63050', '782870', '3189301', '603516', '494734', '70812606', '1819495', '248001', '859679', '5046015', '14024854', '19577768', '1568305', '274279', '513587', '7537015', '1281395', '2335171', '43805', '1137512', '1651521', '4588567', '15969', '30162', '1616817', '3048', '1151031', '2846166', '113692', '6209506', '15282594', '247555', '19087', '967753', '207281', '83436', '171997', '17419881', '4817115', '1655016', '98669', '1327547', '3987', '2982208', '6564197', '58928', '502534', '31429', '4530', '32612867', '10107057', '1295846', '541380', '2565558', '56046211', '6138756', '53548', '6349202', '142273', '1346649', '87199', '2047', '749133', '25130', '2613646', '441366', '118214', '28018071', '6342', '26877', '7291456', '347030', '349959', '4357910', '520326', '40832', '90525', '2312484', '99684', '50139', '25962576', '61005', '1917874', '54007', '39332', '169237482', '4195938', '10882897', '8501', '2721121', '220299', '13779883', '421038', '84746727', '48047', '32997', '2606737', '34903274', '854796', '839058', '819607', '4915287', '127607', '289991', '82873939', '119980', '2965', '156949', '183548']
# ['Frenzal Rhomb', 'Direct Hit!', 'Stubborn All-Stars', 'Tyrannosaurus Alan', 'The Gaylads', 'The Heptones', 'Backyard Superheroes', 'Street Dogs', 'Andrés Calamaro', 'TOTALFAT', 'We Are the Union', 'Lagwagon', 'Teenage Bottlerocket', 'Figa Flawas', "Ска'N'ворд", None, 'Face to Face', 'Less Than Jake', "Gentleman's Dub Club", 'The Decline', None, 'Strung Out', None, 'Good Riddance', 'Stubborn All-Stars', None, None, 'Los Piojos', 'Matamoska!', 'Anastasio y los del Monte', 'The Pioneers', 'The Quaranteds', 'The Techniques', 'The Heptones', 'Tequila and the Sunrise Gang', 'Lagwagon', 'Spanish Love Songs', 'Riddim', "The Steady 45's", None, 'The Skatalites', 'JOYstick!', 'The Planet Smashers', 'Brody Dalle', 'Derrick Morgan', 'Panteón Rococó', 'The Bar Stool Preachers', 'MxPx', 'Smooth Beans', 'Nonpalidece', 'The Mr. T Experience', 'Russian Girlfriends', 'JOYstick!', 'Mango Wood', 'TOMMY TORNADO', 'Pennywise', 'The Falcon', 'Inspector', None, 'Good Riddance', 'Matt Skiba And The Sekrets', 'Guttermouth', 'Rude Tins', 'Mustard Plug', 'Catbite', None, 'The Best of the Worst', '8 Kalacas', 'Bad Cop/Bad Cop', 'Western Standard Time Ska Orchestra', 'The Distillers', 'Catch-It Kebabs', 'Dr. Ring-Ding & The Senior Allstars', 'Reel Big Fish', 'Marzela', 'Stop the Presses', 'Los Tres', "Skankin' Pickle", 'The Bruce Lee Band', 'Fenix TX', 'Estelares', 'La Banda Skalavera', 'Stubborn All-Stars', 'General Public', 'Riddim', 'The Bar Stool Preachers', 'Sum 41', 'Backyard Superheroes', None, 'Backyard Superheroes', 'Klezmerson', 'Sum 41', 'Los Fabulosos Cadillacs', 'Less Than Jake', 'Malarians', "Skankin' Pickle", 'Kill Lincoln', 'Slick Shoes', 'The Decline', 'Pennywise', 'Oferta Especial', 'DJ Who', 'The Slackers', 'All', 'Los Cafres', 'Inspector', 'The Holophonics', 'Bob Marley & The Wailers', 'Catbite', 'Los Estrambóticos', 'Pepper', None, 'K-Man & The 45s', 'Hans Gruber And The Die Hards', 'Little Violet']

# %%
df_lfm_2020 = pd.DataFrame(dic_artistas_ska_2020_lfm)
df_lfm_2020
# Out:
#                    Artista                                          Biografia  \
# 0                  Bracket  There are two artists which use this name:\n1....
# 1                    Pears  At only 8 months old, PEARS (all caps, no "the...
# 2         The Players Band  The Players Band is an 8-piece ska band formed...
# 3            Faintest Idea  Playing anywhere and everywhere from squats to...
# 4             Lord Creator  Lord Creator (born Kentrick Patrick in San Fer...
# ..                     ...                                                ...
# 110                Sublime  Sublime was an American reggae rock and ska pu...
# 111      Los Estramboticos  Los Estrambóticos tienen una amplia carrera de...
# 112           The Meddlers   <a href="https://www.last.fm/music/The+Meddle...
# 113  The Best of the Worst  2005-Present\n\nThe Best of the Worst is a ska...
# 114             Cut Capers  Cut Capers are a 9-piece Bristol band whose en...
#
#     Listeners Playcount             Artistas Similares
# 0       70440    806167                  Frenzal Rhomb
# 1       31104    606340                    Direct Hit!
# 2         500      4400             Stubborn All-Stars
# 3        5615    118057             Tyrannosaurus Alan
# 4       55249    234240                    The Gaylads
# ..        ...       ...                            ...
# 110   2530887  82873939                         Pepper
# 111     10052    119980                           None
# 112       915      2965                K-Man & The 45s
# 113      7900    156949  Hans Gruber And The Die Hards
# 114     22907    183548                  Little Violet
#
# [115 rows x 5 columns]

# %%
df_lfm_2020.to_csv("dic_artistas_ska_2020_lfm.csv", index=False)
