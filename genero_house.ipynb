# %%
import requests
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = '9f13200092714d0a868666486c7fe6dc'
api_key = '60c7756990384928a3521695221eccc2'

auth_manager = SpotifyClientCredentials( client_id, api_key)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
canciones = sp.search(q="genre:house year:2019", type="track", limit=50, offset=0)

# %%
canciones["tracks"]["items"][0]["album"]["release_date"]
# Out:
# '2019-10-04'

# %%
canciones["tracks"]["items"][0]["artists"][0]["name"]
canciones["tracks"]["items"][0]["artists"][0]["name"]
# Out:
# 'Travis Scott'

# %% [markdown]
# ## CANCIONES HOUSE 2019

# %%
#LISTA DE CANCIONES HOUSE 2019
dict_tracks_house_2019 ={"canciones":[], "artistas": [], "género": "house", "tipo": "track", "año lanzamiento": []}
for offset in range(0,500,50):
    canciones_2019 = sp.search(q="genre:house year:2019", type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_house_2019["canciones"].append(canciones_2019["tracks"]["items"][i]["name"])
        

print(dict_tracks_house_2019)    
len(dict_tracks_house_2019)
# Out:
# {'canciones': ['HIGHEST IN THE ROOM', 'One Thing Right', 'Ride It', 'Opendoors', 'Dancin - Krono Remix', 'Here With Me', 'Higher Love', 'All Around The World (La La La)', 'Summer Days (feat. Macklemore & Patrick Stump of Fall Out Boy)', 'On My Way', 'Control', "U Weren't Here I Really Miss You", 'San Frandisco', 'Lose Control', 'Trap [Feat. Lil Baby]', 'Temptations', 'You Little Beauty', 'Post Malone (feat. RANI)', 'Rescue Me', '94 Bentley', 'Alors On Danse - DubDogz Remix', 'Monster', 'Piece Of Your Heart - Alok Remix', 'Play', 'Piece Of Your Heart', 'HIGHEST IN THE ROOM (feat. ROSALÍA & Lil Baby) - REMIX', 'Blah Blah Blah', 'Post Malone (feat. RANI)', 'Turn Me On (feat. Vula)', 'Catchy Song (feat. T-Pain & That Girl Lay Lay)', 'Hooked', 'Baby Baby', 'Another Me (with Dylan Matthew)', 'Move Your Body', 'Count Contessa', 'On My Mind', 'Breathing', 'Redemption', 'Waiting', 'The Way', "You Don't Know Me (feat. RAYE)", 'Island (feat. Nevve)', 'Better With You', 'WET', "Giant (with Rag'n'Bone Man)", 'Tongue Tied (with YUNGBLUD & blackbear)', 'Bittersweet Symphony (feat. Emily Roberts)', 'Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu")', 'Rockstar', 'Who Do You Blame', 'Starry Night - Edit', 'NUMB', 'What I Like About You (feat. Theresa Rex)', 'Roses - Imanbek Remix', 'Think About You', 'Jubel', 'Gipsy', 'Losing My Way', '5 Thousand Singles', 'Enough to Believe - Jamie Jones Remix', 'Go Solo (feat. Tom Rosenthal)', 'Ritual', 'Ride It - Jonas Blue Remix', 'No Sleep (feat. Bonn)', 'Honey', 'Bones (feat. OneRepublic)', 'The One - NGHTMRE Remix', '22:39', 'So Many Times', 'Changes', 'Free Your Body', 'Monster - Robin Schulz Remix', 'Gimme! Gimme! Gimme!', "I'm a Rock", 'Leave My Home', 'Red Light Green Light - For Club Play Only, Pt. 6', 'Mamma Mia (feat. Amber Van Day)', 'All My Friends', 'Used To Love (with Dean Lewis)', 'Anything Can Happen [Feat. Meek Mill]', 'Braincase', 'Know Some', 'Dreamland', 'Slow Burn', "I Was Lovin' You (feat. Dots Per Inch & Ayak) - TS7 Remix", 'God Is A Dancer (with Mabel)', 'DFCW', 'Not Ok', 'Through Glass', 'Stay With Me', 'Just Friends', 'Proud', 'This Groove', 'Instruction (feat. Demi Lovato & Stefflon Don)', 'All Night Long - Y.V.E. 48 Remix', 'Save Me Tonight', 'Light It Up (with Tyga & Chris Brown)', 'Tokyo', 'Faith (with Dolly Parton) [feat. Mr. Probz]', 'On Your Mind', "Cradle - LTN 'Sunrise' Remix", 'One Life', 'Simple Hit', 'Iris in the Dark', 'By My Side', 'Ghost Voices - Lane 8 Remix', 'Every Morning', 'Tired and Sick', 'Need It', 'Who Am I', 'Sad (feat. Afrojack)', 'Tricky Tricky', 'Return to Oz - ARTBAT Remix', 'Trip', 'Pica', 'With You', 'Wedding Day', 'Repeat After Me', 'CASH COW', 'Boom Shakalaka', 'Melody', 'Epico', 'REDLIGHT', 'Post Malone (feat. RANI) - VIZE Remix', 'Gravity (feat. Laura Korinth) - Edit', 'Rescue Me', 'Lost In Mind', 'Soul Sacrifice', 'RIVA (Restart the Game) - Radio Edit', 'Came For The Low', 'Breathe (feat. Ina Wroldsen)', 'I Should Have Walked Away', 'This Is Real (ft. Ella Henderson)', 'High School Reunion', 'These Are Just Places To Me Now', 'BREAK LAW', 'Birthright', 'My Best Life (feat. Mike Waters) - Club Mix', 'One Thing Right - Koni Remix', 'Laserface 01 (Aperture)', 'Praise You', 'Sell Out', 'cabin', 'Daydreams', 'NEW WIP', 'On & On', 'Instagram', 'Maelstrom', 'Summer Love', 'Bad Bitch', 'Heavy With Hoping', 'Nobody Else - A-Trak Remix', 'See The End', 'We Belong', "Zonnetje Op M'n Porem", 'Make Your Move', 'Trophies', 'Open Spaces', "WE'RE BACK", 'How I Feel', 'Headnoise (Get Hype)', 'We Got That Cool (feat. Afrojack & Icona Pop)', 'Juliet & Romeo', 'Hell on Earth', 'The Wall', 'Fire & Gold', 'Beat Of My Heart', 'Post Malone (feat. RANI) - GATTÜSO Remix', 'Castles In The Sky', 'One Thing Right - Firebeatz Remix', 'Dreams', 'Drop It', 'PYRO', 'Call Me After You Hear This', 'All I Want Is A Yacht', 'Nostalgia', 'Final Fantasy - Original Mix', 'Go Like - D&B Remix', 'Wasabi', 'Walk In The Spot', 'Forever Young', 'Up & Down', 'Turn It U ...
# 5

# %% [markdown]
# ## ARTISTAS HOUSE 2019

# %%
#ARTISTAS DE CANCIONES HOUSE 2019

for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"house" year:2019', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_house_2019["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_house_2019)
len(dict_tracks_house_2019)
# Out:
) - Edit', 'Rescue Me', 'Lost In Mind', 'Soul Sacrifice', 'RIVA (Restart the Game) - Radio Edit', 'Came For The Low', 'Breathe (feat. Ina Wroldsen)', 'I Should Have Walked Away', 'This Is Real (ft. Ella Henderson)', 'High School Reunion', 'These Are Just Places To Me Now', 'BREAK LAW', 'Birthright', 'My Best Life (feat. Mike Waters) - Club Mix', 'One Thing Right - Koni Remix', 'Laserface 01 (Aperture)', 'Praise You', 'Sell Out', 'cabin', 'Daydreams', 'NEW WIP', 'On & On', 'Instagram', 'Maelstrom', 'Summer Love', 'Bad Bitch', 'Heavy With Hoping', 'Nobody Else - A-Trak Remix', 'See The End', 'We Belong', "Zonnetje Op M'n Porem", 'Make Your Move', 'Trophies', 'Open Spaces', "WE'RE BACK", 'How I Feel', 'Headnoise (Get Hype)', 'We Got That Cool (feat. Afrojack & Icona Pop)', 'Juliet & Romeo', 'Hell on Earth', 'The Wall', 'Fire & Gold', 'Beat Of My Heart', 'Post Malone (feat. RANI) - GATTÜSO Remix', 'Castles In The Sky', 'One Thing Right - Firebeatz Remix', 'Dreams', 'Drop It', 'PYRO', 'Call Me After You Hear This', 'All I Want Is A Yacht', 'Nostalgia', 'Final Fantasy - Original Mix', 'Go Like - D&B Remix', 'Wasabi', 'Walk In The Spot', 'Forever Young', 'Up & Down', 'Turn It U ...
# 5

# %% [markdown]
# ## AÑO LANZAMIENTO 2019

# %%
#AÑO DE LANZAMIENTO
for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"house" year:2019', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_house_2019["año lanzamiento"].append(track["album"]['release_date'])
print(dict_tracks_house_2019)
len(dict_tracks_house_2019)
# Out:
# {'canciones': ['HIGHEST IN THE ROOM', 'One Thing Right', 'Ride It', 'Opendoors', 'Dancin - Krono Remix', 'Here With Me', 'Higher Love', 'All Around The World (La La La)', 'Summer Days (feat. Macklemore & Patrick Stump of Fall Out Boy)', 'On My Way', 'Control', "U Weren't Here I Really Miss You", 'San Frandisco', 'Lose Control', 'Trap [Feat. Lil Baby]', 'Temptations', 'You Little Beauty', 'Post Malone (feat. RANI)', 'Rescue Me', '94 Bentley', 'Alors On Danse - DubDogz Remix', 'Monster', 'Piece Of Your Heart - Alok Remix', 'Play', 'Piece Of Your Heart', 'HIGHEST IN THE ROOM (feat. ROSALÍA & Lil Baby) - REMIX', 'Blah Blah Blah', 'Post Malone (feat. RANI)', 'Turn Me On (feat. Vula)', 'Catchy Song (feat. T-Pain & That Girl Lay Lay)', 'Hooked', 'Baby Baby', 'Another Me (with Dylan Matthew)', 'Move Your Body', 'Count Contessa', 'On My Mind', 'Breathing', 'Redemption', 'Waiting', 'The Way', "You Don't Know Me (feat. RAYE)", 'Island (feat. Nevve)', 'Better With You', 'WET', "Giant (with Rag'n'Bone Man)", 'Tongue Tied (with YUNGBLUD & blackbear)', 'Bittersweet Symphony (feat. Emily Roberts)', 'Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu")', 'Rockstar', 'Who
# 5

# %%
df_2019 = pd.DataFrame(dict_tracks_house_2019)
df_2019
# Out:
#                                   canciones      artistas género   tipo  \
# 0                       HIGHEST IN THE ROOM  Travis Scott  house  track
# 1                           One Thing Right    Marshmello  house  track
# 2                                   Ride It        Regard  house  track
# 3                                 Opendoors        Jitwam  house  track
# 4                      Dancin - Krono Remix   Aaron Smith  house  track
# ..                                      ...           ...    ...    ...
# 495  Better With You - Kastra & twoDB Remix          3LAU  house  track
# 496                           Wait A Minute   Party Favor  house  track
# 497                          Hold You Tight         Diplo  house  track
# 498                       Live Fast - PUBGM   Alan Walker  house  track
# 499                            Lose Control          Grum  house  track
#
#     año lanzamiento
# 0        2019-10-04
# 1        2019-06-21
# 2        2019-07-26
# 3        2019-05-03
# 4        2019-11-11
# ..              ...
# 495      2019-07-10
# 496      2019-04-26
# 497      2019-05-02
# 498      2019-07-25
# 499      2019-11-08
#
# [500 rows x 5 columns]

# %%
df_2019.to_csv("dict_tracks_house_2019.csv", index=False)

# %%
df_2019.describe(include="object")
# Out:
#                        canciones    artistas género   tipo año lanzamiento
# count                        500         500    500    500             500
# unique                       491         252      1      1             140
# top     Post Malone (feat. RANI)  Marshmello  house  track      2019-11-15
# freq                           2          19    500    500              16

# %% [markdown]
# ## CANCIONES HOUSE 2020

# %%
#LISTA DE CANCIONES HOUSE 2020

dict_tracks_house_2020 ={"canciones":[], "artistas": [], "género": "house", "tipo": "track", "año lanzamiento": []}
for offset in range(0,500,50):
    canciones_2020 = sp.search(q="genre:house year:2020", type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_house_2020["canciones"].append(canciones_2020["tracks"]["items"][i]["name"])
        

print(dict_tracks_house_2020)    
len(dict_tracks_house_2020)
# Out:
# {'canciones': ['Heartless (feat. Morgan Wallen)', 'Roses - Imanbek Remix', 'Higher Love', 'Baianá', 'Be Kind (with Halsey)', 'FRANCHISE (feat. Young Thug & M.I.A.)', 'Pump It Up', 'The Business', 'Forget It', 'Ocean Drive', 'Pumped Up Kicks', 'Bayside - Radio Edit', 'Jackie Chan', 'Lose Somebody', 'Turn Back Time', 'TRRST', 'Deep End - SIDEPIECE Remix', 'Calling (Lose My Mind) - Radio Edit', 'Over Now (with The Weeknd)', "What's Love Got to Do with It", 'Wake Me Up In Paris', 'GET LOST', 'Road', 'Paradise (feat. Dermot Kennedy)', 'Suffocate', 'Goosebumps', 'Secrets', 'Someone Else', 'FRANCHISE (feat. Future, Young Thug & M.I.A.) - REMIX', 'Take A Step Back', 'OK Not To Be OK', "Somebody's Watching Me", 'FEELING GUD', 'Demons - Massane Remix', 'Crusade', 'Moments - Ben Böhmer & Nils Hoffmann Remix', 'Midnight (feat. Liam Payne)', 'Drown (feat. Clinton Kane)', 'Lose Somebody', 'Jerusalema (feat. Nomcebo Zikode)', 'We No Speak Americano (Edit)', 'Ghostkeeper', 'Dance with Me (feat.
yoto', 'Love Like That', 'Beside You (feat. Georgia Ku)', 'Rave Love', 'Rescue Me', 'Gang', 'Higher Ground (feat. John Martin)', 'Heartless (feat. Morgan Wallen)', 'Be Kind (with Halsey) [Surf Mesa Remix]', 'Moving Blind', 'Where Have You Gone (Anywhere)', 'Creep', 'Thank You [Not So Bad]', 'In The Club', 'You and Me', 'Марш', 'Show Me', 'Your Love', 'Home', 'Could You Love Me', 'Brightes ...
# 5

# %% [markdown]
# ## ARTISTAS HOUSE 2020

# %%
#ARTISTAS DE CANCIONES HOUSE 2020
for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"house" year:2020', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_house_2020["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_house_2020)
len(dict_tracks_house_2020)
# Out:
# {'canciones': ['Heartless (feat. Morgan Wallen)', 'Roses - Imanbek Remix', 'Higher Love', 'Baianá', 'Be Kind (with Halsey)', 'FRANCHISE (feat. Young Thug & M.I.A.)', 'Pump It Up', 'The Business', 'Forget It', 'Ocean Drive', 'Pumped Up Kicks', 'Bayside - Radio Edit', 'Jackie Chan', 'Lose Somebody', 'Turn Back Time', 'TRRST', 'Deep End - SIDEPIECE Remix', 'Calling (Lose My Mind) - Radio Edit', 'Over Now (with The Weeknd)', "What's Love Got to Do with It", 'Wake Me Up In Paris', 'GET LOST', 'Road', 'Paradise (feat. Dermot Kennedy)', 'Suffocate', 'Goosebumps', 'Secrets', 'Someone Else', 'FRANCHISE (feat. Future, Young Thug & M.I.A.) - REMIX', 'Take A Step Back', 'OK Not To Be OK', "Somebody's Watching Me", 'FEELING GUD', 'Demons - Massane Remix', 'Crusade', 'Moments - Ben Böhmer & Nils Hoffmann Remix', 'Midnight (feat. Liam Payne)', 'Drown (feat. Clinton Kane)', 'Lose Somebody', 'Jerusalema (feat. Nomcebo Zikode)', 'We No Speak Americano (Edit)', 'Ghostkeeper', 'Dance with Me (feat. Thomas Rhett & Young Thug)', 'Kids (feat. MKLA)', 'Gimme Gimme - Club Mix', 'Hot Stuff', "I'll Wait", 'Goodbye', "Wanna Go Dancin'", 'End of Time', 'Ritual', 'Not So Bad (feat. Emie)', 'West Coast (feat. Quinn XCII)', 'Tondo', 'DAMN', 'Say My Name', 'The Rope (feat. POLIÇA)', 'Lonely (with Jonas Brothers)', 'Someday', 'Coming Home', "Don't Wanna Know", 'Pullin Up', 'Ecstasy - Mixed', 'I Found You', 'Fade Away', "I'll Wait", 'Touch', 'Forever Yours - Avicii Tribute', 'We No Speak Americano', 'Bottle’s Bout Dead (feat. ERNEST)', 'Alone - Sullivan King Remix', 'Broken Glass', 'Freedom', 'Heartless (with Julia Michaels & Morgan Wallen)', 'Army', 'Time After Time', 'Freaks', 'Poison', 'Rule The World', 'Take Me Home', "Don't Say Goodbye (feat. Tove Lo)", 'Jerusalema (feat. Burna Boy & Nomcebo Zikode) - Remix', 'Rise Up (feat. Vamero)', 'U Got Me', 'Freedom', 'Stars Tonight', 'Apologize', 'Be With You (ft. Gloria Kim)', 'Tinted Eyes (feat. 24kGoldn)', 'Children', 'OVERDOSE', 'Fly Me to the Moon', 'Bad', 'Every Breath You Take', 'Faith (with Dolly Parton) [feat. Mr. Probz]', 'HIGHEST IN THE ROOM', 'ON FIRE', 'Praise', 'Nuclear Bass Face (feat. Boogie T)', 'Stereo Love', 'Together', 'Luv Is Not Enough', 'Numb', 'Thin Line', 'By Your Side', 'Homeless', 'Breathe, Be Happy', 'Battle Drums', 'Love To Go', 'Touch Me - PAX & Rui Da Silva Version', 'Only Now (feat. Tyler Graves)', 'SUB ZERO', 'Sucks To Be You', 'i miss u (with Au/Ra)', 'Wish We Could', 'Too Much (feat. Usher)', 'Like It Is', 'Ibiza', 'Ocean Drive', 'I Was Made', 'Run', 'Come Together', "Summer's End", 'Freedom Is Priceless', 'Tidalwave', 'Summer 91', 'Get in Trouble (So What)', 'Foolish Of Me (feat. Jonathan Mendelsohn)', 'Prayer In C', 'Bones (feat. OneRepublic)', 'About Us (feat. EMME)', 'Told You So', "What's the Move (feat. General Degree)", 'Tell Me', 'Come My Way', 'Blue Monday', "Don't Leave Me Now", 'Jessie (i miss you)', 'Away With Me - Fideles Remix', 'Aurora', 'Like It Is', 'Space Melody (Edward Artemyev) (feat. Leony)', 'Too Much', 'Lose You', 'WUT', 'Expressing What Matters', 'Flames (with ZAYN)', 'Born To Love (feat. SHELLS)', "Can't Love Myself (feat. Mishaal & LPW)", 'Seesaw', 'Flow', 'Gorgeous', 'The Power', 'Only A Fool (with Pink Sweat$)', 'Hypnotized', 'Crazy', 'Flip Reset', 'No Fear No More (Remix)', 'Up All Night (feat. Afrojack)', 'GOMF (feat. BRIDGE)', 'Zombie (Zombic & Felix Schorn Remix)', 'Poppin Bottles', 'Cold Day in Hell', 'Greenlights', 'Rescue', 'On My Mind - Do You Dance? Edit', 'Feels Like Forever', 'Solid Ground', 'Save My Grave', 'Яма', 'Плак-Плак', 'In Your Eyes (feat. Alida)', 'Kyoto', 'Love Like That', 'Beside You (feat. Georgia Ku)', 'Rave Love', 'Rescue Me', 'Gang', 'Higher Ground (feat. John Martin)', 'Heartless (feat. Morgan Wallen)', 'Be Kind (with Halsey) [Surf Mesa Remix]', 'Moving Blind', 'Where Have You Gone (Anywhere)', 'Creep', 'Thank You [Not So Bad]', 'In The Club', 'You and Me', 'Марш', 'Show Me', 'Your Love', 'Home', 'Could You Love Me', 'Brightes ...
# 5

# %% [markdown]
# ## AÑO LANZAMIENTO 2020

# %%
#AÑO DE LANZAMIENTO
for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"house" year:2020', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_house_2020["año lanzamiento"].append(track["album"]['release_date'])
print(dict_tracks_house_2020)
len(dict_tracks_house_2020)
# Out:
'Tell Me', 'Come My Way', 'Blue Monday', "Don't Leave Me Now", 'Jessie (i miss you)', 'Away With Me - Fideles Remix', 'Aurora', 'Like It Is', 'Space Melody (Edward Artemyev) (feat. Leony)', 'Too Much', 'Lose You', 'WUT', 'Expressing What Matters', 'Flames (with ZAYN)', 'Born To Love (feat. SHELLS)', "Can't Love Myself (feat. Mishaal & LPW)", 'Seesaw', 'Flow', 'Gorgeous', 'The Power', 'Only A Fool (with Pink Sweat$)', 'Hypnotized', 'Crazy', 'Flip Reset', 'No Fear No More (Remix)', 'Up All Night (feat. Afrojack)', 'GOMF (feat. BRIDGE)', 'Zombie (Zombic & Felix Schorn Remix)', 'Poppin Bottles', 'Cold Day in Hell', 'Greenlights', 'Rescue', 'On My Mind - Do You Dance? Edit', 'Feels Like Forever', 'Solid Ground', 'Save My Grave', 'Яма', 'Плак-Плак', 'In Your Eyes (feat. Alida)', 'Kyoto', 'Love Like That', 'Beside You (feat. Georgia Ku)', 'Rave Love', 'Rescue Me', 'Gang', 'Higher Ground (feat. John Martin)', 'Heartless (feat. Morgan Wallen)', 'Be Kind (with Halsey) [Surf Mesa Remix]', 'Moving Blind', 'Where Have You Gone (Anywhere)', 'Creep', 'Thank You [Not So Bad]', 'In The Club', 'You and Me', 'Марш', 'Show Me', 'Your Love', 'Home', 'Could You Love Me', 'Brightes ...
# 5

# %%
df_2020 = pd.DataFrame(dict_tracks_house_2020)
df_2020
# Out:
#                            canciones          artistas género   tipo  \
# 0    Heartless (feat. Morgan Wallen)             Diplo  house  track
# 1              Roses - Imanbek Remix         SAINt JHN  house  track
# 2                        Higher Love              Kygo  house  track
# 3                             Baianá          Bakermat  house  track
# 4              Be Kind (with Halsey)        Marshmello  house  track
# ..                               ...               ...    ...    ...
# 495     I'm Solo (feat. Barry Drift)  Claude VonStroke  house  track
# 496                         Birthday        Disclosure  house  track
# 497            The Best Rapper Alive        Dj Streaks  house  track
# 498                 Girl - 6am Remix         KC Lights  house  track
# 499                  Be Mine Tonight          Breakbot  house  track
#
#     año lanzamiento
# 0        2020-05-29
# 1        2020-11-20
# 2        2020-05-29
# 3        2020-10-09
# 4        2020-05-01
# ..              ...
# 495      2020-04-03
# 496      2020-08-26
# 497      2020-02-14
# 498      2020-10-23
# 499      2020-03-13
#
# [500 rows x 5 columns]

# %%
df_2020.to_csv("dict_tracks_house_2020.csv", index=False)

# %%
df_2020.describe(include="object")
# Out:
#                                     canciones artistas género   tipo  \
# count                                     500      500    500    500
# unique                                    480      259      1      1
# top     FRANCHISE (feat. Young Thug & M.I.A.)     Kygo  house  track
# freq                                        3       25    500    500
#
#        año lanzamiento
# count              500
# unique             132
# top         2020-05-29
# freq                30

# %%
df_2020.duplicated().sum()
# Out:
# 3

# %% [markdown]
# # MUSICBRAINZ

# %%
#pip install musicbrainzngs   #Instalamos la libreria

# %%
#Importamos la libreria 

import musicbrainzngs

# %%
#Configuramos el usuario 
musicbrainzngs.set_useragent("MusicStream", "1.0", "laura2016custy@gmail.com")

# %% [markdown]
# # ARTISTAS HOUSE 2019

ayan', '4B', 'Tiësto', 'Matroda', 'Fred again..', 'Marshmello', 'Mike Perry', 'Darkzy', 'AFROJACK', 'Yann Muller', 'Nora Van Elken', 'Nora En Pure', 'Rezz', 'Marten Hørger', 'Hot Since 82', 'Ardalan', 'Zeds Dead', 'Dombresky', 'Aaron Smith', 'Riton', 'K-391', 'Dog Blood', 'Walker & Royce', 'Above & Beyond', 'Calvin Harris', 'SIDEPIECE', 'Kidnap', 'Sultan + Shepard', 'Martin Solveig', 'Kygo', 'Felix Jaehn', 'Azealia Banks', 'PAAX (Tulum)', 'Lost Frequencies', 'AC Slater', 'Boris Brejcha', 'Julian Calor', 'Galantis', 'Chico Rose', 'DJ S.K.T', 'Ehrling', 'Grum', 'Dillon Francis', 'John De Sohn', 'Cupido', 'Fox Stevenson', 'Matisse & Sadko', 'Wax Motif', 'Yves V', 'Didier Armeni', 'Ian van Dahl', 'Mat.Joe', 'Kura', 'DJ Goja', 'Martin Garrix', 'Jimmy Sax', 'Party Favor', 'HUGEL', 'Chris Lake', 'Don Diablo', 'Jax Jones', 'Just Kiddin', 'Palm Trees', 'Durante', 'Regard', 'Dimitri Vegas & Like Mike', 'Tujamo', 'Steve Aoki', 'Angelo Ferreri', 'Morgan Page', 'Cut Off', 'Disco Fries', 'Conducta', 'MEDUZA', 'Amtrac', 'Steff da Campo', 'Gorgon City', 'What So Not', 'Lane 8', 'Habstrakt', 'Aexcit', 'San Holo'}

# %%
lista_artistas_2019 = list(set_artistas_2019) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_2019)
# Out:
# 252

# %%
#ejemplo de como muestra los resultados:
result = musicbrainzngs.search_artists(artist='Marshmellow')
print(result)
# Out:
# {'artist-list': [{'id': 'aaabd9dc-711e-4f3c-bcdc-233dcdc29551', 'type': 'Person', 'ext:score': '100', 'name': 'Marshmellow', 'sort-name': 'Marshmellow', 'gender': 'male', 'area': {'id': 'b2bc1294-77be-4c7b-af93-9868b83b1f34', 'type': 'City', 'name': 'Auckland', 'sort-name': 'Auckland', 'life-span': {'ended': 'false'}}, 'begin-area': {'id': 'b2bc1294-77be-4c7b-af93-9868b83b1f34', 'type': 'City', 'name': 'Auckland', 'sort-name': 'Auckland', 'life-span': {'ended': 'false'}}, 'disambiguation': 'New Zealand', 'ipi-list': ['00261920575'], 'life-span': {'begin': '1975', 'ended': 'false'}}, {'id': '8cddcc52-632f-4c9a-908e-bd4394d5e7fc', 'type': 'Person', 'ext:score': '99', 'name': 'Marshmellow', 'sort-name': 'Marshmellow', 'gender': 'male', 'disambiguation': 'Yuri Wesseling; trance', 'life-span': {'ended': 'false'}}, {'id': '71cfbc8e-b0f0-4a9b-ac07-20306b69207c', 'ext:score': '90', 'name': 'Marshmellow Club', 'sort-name': 'Marshmellow Club', 'life-span': {'ended': 'false'}}, {'id': '198903dc-8891-416f-9e4b-f3482839626a', 'type': 'Group', 'ext:score': '90', 'name': 'Marshmellow Men', 'sort-name': 'Marshmellow Men', 'life-span': {'ended': 'false'}}, {'id': 'b71e8bbb-974f-4ee7-9490-9f3d8e759574', 'ext:score': '89', 'name': 'Hard Marshmellow', 'sort-name': 'Hard Marshmellow', 'life-span': {'ended': 'false'}}, {'id': '2052298c-b5e5-4ed2-9267-f00b419d3e6a', 'type': 'Person', 'ext:score': '89', 'name': 'Marshmellow Alien', 'sort-name': 'Marshmellow Alien', 'gender': 'male', 'disambiguation': 'Daniël Leeflang aka DJ Dano, hardcore/gabber', 'life-span': {'ended': 'false'}}, {'id': '940f61df-ceb8-4a19-8410-a3c5fd634d82', 'ext:score': '89', 'name': 'Marshmellow Mike', 'sort-name': 'Marshmellow Mike', 'life-span': {'ended': 'false'}}, {'id': 'babdf149-1cc0-4fe1-aa6f-bd95f22d4e1d', 'ext:score': '83', 'name': 'The Marshmellow Highway', 'sort-name': 'Marshmellow Highway, The', 'disambiguation': '60s Psychedelic', 'life-span': {'ended': 'false'}}, {'id': 'a3a7dc2c-0334-458c-8981-9cc4232825ff', 'type': 'Group', 'ext:score': '76', 'name': 'George F. Smallwood & Marshmellow Band', 'sort-name': 'Smallwood, George F. & Marshmellow Band', 'life-span': {'ended': 'false'}}], 'artist-count': 9}

# %%
#Aqui tenemos la búsqueda de un artista. Trabajando con la librería. 
artistas_2019_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_2019:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_2019_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_2019_mb["artista"].append("no data")
    try:
        artistas_2019_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_2019_mb["pais de origen"].append("no data")
    try:
        artistas_2019_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_2019_mb["area de origen"].append("no data") 
    try:
        artistas_2019_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"])
    except:
        artistas_2019_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_2019_mb["fin de actividad"].append("no activo")
        else:
            artistas_2019_mb["fin de actividad"].append("activo")
    except:
        artistas_2019_mb["fin de actividad"].append("no data")

# %%
df_mb_2019 = pd.DataFrame(artistas_2019_mb)

df_mb_2019
# Out:
#          artista pais de origen area de origen fecha inicio actividad  \
# 0           Sole  United States       Portland             1977-09-25
# 1     Neil Young         Canada        Toronto             1945-11-12
# 2     Emmit Fenn  United States       Berkeley                no data
# 3       Vicetone      Groningen      Groningen                   2012
# 4          Rampa        no data        no data                no data
# ..           ...            ...            ...                    ...
# 247  What So Not      Australia      Australia                   2010
# 248       Lane 8  United States        no data                no data
# 249    Habstrakt         France        no data             1990-03-28
# 250       Aexcit       Nürnberg        no data             2014-11-05
# 251     San Holo    Netherlands     Zoetermeer             1990-11-26
#
#     fin de actividad
# 0             activo
# 1             activo
# 2             activo
# 3             activo
# 4             activo
# ..               ...
# 247           activo
# 248           activo
# 249           activo
# 250           activo
# 251           activo
#
# [252 rows x 5 columns]

# %%
df_mb_2019.to_csv("artistas_2019_mb.csv", index=False)

# %%
artistas_2019_mb
# Out:
# {'artista': ['Sole',
#   'Neil Young',
#   'Emmit Fenn',
#   'Vicetone',
#   'Rampa',
#   'Borgeous',
#   'NOTION',
#   'Dzeko',
#   'Zwette',
#   'ARIA',
#   'deadmau5',
#   'Klingande',
#   'Sneaky Sound System',
#   'Matt Fax',
#   'Monolink',
#   'MK',
#   'Enamour',
#   'Mr. Belt & Wezol',
#   'Felon',
#   'MANT',
#   'Jefferson Airplane',
#   'W&W',
#   'Pegboard Nerds',
#   'Phil Fuldner',
#   'Pink Floyd',
#   'Boombox Cartel',
#   'Taiki Nulight',
#   'Feed Me',
#   'Gareth Emery',
#   'David Nathan',
#   'Chris Rea',
#   'Dr. Fresch',
#   'Syence',
#   '[no artist]',
#   'Seven Lions',
#   'The Beatles',
#   'Folamour',
#   'Louis Jordan',
#   'Sebjak',
#   'Alan Silvestri',
#   'Peggy Lee',
#   'Diplo',
#   'NTO',
#   'Drezo',
#   'Kaskade',
#   'Deorro',
#   'Cult Member',
#   'Koni',
#   'no data',
#   'Dom Dolla',
#   'Adventure Club',
#   'Purple Disco Machine',
#   'Danger Danger',
#   'Noizu',
#   'Lucas & Steve',
#   'i_o',
#   'Bali Bandits',
#   'ZHU',
#   'SAINt JHN',
#   'Malaa',
#   'Just a Gent',
#   'Ghastly',
#   'Besomorph',
#   'Duke Dumont',
#   'MOTi',
#   'Alesso',
#   'Benny Benassi',
#   'Mord Fustang',
#   'Gamper & Dadoni',
#   'Anderholm',
#   'R3HAB',
#   'Bob Dylan',
#   'Rootkit',
#   'Y.V.E. 48',
#   'Chaka Khan',
#   'Kid Vinil',
#   'Patrick Rothfuss',
#   'Armin van Buuren',
#   'James Brown',
#   'Leftwing : Kody',
#   'Roberto Surace',
#   'Anti‐Flag',
#   'FKJ',
#   'Dillon Nathaniel',
#   'Felix Mendelssohn',
#   'Mauvé',
#   'Moguai',
#   'DallasK',
#   'Example',
#   'Travis Scott',
#   'Basixx',
#   'Antoine Clamaran',
#   'Gadjo',
#   'Seb Wildblood',
#   'Gerry Mulligan',
#   'Major Lazer',
#   'SNBRN',
#   'Sonny Fodera',
#   'DubVision',
#   'Alok',
#   'NGHTMRE',
#   'Bro Safari',
#   '3LAU',
#   'LUM!X',
#   'Danny Elfman',
#   'KSHMR',
#   'Matoma',
#   'Benjamin Britten',
#   'Moksi',
#   'Ben Böhmer',
#   'Jerro',
#   'Paris Blohm',
#   'Solardo',
#   'Kaaze',
#   'Dean Martin',
#   'UK Subs',
#   'Garth Brooks',
#   'Oliver Heldens',
#   'Sonic Youth',
#   'Curbi',
#   'Ship Wrek',
#   'Avoure',
#   'Midsplit',
#   'Volac',
#   'Otha',
#   'Hardwell',
#   'Jonas Blue',
#   'M-22',
#   'Bloc Party',
#   'Jean Sibelius',
#   'Audien',
#   'Sam Cooke',
#   'Moon Boots',
#   'Tinlicker',
#   'Ilkay Sencan',
#   'Albert Calvo',
#   'Keinemusik',
#   'Yuksek',
#   'John Williams',
#   'Cephalic Carnage',
#   'NASAYA',
#   'Icarus',
#   'Rodg',
#   'Sam Feldt',
#   'Melosense',
#   'Ekali',
#   'Hogland',
#   'Tritonal',
#   'John Williams',
#   'JLV',
#   'ARTY',
#   'Becky Hill',
#   'Nat King Cole',
#   'Axwell',
#   'BUNT',
#   'RuPaul',
#   'James Brown',
#   'Madeon',
#   'V-Neck',
#   'India Fisher',
#   'Marnik',
#   'Kayzo',
#   'Mylo',
#   'Vandelux',
#   'Boney M.',
#   'Stromae',
#   'Anton Bruckner',
#   'Jitwam',
#   'LVNDSCAPE',
#   'Disco Lines',
#   'Gregory Esayan',
#   '4B',
#   'Tiësto',
#   'Matroda',
#   'Fred again..',
#   'Marshmello',
#   'Perry Como',
#   'Darkzy',
#   'Afrojack',
#   'Yann Tiersen',
#   'Nora Van Elken',
#   'Nora en Pure',
#   'REZZ',
#   'Marten Hørger',
#   'Hot Since 82',
#   'Ardalan',
#   'Grateful Dead',
#   'Dombresky',
#   'Aaron Copland',
#   'Riton',
#   'K‐391',
#   'Blood',
#   'Walker & Royce',
#   'Above & Beyond',
#   'Calvin Harris',
#   'SIDEPIECE',
#   'Kidnap',
#   'Sultan + Shepard',
#   'Martin Solveig',
#   'Kygo',
#   'Felix Jaehn',
#   'Azealia Banks',
#   'PAAX',
#   'Lost Frequencies',
#   'AC/DC',
#   'Boris Brejcha',
#   'Julian Calor',
#   'Galantis',
#   'Karen Rose',
#   'DJ S.K.T',
#   'Ehrling',
#   'Grum',
#   'Francis Poulenc',
#   'John de Sohn',
#   'Cupido',
#   'Fox Stevenson',
#   'Matisse & Sadko',
#   'Wax Motif',
#   'Yves Montand',
#   'Didier Armeni',
#   'Ian Van Dahl',
#   'Mat.Joe',
#   'KURA',
#   'DJ Goja',
#   'Martin Garrix',
#   'Jimmy Cliff',
#   'Party Favor',
#   'HUGEL',
#   'Chris Lake',
#   'Don Diablo',
#   'George Jones',
#   'Just Kiddin',
#   'Palm Trees',
#   'Jimmy Durante',
#   'Regard',
#   'Dimitri Vegas & Like Mike',
#   'Tujamo',
#   'Steve Aoki',
#   'Angelo Ferreri',
#   'Patti Page',
#   'Cut Off',
#   'Disco Fries',
#   'Conducta',
#   'Eddie Meduza',
#   'AMTRAC',
#   'Steff da Campo',
#   'Gorgon City',
#   'What So Not',
#   'Lane 8',
#   'Habstrakt',
#   'Aexcit',
#   'San Holo'],
#  'pais de origen': ['United States',
#   'Canada',
#   'United States',
#   'Groningen',
#   'no data',
#   'United States',
#   'Bristol',
#   'Canada',
#   'Germany',
#   'Chile',
#   'Canada',
#   'France',
#   'Australia',
#   'France',
#   'Germany',
#   'United States',
#   'United States',
#   'Netherlands',
#   'United Kingdom',
#   'no data',
#   'United States',
#   'Netherlands',
#   'Denmark',
#   'Germany',
#   'England',
#   'United States',
#   'United Kingdom',
#   'United Kingdom',
#   'United Kingdom',
#   'Germany',
#   'United Kingdom',
#   'United States',
#   'no data',
#   'no data',
#   'United States',
#   'United Kingdom',
#   'France',
#   'United States',
#   'no data',
#   'United States',
#   'United States',
#   'United States',
#   'France',
#   'California',
#   'United States',
#   'Los Angeles',
#   'Québec City',
#   'Germany',
#   'no data',
#   'Australia',
#   'Canada',
#   'Germany',
#   'United States',
#   'Los Angeles',
#   'no data',
#   'United States',
#   'no data',
#   'United States',
#   'Guyana',
#   'France',
#   'Australia',
#   'Finland',
#   'United States',
#   'United Kingdom',
#   'Netherlands',
#   'Sweden',
#   'Italy',
#   'Estonia',
#   'Germany',
#   'Lutsk',
#   'Netherlands',
#   'United States',
#   'Norway',
#   'Germany',
#   'United States',
#   'Brazil',
#   'United States',
#   'Netherlands',
#   'United States',
#   'London',
#   'no data',
#   'United States',
#   'France',
#   'Los Angeles',
#   'Germany',
#   'Germany',
#   'Berlin',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'no data',
#   'France',
#   'Germany',
#   'United Kingdom',
#   'United States',
#   'Jamaica',
#   'Los Angeles',
#   'Australia',
#   'Netherlands',
#   'Brazil',
#   'United States',
#   'United States',
#   'United States',
#   'Austria',
#   'United States',
#   'United States',
#   'Norway',
#   'United Kingdom',
#   'Netherlands',
#   'Berlin',
#   'Belgium',
#   'Los Angeles',
#   'United Kingdom',
#   'Sweden',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'Netherlands',
#   'United States',
#   'Halstead',
#   'Los Angeles',
#   'Ukraine',
#   'Montréal',
#   'no data',
#   'Oslo',
#   'Netherlands',
#   'United Kingdom',
#   'no data',
#   'United Kingdom',
#   'Finland',
#   'United States',
#   'United States',
#   'United States',
#   'Netherlands',
#   'Istanbul',
#   'no data',
#   'Berlin',
#   'France',
#   'United States',
#   'Edgewater',
#   'no data',
#   'United Kingdom',
#   'Amsterdam',
#   'Netherlands',
#   'Greece',
#   'Vancouver',
#   'no data',
#   'United States',
#   'United States',
#   'Utrecht',
#   'Russia',
#   'United Kingdom',
#   'United States',
#   'Sweden',
#   'Germany',
#   'United States',
#   'United States',
#   'France',
#   'United Kingdom',
#   'United Kingdom',
#   'Italy',
#   'Los Angeles',
#   'United Kingdom',
#   'no data',
#   'Bonn',
#   'Belgium',
#   'Austria',
#   'Independence',
#   'Netherlands',
#   'no data',
#   'Saratov',
#   'New Jersey',
#   'Netherlands',
#   'no data',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'Nottingham',
#   'Netherlands',
#   'France',
#   'no data',
#   'Switzerland',
#   'Canada',
#   'Germany',
#   'United Kingdom',
#   'San Francisco',
#   'United States',
#   'France',
#   'United States',
#   'United Kingdom',
#   'Norway',
#   'Germany',
#   'no data',
#   'United Kingdom',
#   'Scotland',
#   'no data',
#   'United Kingdom',
#   'Canada',
#   'France',
#   'Norway',
#   'Germany',
#   'United States',
#   'Mexico',
#   'Belgium',
#   'Australia',
#   'Germany',
#   'Wageningen',
#   'Sweden',
#   'United States',
#   'United Kingdom',
#   'Stockholm',
#   'United Kingdom',
#   'France',
#   'Sweden',
#   'Spain',
#   'United Kingdom',
#   'Russia',
#   'United States',
#   'France',
#   'no data',
#   'Belgium',
#   'Germany',
#   'Portugal',
#   'București',
#   'Netherlands',
#   'Jamaica',
#   'Los Angeles',
#   'France',
#   'United Kingdom',
#   'Netherlands',
#   'United States',
#   'United Kingdom',
#   'Netherlands',
#   'United States',
#   'New York',
#   'Belgium',
#   'Germany',
#   'United States',
#   'Italy',
#   'United States',
#   'no data',
#   'United States',
#   'United Kingdom',
#   'Sweden',
#   'United States',
#   'no data',
#   'United Kingdom',
#   'Australia',
#   'United States',
#   'France',
#   'Nürnberg',
#   'Netherlands'],
#  'area de origen': ['Portland',
#   'Toronto',
#   'Berkeley',
#   'Groningen',
#   'no data',
#   'Miami',
#   'no data',
#   'Toronto',
#   'no data',
#   'Chile',
#   'Niagara Falls',
#   'Croix',
#   'no data',
#   'no data',
#   'no data',
#   'Detroit',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'San Francisco',
#   'Mexico',
#   'no data',
#   'Marl',
#   'London',
#   'Monterrey',
#   'no data',
#   'Hertfordshire',
#   'Southampton',
#   'Berlin',
#   'Middlesbrough',
#   'no data',
#   'no data',
#   'no data',
#   'Santa Barbara',
#   'Liverpool',
#   'Lyon',
#   'Brinkley',
#   'no data',
#   'New York',
#   'Jamestown',
#   'Tupelo',
#   'Marseille',
#   'no data',
#   'Chicago',
#   'Ciudad de México',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'Montréal',
#   'Dresden',
#   'Queens',
#   'no data',
#   'Maastricht',
#   'Richmond',
#   'no data',
#   'San Francisco',
#   'Brooklyn',
#   'Paris',
#   'no data',
#   'Tampere',
#   'Germany',
#   'Harrow',
#   'no data',
#   'Stockholm',
#   'Reggio Emilia',
#   'Tallinn',
#   'Hamburg',
#   'no data',
#   'Breda',
#   'Duluth',
#   'no data',
#   'no data',
#   'Chicago',
#   'Cedral',
#   'Madison',
#   'Leiden',
#   'Barnwell',
#   'no data',
#   'no data',
#   'Pittsburgh',
#   'Tours',
#   'no data',
#   'Hamburg',
#   'no data',
#   'Marl',
#   'United States',
#   'no data',
#   'Houston',
#   'no data',
#   'Neuilly-sur-Seine',
#   'no data',
#   'no data',
#   'Queens',
#   'Los Angeles',
#   'no data',
#   'no data',
#   'Netherlands',
#   'Goiânia',
#   'no data',
#   'Roma',
#   'no data',
#   'Rohrbach in Oberösterreich',
#   'Los Angeles',
#   'Berkeley',
#   'Åsnes',
#   'Lowestoft',
#   'no data',
#   'Göttingen',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'Steubenville',
#   'London',
#   'Tulsa',
#   'Rotterdam',
#   'New York',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'Breda',
#   'London',
#   'no data',
#   'Reading',
#   'Hämeenlinna',
#   'New London',
#   'Clarksdale',
#   'Prospect Heights',
#   'Utrecht',
#   'Istanbul',
#   'no data',
#   'no data',
#   'Reims',
#   'Flushing',
#   'Denver',
#   'Réunion',
#   'no data',
#   'no data',
#   'Amsterdam',
#   'no data',
#   'Vancouver',
#   'no data',
#   'Austin',
#   'Flushing',
#   'no data',
#   'Engels',
#   'Bewdley',
#   'Montgomery',
#   'Lund',
#   'no data',
#   'San Diego',
#   'Barnwell',
#   'Nantes',
#   'no data',
#   'Stoke-on-Trent',
#   'Milano',
#   'no data',
#   'Broadford',
#   'no data',
#   'no data',
#   'Etterbeek',
#   'Ansfelden',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'Breda',
#   'no data',
#   'United Kingdom',
#   'Philadelphia',
#   'Canonsburg',
#   'no data',
#   'Spijkenisse',
#   'Brest',
#   'no data',
#   'Johannesburg',
#   'Ukraine',
#   'no data',
#   'no data',
#   'Tehran',
#   'Palo Alto',
#   'no data',
#   'Brooklyn',
#   'Newcastle upon Tyne',
#   'Bamble',
#   'Speyer',
#   'no data',
#   'United Kingdom',
#   'Dumfries',
#   'no data',
#   'no data',
#   'Montréal',
#   'Paris',
#   'Singapore',
#   'Hamburg',
#   'Harlem',
#   'Tulum',
#   'Brussels',
#   'Sydney',
#   'Ludwigshafen',
#   'no data',
#   'Stockholm',
#   'no data',
#   'no data',
#   'no data',
#   'Glasgow',
#   'Paris',
#   'Ystad',
#   'no data',
#   'Leeds',
#   'no data',
#   'Australia',
#   'Monsummano Terme',
#   'no data',
#   'no data',
#   'no data',
#   'Leiria',
#   'no data',
#   'Amstelveen',
#   'Adelphi',
#   'no data',
#   'France',
#   'Aberdeen',
#   'Coevorden',
#   'Saratoga',
#   'Leicester',
#   'no data',
#   'Manhattan',
#   'no data',
#   'Willebroek',
#   'Germany',
#   'Miami',
#   'Modica',
#   'Claremore',
#   'no data',
#   'no data',
#   'no data',
#   'Gothenburg',
#   'Morehead',
#   'no data',
#   'no data',
#   'Australia',
#   'no data',
#   'no data',
#   'no data',
#   'Zoetermeer'],
#  'fecha inicio actividad': ['1977-09-25',
#   '1945-11-12',
#   'no data',
#   '2012',
#   'no data',
#   'no data',
#   'no data',
#   '1992-05-03',
#   'no data',
#   '2010',
#   '1981-01-05',
#   '2012-12',
#   '2001',
#   'no data',
#   '1989',
#   '1972-08-03',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   '1965',
#   '2007',
#   '2012',
#   '1973-08-02',
#   '1965',
#   '2012',
#   'no data',
#   '1984-08-22',
#   '1980-07-18',
#   '1971-03-16',
#   '1951-03-04',
#   'no data',
#   'no data',
#   'no data',
#   '1987-03-31',
#   '1960',
#   'no data',
#   '1908-07-08',
#   'no data',
#   '1950-03-26',
#   '1920-05-26',
#   '1978-11-10',
#   '1985',
#   'no data',
#   '1971-02-25',
#   '1991-08-30',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   '2011',
#   '1980-02-12',
#   '1987',
#   'no data',
#   '2010',
#   '1990-05-16',
#   'no data',
#   '1989-04-28',
#   '1986-08-26',
#   'no data',
#   'no data',
#   '2011',
#   '1997',
#   '1982-08-27',
#   'no data',
#   '1991-07-07',
#   '1967-07-13',
#   '1991-02-21',
#   'no data',
#   'no data',
#   '1986-04-02',
#   '1941-05-24',
#   '1997-09-17',
#   'no data',
#   '1953-03-23',
#   '1955-03-10',
#   '1973-06-06',
#   '1976-12-25',
#   '1933-05-03',
#   'no data',
#   'no data',
#   '1988',
#   '1991-03-27',
#   'no data',
#   '1809-02-03',
#   'no data',
#   '1973-08-09',
#   '1993',
#   '1982-06-20',
#   '1991-04-30',
#   'no data',
#   '1964-11-08',
#   'no data',
#   'no data',
#   '1927-04-06',
#   '2008',
#   'no data',
#   'no data',
#   '1995',
#   '1991-08-26',
#   '1990-10-11',
#   '1979-04-06',
#   '1991-01-09',
#   '2002-07-23',
#   '1953-05-29',
#   '1988-10-06',
#   '1991-05-29',
#   '1913-11-22',
#   '2015',
#   '1994',
#   'no data',
#   'no data',
#   'no data',
#   '1989-01-30',
#   '1917-06-07',
#   '1977',
#   '1962-02-07',
#   '1995-02-01',
#   '1981',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   'no data',
#   '1988-01-07',
#   '1989-08-02',
#   'no data',
#   '1999-08',
#   '1865-12-08',
#   '1992-01-11',
#   '1931-01-22',
#   '1984-06-27',
#   '2012',
#   'no data',
#   'no data',
#   'no data',
#   '1977-06-03',
#   '1932-02-08',
#   '1992',
#   'no data',
#   '1997',
#   'no data',
#   '1993-08-01',
#   'no data',
#   '1991-09-22',
#   'no data',
#   '2007',
#   '1932-02-08',
#   'no data',
#   '1989-09-28',
#   '1994-02-14',
#   '1919-03-17',
#   '1977-12-18',
#   'no data',
#   '1960-11-17',
#   '1933-05-03',
#   '1994-05-30',
#   'no data',
#   '1974-09-10',
#   'no data',
#   '1991-08-08',
#   '1978-05-10',
#   'no data',
#   '1975',
#   '1985-03-12',
#   '1824-09-04',
#   'no data',
#   'no data',
#   'no data',
#   '1989-05-31',
#   '1992',
#   '1969-01-17',
#   'no data',
#   '1994',
#   '1992-05-19',
#   '1912-05-18',
#   'no data',
#   '1987-09-09',
#   '1970-06-23',
#   'no data',
#   '1990-07-20',
#   '1995-03-28',
#   'no data',
#   'no data',
#   'no data',
#   '1965',
#   'no data',
#   '1900-11-14',
#   '1978-09',
#   '1994-11-02',
#   '1986-03',
#   'no data',
#   '2000',
#   '1984-01-17',
#   'no data',
#   'no data',
#   'no data',
#   '1976-09-22',
#   '1991-09-11',
#   '1994-08-28',
#   '1991-05-31',
#   'no data',
#   '1993-11-30',
#   '1973-11',
#   '1981-11-26',
#   'no data',
#   '2012-03-01',
#   'no data',
#   'no data',
#   'no data',
#   '1986-05-02',
#   '1899-01-07',
#   '1984-10-13',
#   'no data',
#   '1993-01-25',
#   'no data',
#   '1984-11-20',
#   '1921-10-13',
#   'no data',
#   '2000',
#   'no data',
#   '1987-08-21',
#   'no data',
#   '1996-05-15',
#   '1944-07-30',
#   'no data',
#   '1987-12-04',
#   '1982-08-08',
#   '1980-02-27',
#   '1931-09-12',
#   'no data',
#   'no data',
#   '1893-02-10',
#   '1993',
#   '2007',
#   'no data',
#   '1977-11-30',
#   '1984',
#   '1927-11-08',
#   'no data',
#   '2011',
#   'no data',
#   '1948-06-17',
#   '1987-05-19',
#   'no data',
#   '2012',
#   '2010',
#   'no data',
#   '1990-03-28',
#   '2014-11-05',
#   '1990-11-26'],
#  'fin de actividad': ['activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'no data',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo']}

# %% [markdown]
# # ARTISTAS HOUSE 2020

# %%
set_artistas_2020= set(dict_tracks_house_2020['artistas'])  # Convertir el valor asociado a la clave 'artistas' en un set para limpiar los artistas repetidos
print(set_artistas_2020)
# Out:
# {'Sole Sole', 'Danko', 'Sander van Doorn', 'Emmit Fenn', 'Ummet Ozcan', 'Obskür', 'Chocolate Puma', 'HNNY', 'deadmau5', 'JOYRYDE', 'Imanbek', 'Moon Rocket', 'Sebastian Ingrosso', 'THYPONYX', 'Mr. Belt & Wezol', 'Hi_Tack', 'Helsloot', 'W&W', 'Low Steppa', 'CamelPhat', 'Taiki Nulight', 'Dustycloud', 'Justin Jay', 'Nightcrawlers', 'Krewella', 'Nico de Andrea', 'Cloonee', 'Gareth Emery', 'Nathan Micay', 'Dr. Fresch', 'Ross Quinn', 'WHOCARES', 'Tep No', 'Seven Lions', 'Sound Quelle', 'Kurd Maverick', 'Godford', 'Sunlike Brothers', 'IC3PEAK', 'Kartell', 'Arc North', 'PAX', 'Alan Walker', 'Diplo', 'Kaskade', 'Deorro', 'Purple Disco Machine', 'Master KG', 'Deep Chills', 'Lemtom', 'Noizu', 'Biscits', 'Lucas & Steve', 'HI-LO', 'i_o', 'Nitefreak', 'Klaus Veen', 'David Penn', 'Deepend', 'ZHU', 'SAINt JHN', 'Anoraak', 'Just A Gent', 'Duke Dumont', 'Besomorph', 'Saco', 'gum.mp3', 'Alesso', 'Braaten', 'Soulwax', 'GAMPER & DADONI', 'Ooyy', 'LTN', 'Forester', 'Spencer Brown', 'Gostan', 'R3HAB', 'Bob Moses', 'Rootkit', 'Porter Robinson', 'Y.V.E. 48', 'Mative', 'Chaël', 'Ahmed Spins', 'spüke', 'James Hype', 'Anthony Keyrouz', 'Alex Cruz', 'Klangkarussell', 'Mauve', 'MOGUAI', 'MELON', 'Travis Scott', 'Kisch', 'Furkan Sert', 'Major Lazer', 'Daniel Glaven', 'Sonny Fodera', 'Cash Cash', 'Alok', 'NGHTMRE', 'Orjan Nilsen', 'LUM!X', 'Marsh', 'KSHMR', 'Marc Benjamin', 'Matoma', 'Ilkan Gunuc', 'Moksi', 'Ben Böhmer', 'Rezident', 'EMBRZ', 'Jerro', 'Fabich', 'KAAZE', 'Thomas Newson', 'Sosa UK', 'LANNÉ', 'Tungevaag', 'Le Youth', 'Madism', 'hentai boys', 'Curbi', 'Chaos In The CBD', 'The Underdog Project', 'Lulleaux', 'Mat Zo', 'Robin Schulz', 'Keys N Krates', 'Prospa', 'Jean Tonique', 'Miami Horror', 'Tinlicker', 'Deeper Purpose', 'Leaving Laurel', 'NITTI', 'Shoby', 'VIZE', 'ATFC', 'INNA', 'MATVEÏ', 'Dario G', 'KC Lights', 'Mike Williams', 'Sam Feldt', 'Melosense', 'Ekali', 'Innocent Panda', 'Sammy Virji', 'John Summit', 'Offmind', 'JLV', 'Paratone', 'Angara', 'Becky Hill', 'Nils Hoffmann', 'BUNT.', 'Yaeji', 'Borgore', 'ARTY', 'Madeon', 'FISHER', 'Marnik', 'Kayzo', 'Kevin McKay', 'Zonderling', 'Joris Voorn', 'Disco Lines', 'Tiësto', 'Matroda', 'Fred again..', 'Marshmello', 'Mike Perry', 'Pool Blue', 'Jason Ross', 'Nox Vahn', 'HVME', 'Nora Van Elken', 'Nora En Pure', 'Dale Howard', 'Rezz', 'HUTS', 'Dimitri Vangelis & Wyman', 'Marten Hørger', 'Disclosure', 'iwilldiehere', 'Zeds Dead', 'Tchami', 'TCTS', 'Paul Woolford', 'Quintino', 'K-391', 'SIDEPIECE', 'Soda', 'Calvin Harris', 'Above & Beyond', 'Louie Vega', 'Coffee Cub', 'Bakermat', 'Kidnap', 'Rosbeh', 'Chris Stussy', 'Sultan + Shepard', 'HAYASA G', 'Kygo', 'Breakbot', 'OTR', 'Lost Frequencies', 'Alan Fitzpatrick', 'Boris Brejcha', 'Falden', 'Bassboy', 'Galantis', 'Chico Rose', 'Chris Avantgarde', 'Claude VonStroke', 'Dillon Francis', 'Jerome Isma-Ae', 'Fox Stevenson', 'Henry Fong', 'Wax Motif', 'VINAI', 'Yves V', 'Polar Inc.', 'DJ Goja', 'Martin Garrix', 'Party Favor', 'DM 90', 'HUGEL', 'Dj Streaks', 'Parra for Cuva', 'Yolanda Be Cool', 'Chris Lake', 'Michael Calfan', 'Disko Junkie', 'Don Diablo', 'Jax Jones', 'Massane', 'Bingo Players', 'Regard', 'EDX', 'Dimitri Vegas & Like Mike', 'Steve Aoki', 'Fukkk Offf', 'Technotronic', 'Morgan Page', 'Endor', 'MEDUZA', 'SALEM', 'Adriatique', 'The Magician', 'BAD NINJA', 'Agoria', 'DVBBS', 'Lane 8', 'Robbie Rivera', 'Habstrakt', 'A-Trak', 'Aexcit'}

# %%
lista_artistas_2020 = list(set_artistas_2020) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_2020)
# Out:
# 259

# %%
#Aqui tenemos la búsqueda de un artista. Trabajando con la librería. 
artistas_2020_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_2020:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_2020_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_2020_mb["artista"].append("no data")
    try:
        artistas_2020_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_2020_mb["pais de origen"].append("no data")
    try:
        artistas_2020_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_2020_mb["area de origen"].append("no data") 
    try:
        artistas_2020_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"])
    except:
        artistas_2020_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_2020_mb["fin de actividad"].append("no activo")
        else:
            artistas_2020_mb["fin de actividad"].append("activo")
    except:
        artistas_2020_mb["fin de actividad"].append("no data")

# %%
df_mb_2020 = pd.DataFrame(artistas_2020_mb)

df_mb_2020
# Out:
#               artista pais de origen area de origen fecha inicio actividad  \
# 0                Sole  United States       Portland             1977-09-25
# 1         Danko Jones         Canada        Toronto                   1996
# 2    Sander van Doorn    Netherlands      Eindhoven             1979-02-28
# 3          Emmit Fenn  United States       Berkeley                no data
# 4         Ummet Ozcan    Netherlands        no data             1982-08-16
# ..                ...            ...            ...                    ...
# 254            Lane 8  United States        no data                no data
# 255     Robbie Rivera  United States       San Juan             1973-08-07
# 256         Habstrakt         France        no data             1990-03-28
# 257            A‐Trak         Canada       Montréal             1982-03-30
# 258            Aexcit       Nürnberg        no data             2014-11-05
#
#     fin de actividad
# 0             activo
# 1             activo
# 2             activo
# 3             activo
# 4             activo
# ..               ...
# 254           activo
# 255           activo
# 256           activo
# 257           activo
# 258           activo
#
# [259 rows x 5 columns]

# %%
df_mb_2020.to_csv("artistas_2020_mb.csv", index=False)

# %% [markdown]
# # LASTFM

# %%
Application_name = "proyecto_mod_2_LastFM"

api_key = "81d4d7d064912663a92c1e782d1e5c1f"

shared_secred = "7cd255e7d812c3054becf00fe8dc78cd"

Registered_to = "Kaleeshy6162"

# %%
url = "http://ws.audioscrobbler.com/2.0"

params_info = {
        'method': 'artist.getinfo',
        'artist': "Marshmello",
        'api_key': api_key,
        'format': 'json'
    }

# %%
respuesta = requests.get(url, params = params_info)

# %%
artista = respuesta.json()

artista
# Out:
# {'artist': {'name': 'Marshmello',
#   'url': 'https://www.last.fm/music/Marshmello',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': ''}],
#   'streamable': '0',
#   'ontour': '0',
#   'stats': {'listeners': '2009412', 'playcount': '51219793'},
#   'similar': {'artist': [{'name': 'The Chainsmokers',
#      'url': 'https://www.last.fm/music/The+Chainsmokers',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'Martin Garrix',
#      'url': 'https://www.last.fm/music/Martin+Garrix',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'Alan Walker',
#      'url': 'https://www.last.fm/music/Alan+Walker',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'Jonas Blue',
#      'url': 'https://www.last.fm/music/Jonas+Blue',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]},
#     {'name': 'DJ Snake',
#      'url': 'https://www.last.fm/music/DJ+Snake',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': ''}]}]},
#   'tags': {'tag': [{'name': 'electronic',
#      'url': 'https://www.last.fm/tag/electronic'},
#     {'name': 'dance', 'url': 'https://www.last.fm/tag/dance'},
#     {'name': 'trap', 'url': 'https://www.last.fm/tag/trap'},
#     {'name': 'EDM', 'url': 'https://www.last.fm/tag/EDM'},
#     {'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}]},
#   'bio': {'links': {'link': {'#text': '',
#      'rel': 'original',
#      'href': 'https://last.fm/music/Marshmello/+wiki'}},
#    'published': '11 Jul 2016, 18:11',
#    'summary': '(1) Chris Comstock, better known by his stage name Marshmello, was born on May 19, 1992. He is an American electronic dance music producer and DJ. He first gained international recognition by remixing songs by Jack Ü and Zedd, and later collaborated with artists including Omar LinX, Ookay, Jauz and Slushii. In January 2017, his song "Alone" appeared on the U.S. Billboard Hot 100 chart.\nIn 2018, he released "Friends", a collaboration with British singer Anne-Marie which peaked in the top 20 in the US. <a href="https://www.last.fm/music/Marshmello">Read more on Last.fm</a>',
#    'content': '(1) Chris Comstock, better known by his stage name Marshmello, was born on May 19, 1992. He is an American electronic dance music producer and DJ. He first gained international recognition by remixing songs by Jack Ü and Zedd, and later collaborated with artists including Omar LinX, Ookay, Jauz and Slushii. In January 2017, his song "Alone" appeared on the U.S. Billboard Hot 100 chart.\nIn 2018, he released "Friends", a collaboration with British singer Anne-Marie which peaked in the top 20 in the US. Months later, his second studio album, Joytime II, was released with singles "Tell Me" and "Check This Out". "Happier", a collaboration with British band Bastille, was released in August and became his highest-charting song on the Billboard Hot 100 at #2. In 2019, he earned $40 million, ranking second on the list of highest paid DJs compiled by Forbes. In 2020, he and American rapper Juice Wrld released "Come & Go", from the latter\'s posthumous album Legends Never Die; the song reached number two on the Billboard Hot 100, matching "Happier" as his highest-charting song. In 2021, his album Shockwave earned him a Grammy nomination.\n\nMarshmello wears a custom helmet for public appearances. His identity was unknown, but was confirmed to be Chris Comstock in late 2017 by Forbes.\n\nMarshmello\'s stage name, an alternative spelling of "marshmallow", and his marshmallow mascot head were both inspired by Canadian electro house music producer and DJ deadmau5, who also notably uses an alternate spelling for his stage name and performs wearing a "dead mouse" mascot head.\n\n(2) Marshmello (Blackbird) is an alias of Marsha Smith (London, UK). She is DJ, radio host, music consultant, supervisor, mentor, networking and creative developer, also notable for vocals on tracks by The Funky Lowlives or Basement Jaxx. <a href="https://www.last.fm/music/Marshmello">Read more on Last.fm</a>. User-contributed text is available under the Creative Commons By-SA License; additional terms may apply.'}}}

# %% [markdown]
# # ARTISTAS HOUSE 2019

# %%
dic_artistas_2019_LFM = {"Artista":[], "Biografia":[], "Listeners":[], "Playcount":[], "Artistas Similares":[]}
for a in lista_artistas_2019 [:5]:
    params_info = {
        'method': 'artist.getinfo',
        'artist': a,
        'api_key': api_key,
        'format': 'json'
        }
    url = f"http://ws.audioscrobbler.com/2.0/"
    respuesta = requests.get(url, params=params_info)
    artista = respuesta.json()
    try:
        dic_artistas_2019_LFM['Artista'].append(artista["artist"]["name"])
    except:
        dic_artistas_2019_LFM["Artista"].append(None)
    try:
        dic_artistas_2019_LFM["Biografia"].append(artista["artist"]["bio"]["summary"])
    except:
        dic_artistas_2019_LFM["Biografia"].append(None)
    try:
        dic_artistas_2019_LFM["Listeners"].append(artista["artist"]["stats"]["listeners"])
    except:
        dic_artistas_2019_LFM["Listeners"].append(None)
    try:
        dic_artistas_2019_LFM["Playcount"].append(artista["artist"]["stats"]["playcount"])
    except:
        dic_artistas_2019_LFM["Playcount"].append(None)
    try:
        dic_artistas_2019_LFM["Artistas Similares"].append(artista["artist"]["similar"]["artist"][0]["name"])
    except:
        dic_artistas_2019_LFM["Artistas Similares"].append(None)

# %%
df_lfm_2019 = pd.DataFrame(dic_artistas_2019_LFM)

df_lfm_2019
# Out:
#          Artista                                          Biografia Listeners  \
# 0      Sole Sole   <a href="https://www.last.fm/music/Sole+Sole"...     39039
# 1  Chester Young   <a href="https://www.last.fm/music/Chester+Yo...     37789
# 2     Emmit Fenn  Raised in Berkeley, California, Emmit Fenn is ...    382721
# 3       Vicetone  Vicetone is a Dutch DJ and production duo form...    497544
# 4          Rampa  From 2009 on, Rampa made a name of himself thr...    110684
#
#   Playcount Artistas Similares
# 0    244388   Tomas Skyldeberg
# 1    284303            grimmmz
# 2   3981807         Elderbrook
# 3   8347454     Axel Johansson
# 4    779315                &ME

# %%
df_lfm_2019.to_csv("dic_artistas_2019_LFM.csv", index=False)

# %% [markdown]
# # ARTISTAS HOUSE 2020

# %%
dic_artistas_2020_LFM = {"Artista":[], "Biografia":[], "Listeners":[], "Playcount":[], "Artistas Similares":[]}
for a in lista_artistas_2020 [:5]:
    params_info = {
        'method': 'artist.getinfo',
        'artist': a,
        'api_key': api_key,
        'format': 'json'
        }
    url = f"http://ws.audioscrobbler.com/2.0/"
    respuesta = requests.get(url, params=params_info)
    artista = respuesta.json()
    try:
        dic_artistas_2020_LFM['Artista'].append(artista["artist"]["name"])
    except:
        dic_artistas_2020_LFM["Artista"].append(None)
    try:
        dic_artistas_2020_LFM["Biografia"].append(artista["artist"]["bio"]["summary"])
    except:
        dic_artistas_2020_LFM["Biografia"].append(None)
    try:
        dic_artistas_2020_LFM["Listeners"].append(artista["artist"]["stats"]["listeners"])
    except:
        dic_artistas_2020_LFM["Listeners"].append(None)
    try:
        dic_artistas_2020_LFM["Playcount"].append(artista["artist"]["stats"]["playcount"])
    except:
        dic_artistas_2020_LFM["Playcount"].append(None)
    try:
        dic_artistas_2020_LFM["Artistas Similares"].append(artista["artist"]["similar"]["artist"][0]["name"])
    except:
        dic_artistas_2020_LFM["Artistas Similares"].append(None)

# %%
df_lfm_2020 = pd.DataFrame(dic_artistas_2020_LFM)

df_lfm_2020
# Out:
#             Artista                                          Biografia  \
# 0         Sole Sole   <a href="https://www.last.fm/music/Sole+Sole"...
# 1             Danko  There are at least four artists performing und...
# 2  Sander Van Doorn  Thought to be a technical and musical genius b...
# 3        Emmit Fenn  Raised in Berkeley, California, Emmit Fenn is ...
# 4       Ummet Ozcan  Ummet Ozcan iUmmet Ozcan, originally from Turk...
#
#   Listeners Playcount Artistas Similares
# 0     39039    244388   Tomas Skyldeberg
# 1     39931    244421       Madison Mars
# 2    410891   3743845               None
# 3    382721   3981807         Elderbrook
# 4    228663   2175041               NWYR

# %%
df_lfm_2020.to_csv("dic_artistas_2020_LFM.csv", index=False)
