# %%
#%pip install spotipy

# %%
import requests
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = "9ba747b4cd1a426c826e14373c7648a1"
api_key = "4c67909da02740418998f8277a500767"

auth_manager = SpotifyClientCredentials( client_id, api_key)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
canciones = sp.search(q="genre:pop year:2019", type="track", limit=50, offset=0)

# %%
canciones.keys()
# Out:
# dict_keys(['tracks'])

# %%
canciones["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
canciones["tracks"]["items"][0]["album"]["release_date"]
# Out:
# '2019-08-23'

# %%
canciones["tracks"]["items"][0]["artists"][0]["name"]
canciones["tracks"]["items"][0]["artists"][0]["name"]
# Out:
# 'Taylor Swift'

# %% [markdown]
# ## CANCIONES POP 2019

# %%
#LISTA DE CANCIONES POP 2019
dict_tracks_pop_2019 ={"canciones":[], "artistas": [], "género": "Pop", "tipo": "track", "año lanzamiento": []}
for offset in range(0,500,50):
    canciones_2019 = sp.search(q="genre:pop year:2019", type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_pop_2019["canciones"].append(canciones_2019["tracks"]["items"][i]["name"])
        

print(dict_tracks_pop_2019)    
len(dict_tracks_pop_2019)
# Out:
# {'canciones': ['Cruel Summer', 'Jealous', 'Circles', 'Cry', 'Sunflower - Spider-Man: Into the Spider-Verse', 'Would That I', 'Lover', 'Someone You Loved', "when the party's over", 'Bags', 'Mrs Magic', 'Dreams, Fairytales, Fantasies (feat. Brent Faiyaz & Salaam Remi)', 'YKWIM?', 'Kingston', 'Almost (Sweet Music)', 'Streets', 'Cinnamon Girl', 'The Man', 'everything i wanted', 'Sofia', 'Wow.', 'bad guy', 'Watermelon Sugar', 'i love you', '7 rings', 'One Thing Right', 'Before You Go', 'You Need To Calm Down', 'Trust Issues', 'Looking at Me', 'Heavenly', 'Right Side of My Neck', 'Adore You', 'you should see me in a crown', 'Take What You Want (feat. Ozzy Osbourne & Travis Scott)', 'There Was This Girl', "Where's My Love", "Doin' Time", 'Bruises', 'Shameless', 'Miss Americana & The Heartbreak Prince', 'Fine Line', "Don't Give Up On Me", 'Money In The Grave (Drake ft. Rick Ross)', 'Falling', 'ONE BEER (feat. Lauren Alaina & Devin Dawson)', 'Mount Everest', 'thank u, next', 'Paper Rings', 'Goodbyes (feat. Young Thug)', 'False Confidence', "Ballin' (with Roddy Ricch)", 'Sucker', 'What Would I Do?', 'Intermission', 'Mess', 'Please Me', 'Under The Sun (with J. Cole & Lute feat. DaBaby)', 'Apple Cider', 'Pure Water (with Migos)', 'Spooky, Scary Skeletons - Undead Tombstone Remix', 'Alaska', 'Ride It', "Hollywood's Bleeding", 'bury a friend', 'Hey Lover!', 'listen before i go', 'Formula', 'I Wish Grandpas Never Died', 'All I Want - From "High School Musical: The Musical: The Series"', 'What A Time (feat. Niall Horan)', 'OUT WEST (feat. Young Thug)', 'Truth Hurts', 'Be Alright', 'Nights Like This (feat. Ty Dolla $ign)', 'The Archer', 'Pluto Projector', 'Norman fucking Rockwell', 'boyfriend (with Social House)', "Teacher's Pet", 'Tia Tamera (feat. Rico Nasty)', 'Happiness is a butterfly', 'The Search', 'How to disappear', 'bad idea!', 'BOP', 'wish you were gay', 'Señorita', 'False God', 'Paradise', "break up with your girlfriend, i'm bored", 'Welcome to the Show', 'Metamodernity', 'Hold Me While You Wait', 'all the good girls go to hell', 'All Of The Girls You Loved Before', 'ilomilo', 'Simple', 'ME! (feat. Brendon Urie of Panic! At The Disco)', 'Taste (feat. Offset)', 'Juliet', 'Season Of The Witch', 'Daylight', 'Young Blood', 'Say So', 'ROXANNE', 'Falling In Love', 'Light On', 'Despacito', 'John Redcorn', 'Cradles', 'Afterglow', "I Don't Care (with Justin Bieber)", 'Someone To You', 'Me Rehúso', 'bloodline', 'Good as Hell', 'He Went To Jared (HARDY feat. Morgan Wallen)', 'Hurt Somebody', 'El Efecto', 'All For Us', 'Cornelia Street', 'Death By A Thousand Cuts', 'Here With Me', 'When I Grow Up', 'Stars Will Fall', 'Jonny', 'Talk (feat. Disclosure)', 'My Oh My (feat. DaBaby)', 'Love You For A Long Time', 'Movement', 'affection', 'Touch', 'Chateau (Feel Alright)', 'Rules', 'Golden', 'I Think He Knows', "I Think I'm OKAY (with YUNGBLUD & Travis Barker)", 'Turn You Down (HARDY feat. Morgan Wallen, Zakk Wylde)', 'Good Godly Woman', 'Kill This Love', "Still Don't Know My Name", 'Suge', 'Softly', 'Adicto (with Anuel AA & Ozuna)', "Car's Outside", 'London Boy', 'Half A Man', 'Like That (feat. Gucci Mane)', 'RNP (feat. Anderson .Paak)', 'Vas', 'light', 'Sleep Thru Ur Alarms', 'Dance Monkey', 'Boys Will Be Bugs', 'Ghost', 'If the World Was Ending (feat. Julia Michaels)', 'Time', 'Cherry', 'Strip That Down (feat. Quavo)', 'xanny', 'i met sarah in the bathroom', "Let's Fall in Love for the Night", 'Forever', 'On My Way to You', 'Die For Me (feat. Future & Halsey)', 'Oncle Jazz', 'no way !', 'Nothing Breaks Like a Heart (feat. Miley Cyrus)', 'needy', 'Homicide (feat. Eminem)', 'Andromeda', 'TOES (feat. Lil Baby & Moneybagg Yo)', 'Higher Love', 'Hate Myself', 'Talk', 'Hate Me (with Juice WRLD)', 'Lalala', 'prom dress', 'Hurts Me Too', 'GATTI', 'High School Sweethearts', 'Only Human', 'Señorita', 'Mariners Apartment Complex', 'Honeybee', "Don't Start Now", 'Shrike', 'South of the Border (feat. Camila Cabello & Cardi B)', 'Gloria', 'Arcade', 'Dove - Doll Ve ...
# 5

# %% [markdown]
# ### ARTISTAS POP 2019

# %%
#ARTISTAS DE CANCIONES POP 2019

for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"pop" year:2019', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_pop_2019["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_pop_2019)
len(dict_tracks_pop_2019)
# Out:
Y (with YUNGBLUD & Travis Barker)", 'Turn You Down (HARDY feat. Morgan Wallen, Zakk Wylde)', 'Good Godly Woman', 'Kill This Love', "Still Don't Know My Name", 'Suge', 'Softly', 'Adicto (with Anuel AA & Ozuna)', "Car's Outside", 'London Boy', 'Half A Man', 'Like That (feat. Gucci Mane)', 'RNP (feat. Anderson .Paak)', 'Vas', 'light', 'Sleep Thru Ur Alarms', 'Dance Monkey', 'Boys Will Be Bugs', 'Ghost', 'If the World Was Ending (feat. Julia Michaels)', 'Time', 'Cherry', 'Strip That Down (feat. Quavo)', 'xanny', 'i met sarah in the bathroom', "Let's Fall in Love for the Night", 'Forever', 'On My Way to You', 'Die For Me (feat. Future & Halsey)', 'Oncle Jazz', 'no way !', 'Nothing Breaks Like a Heart (feat. Miley Cyrus)', 'needy', 'Homicide (feat. Eminem)', 'Andromeda', 'TOES (feat. Lil Baby & Moneybagg Yo)', 'Higher Love', 'Hate Myself', 'Talk', 'Hate Me (with Juice WRLD)', 'Lalala', 'prom dress', 'Hurts Me Too', 'GATTI', 'High School Sweethearts', 'Only Human', 'Señorita', 'Mariners Apartment Complex', 'Honeybee', "Don't Start Now", 'Shrike', 'South of the Border (feat. Camila Cabello & Cardi B)', 'Gloria', 'Arcade', 'Dove - Doll Ve ...
# 5

# %% [markdown]
# ### AÑO LANZAMIENTO 2019

# %%
#AÑO DE LANZAMIENTO
for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"pop" year:2019', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_pop_2019["año lanzamiento"].append(track["album"]['release_date'])
print(dict_tracks_pop_2019)
len(dict_tracks_pop_2019)
# Out:
# {'canciones': ['Cruel Summer', 'Jealous', 'Circles', 'Cry', 'Sunflower - Spider-Man: Into the Spider-Verse', 'Would That I', 'Lover', 'Someone You Loved', "when the party's over", 'Bags', 'Mrs Magic', 'Dreams, Fairytales, Fantasies (feat. Brent Faiyaz & Salaam Remi)', 'YKWIM?', 'Kingston', 'Almost (Sweet Music)', 'Streets', 'Cinnamon Girl', 'The Man', 'everything i wanted', 'Sofia', 'Wow.', 'bad guy', 'Watermelon Sugar', 'i love you', '7 rings', 'One Thing Right', 'Before You Go', 'You Need To Calm Down', 'Trust Issues', 'Looking at Me', 'Heavenly', 'Right Side of My Neck', 'Adore You', 'you should see me in a crown', 'Take What You Want (feat. Ozzy Osbourne & Travis Scott)', 'There Was This Girl', "Where's My Love", "Doin' Time", 'Bruises', 'Shameless', 'Miss Americana & The Heartbreak Prince', 'Fine Line', "Don't Give Up On Me", 'Money In The Grave (Drake ft. Rick Ross)', 'Falling', 'ONE BEER (feat. Lauren Alaina & Devin Dawson)', 'Mount Everest', 'thank u, next', 'Paper Rings', 'Goodbyes (feat. Young Thug)', 'False Confidence', "Ballin' (with Roddy Ricch)", 'Sucker', 'What Would I Do?', 'Intermission', 'Mess', 'Please Me', 'Under The Sun (with J. Cole & Lute feat. DaBaby)', 'Apple Cider', 'Pure
# 5

# %%
df_2019 = pd.DataFrame(dict_tracks_pop_2019)
df_2019
# Out:
#                                          canciones              artistas  \
# 0                                     Cruel Summer          Taylor Swift
# 1                                          Jealous              Eyedress
# 2                                          Circles           Post Malone
# 3                                              Cry  Cigarettes After Sex
# 4    Sunflower - Spider-Man: Into the Spider-Verse           Post Malone
# ..                                             ...                   ...
# 495                                         Dembow           Danny Ocean
# 496     All You Need To Know (feat. Calle Lehmann)               Gryffin
# 497                                   Keanu Reeves                 Logic
# 498                                     fake smile         Ariana Grande
# 499                             Broken & Beautiful        Kelly Clarkson
#
#     género   tipo año lanzamiento
# 0      Pop  track      2019-08-23
# 1      Pop  track      2019-12-06
# 2      Pop  track      2019-09-06
# 3      Pop  track      2019-10-25
# 4      Pop  track      2019-09-06
# ..     ...    ...             ...
# 495    Pop  track      2019-03-22
# 496    Pop  track      2019-10-24
# 497    Pop  track      2019-05-10
# 498    Pop  track      2019-02-08
# 499    Pop  track      2019-03-27
#
# [500 rows x 5 columns]

# %%
df_2019.describe(include="object")
# Out:
#                                 canciones      artistas género   tipo  \
# count                                 500           500    500    500
# unique                                486           220      1      1
# top     I Don't Care (with Justin Bieber)  Taylor Swift    Pop  track
# freq                                    2            16    500    500
#
#        año lanzamiento
# count              500
# unique             117
# top         2019-09-06
# freq                32

# %% [markdown]
# ## CANCIONES POP 2020

# %%
#LISTA DE CANCIONES POP 2020

dict_tracks_pop_2020 ={"canciones":[], "artistas": [], "género": "Pop", "tipo": "track", "año lanzamiento": []}
for offset in range(0,500,50):
    canciones_2020 = sp.search(q="genre:pop year:2020", type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_pop_2020["canciones"].append(canciones_2020["tracks"]["items"][i]["name"])
        

print(dict_tracks_pop_2020)    
len(dict_tracks_pop_2020)
# Out:
# {'canciones': ['Shut up My Moms Calling', 'Heartless (feat. Morgan Wallen)', 'Blinding Lights', 'august', 'Heat Waves', 'Romantic Lover', 'cardigan', 'telepatía', 'anything', 'Heather', 'Maine', 'Save Your Tears', 'Mirage', 'The Thrill', 'not a lot, just forever', "Don't Start Now", 'Sweet but Psycho', 'Chicago Freestyle (feat. Giveon)', 'Levitating (feat. DaBaby)', 'Broke In A Minute', 'half return', 'forwards beckon rebound', 'Steeeam', 'Heartless', 'Lemonade (feat. NAV)', 'seasons', 'Love Me Anyway', 'Pain 1993 (with Playboi Carti)', 'Body Like A Back Road', 'Maniac', 'Figure You Out', 'illicit affairs', 'Good Days', 'WHATS POPPIN', 'Glue Myself Shut', 'Pieces', 'Why', 'Dile a El', 'GIVE HEAVEN SOME HELL', 'Good Die Young', "my ex's best friend (with blackbear)", 'Teeth', 'the 1', 'I Know The End', "Thinking 'Bout Love", 'Not You Too (feat. Chris Brown)', 'After Hours', 'hot girl bummer', 'invisible string', 'Pretty Boy', 'Kings & Queens', 'positions', 'Save Me', 'this is me trying', 'Laugh Now Cry Later (feat. Lil Durk)', 'Save Your Tears (Remix) (with Ariana Grande) -
# 5

# %% [markdown]
# ### ARTISTAS POP 2020

# %%
#ARTISTAS DE CANCIONES POP 2020
for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"pop" year:2020', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_pop_2020["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_pop_2020)
len(dict_tracks_pop_2020)
# Out:
# {'canciones': ['Shut up My Moms Calling', 'Heartless (feat. Morgan Wallen)', 'Blinding Lights', 'august', 'Heat Waves', 'Romantic Lover', 'cardigan', 'telepatía', 'anything', 'Heather', 'Maine', 'Save Your Tears', 'Mirage', 'The Thrill', 'not a lot, just forever', "Don't Start Now", 'Sweet but Psycho', 'Chicago Freestyle (feat. Giveon)', 'Levitating (feat. DaBaby)', 'Broke In A Minute', 'half return', 'forwards beckon rebound', 'Steeeam', 'Heartless', 'Lemonade (feat. NAV)', 'seasons', 'Love Me Anyway', 'Pain 1993 (with Playboi Carti)', 'Body Like A Back Road', 'Maniac', 'Figure You Out', 'illicit affairs', 'Good Days', 'WHATS POPPIN', 'Glue Myself Shut', 'Pieces', 'Why', 'Dile a El', 'GIVE HEAVEN SOME HELL', 'Good Die Young', "my ex's best friend (with blackbear)", 'Teeth', 'the 1', 'I Know The End', "Thinking 'Bout Love", 'Not You Too (feat. Chris Brown)', 'After Hours', 'hot girl bummer', 'invisible string', 'Pretty Boy', 'Kings & Queens', 'positions', 'Save Me', 'this is me trying', 'Laugh Now Cry Later (feat. Lil Durk)', 'Save Your Tears (Remix) (with Ariana Grande) - Bonus Track', 'Honeypie', 'Without Me', 'Intolewd', 'Cloud 9', 'Angels Like You', 'Meet Me At Our Spot', 'Free Mind', 'Time Flies', 'willow', 'Hate Me', 'Lose You To Love Me', 'Higher', 'Hawái', 'Higher Love', 'Bottle and Mary Jane', 'mirrorball', 'that way', 'Dancing With A Stranger (with Normani)', 'The Cut That Always Bleeds', 'ROCKSTAR (feat. Roddy Ricch)', 'Monsters (feat. blackbear)', 'Boss Bitch', 'Dynamite', '3 Headed Goat (feat. Lil Baby & Polo G)', 'If You Love Her', 'Drunk Driving', 'Moon Song', 'Stuck with U (with Justin Bieber)', 'Levitating', 'Rät', '34+35', 'Intentions (feat. Quavo)', 'Eenie Meenie', 'betty', 'No Time To Die', 'Met the Devil in Oklahoma', 'Dicked Down in Dallas', 'Creature', 'Essence (feat. Tems)', 'seven', 'pov', 'Ashes', 'Animal', 'In Your Eyes', 'Michelle', 'Toxic', 'Physical', 'Sanctuary', 'Break My Heart', 'motive (with Doja Cat)', 'Remember That Night?', 'Head & Heart (feat. MNEK)', 'Still With You', 'forget me too (feat. Halsey)', 'Shinunoga E-Wa', 'Tyler Herro', 'Stargazing', "You're All I Want", 'Wish You Were Sober', 'willow', 'Pensándote', 'Hit Different', 'Be Kind (with Halsey)', 'God’s Menu', 'the last great american dynasty', 'Fire On Fire', 'I WANNA SEE SOME ASS (feat. jetsonmade)', 'UNAPOLOGETICALLY COUNTRY AS HELL', "Still Trappin'", 'Can I', 'IDK You Yet', 'Rain On Me (with Ariana Grande)', 'La Mitad', 'Put Your Records On', 'Too Close', 'Kyoto', 'Graceland Too', 'Blastoff (feat. Juice WRLD)', 'bloody valentine', 'El Mismo Aire - con Pablo Alborán', 'Freak', 'All They Wanted', 'Savior Complex', 'Gimme Love', 'You should be sad', 'I Want You To Love Me', 'Blur', 'Wildfires', 'How You Like That', 'gold rush', 'Arcade', 'Need It', 'cardigan', 'Therefore I Am', 'Antidote', 'ivy', 'Wolves (feat. Post Malone)', 'Isis (feat. Logic)', 'WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) - Remix', 'Freak (feat. REI AMI)', 'Midnight Sky', 'Useless', 'Saint Bernard', 'the 1', 'cowboy like me', 'BOOTS', 'Like You Do', 'People You Know', "i'm so tired...", 'You Got It', 'What A Man Gotta Do', 'Tequila Shots', 'ingydar', 'Space Ghost Coast To Coast', 'To the Mountains', 'Prisoner (feat. Dua Lipa)', 'More Hearts Than Mine', "Ponte Pa' Mi", "People I Don't Like", '*Equip Sunglasses*', 'VILLAIN', 'BEST ON EARTH (feat. BIA) - Bonus', '紅蓮華', 'Garden Song', 'My Head & My Heart', 'Lotta True Crime', 'Backyard Boy', 'Chosen (feat. Ty Dolla $ign)', 'my future', 'august', 'Disco Man', 'Tangerine', 'Afterthought', 'peace', 'Caramelo - Remix', "Devil's Advocate", 'The Business', 'Triflin Hoes', 'Levitating (feat. DaBaby)', 'Sensitive', 'Tokyo Drifting', 'marjorie', 'bonfire', 'A Troubled Mind', 'Love Again', 'Précis Two', 'Reloj', 'overwhelmed', 'this is me trying', 'blind', 'Your Love (Déjà Vu)', 'Natural', 'Whats Poppin (feat. DaBaby, Tory Lanez & Lil Wayne) [Remix] - Bonus Track', "You're Somebody Else", 'Killshot', 'Feel Better',  ...
# 5

# %% [markdown]
# ## AÑO LANZAMIENTO 2020

# %%
#AÑO DE LANZAMIENTO
for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"pop" year:2020', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_pop_2020["año lanzamiento"].append(track["album"]['release_date'])
print(dict_tracks_pop_2020)
len(dict_tracks_pop_2020)
# Out:
# {'canciones': ['Shut up My Moms Calling', 'Heartless (feat. Morgan Wallen)', 'Blinding Lights', 'august', 'Heat Waves', 'Romantic Lover', 'cardigan', 'telepatía', 'anything', 'Heather', 'Maine', 'Save Your Tears', 'Mirage', 'The Thrill', 'not a lot, just forever', "Don't Start Now", 'Sweet but Psycho', 'Chicago Freestyle (feat. Giveon)', 'Levitating (feat. DaBaby)', 'Broke In A Minute', 'half return', 'forwards beckon
'm so tired...", 'You Got It', 'What A Man Gotta Do', 'Tequila Shots', 'ingydar', 'Space Ghost Coast To Coast', 'To the Mountains', 'Prisoner (feat. Dua Lipa)', 'More Hearts Than Mine', "Ponte Pa' Mi", "People I Don't Like", '*Equip Sunglasses*', 'VILLAIN', 'BEST ON EARTH (feat. BIA) - Bonus', '紅蓮華', 'Garden Song', 'My Head & My Heart', 'Lotta True Crime', 'Backyard Boy', 'Chosen (feat. Ty Dolla $ign)', 'my future', 'august', 'Disco Man', 'Tangerine', 'Afterthought', 'peace', 'Caramelo - Remix', "Devil's Advocate", 'The Business', 'Triflin Hoes', 'Levitating (feat. DaBaby)', 'Sensitive', 'Tokyo Drifting', 'marjorie', 'bonfire', 'A Troubled Mind', 'Love Again', 'Précis Two', 'Reloj', 'overwhelmed', 'this is me trying', 'blind', 'Your Love (Déjà Vu)', 'Natural', 'Whats Poppin (feat. DaBaby, Tory Lanez & Lil Wayne) [Remix] - Bonus Track', "You're Somebody Else", 'Killshot', 'Feel Better',  ...
# 5

# %%
df_2020 = pd.DataFrame(dict_tracks_pop_2020)
df_2020
# Out:
#                            canciones       artistas género   tipo  \
# 0            Shut up My Moms Calling     Hotel Ugly    Pop  track
# 1    Heartless (feat. Morgan Wallen)          Diplo    Pop  track
# 2                    Blinding Lights     The Weeknd    Pop  track
# 3                             august   Taylor Swift    Pop  track
# 4                         Heat Waves  Glass Animals    Pop  track
# ..                               ...            ...    ...    ...
# 495                    Catching Eyes    49th & Main    Pop  track
# 496    Best of You (feat. Elle King)   Andy Grammer    Pop  track
# 497                             MAGO        GFRIEND    Pop  track
# 498                          Strings           iyla    Pop  track
# 499                        Afterglow     Ed Sheeran    Pop  track
#
#     año lanzamiento
# 0        2020-02-10
# 1        2020-05-29
# 2        2020-03-20
# 3        2020-07-24
# 4        2020-08-07
# ..              ...
# 495      2020-04-24
# 496      2020-02-07
# 497      2020-11-09
# 498      2020-02-07
# 499      2020-12-21
#
# [500 rows x 5 columns]

# %%
df_2020.describe(include="object")
# Out:
#        canciones      artistas género   tipo año lanzamiento
# count        500           500    500    500             500
# unique       475           212      1      1             125
# top     marjorie  Taylor Swift    Pop  track      2020-03-27
# freq           2            40    500    500              22

# %% [markdown]
# # MUSICBRAINZ

# %%
#pip install musicbrainzngs   #Instalamos la libreria
# Out:
# Collecting musicbrainzngs
#   Downloading musicbrainzngs-0.7.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Downloading musicbrainzngs-0.7.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: musicbrainzngs
# Successfully installed musicbrainzngs-0.7.1
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importamos la libreria 
import musicbrainzngs

# %%
#Configuramos el usuario 
musicbrainzngs.set_useragent("MusicStream", "1.0", "psainzpc@hotmail.com")

# %% [markdown]
# ### ARTISTAS POP 2019

# %%
set_artistas_2019= set(dict_tracks_pop_2019['artistas'])  # Convertir el valor asociado a la clave 'artistas' en un set para limpiar los artistas repetidos
print(set_artistas_2019)
# Out:
Suki Waterhouse', 'Vansire', 'Caroline Polachek', 'SYML', 'Orla Gartland', 'Kygo', 'Jervis Campbell', 'NATTI NATASHA', 'Ellie Goulding', 'Halsey', 'Noah Kahan', 'Jakob', 'James TW', 'Weyes Blood', 'Gryffin', 'Sinéad Harnett', 'Surf Mesa', 'Dean Lewis', 'Florida Georgia Line', 'Cody Johnson', 'Bazzi', 'Mark Ronson', 'benny blanco', 'Jacquees', 'melvitto', 'NF', 'Drake', 'Eyedress', 'JACKBOYS', 'Kevin Gates', 'Romeo Santos', 'Harry Styles', 'Still Woozy', 'Arizona Zervas', 'ILLENIUM', 'Men I Trust', 'Reik', 'Hozier', 'Pecos & the Rooftops', 'Olivia Dean', 'Naomi Scott', 'antihoney', 'Jelly Roll', 'A$AP Ferg', 'Blood Orange', 'Sebastian Yatra', 'Jonas Brothers', 'Sleeping At Last', 'Cavetown', 'Camila Cabello', 'awfultune', 'Y2K', 'Lady A', 'Sam Feldt'}

# %%
lista_artistas_2019 = list(set_artistas_2019) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_2019)
# Out:
# 220

# %%
#ejemplo de como muestra los resultados:
result = musicbrainzngs.search_artists(artist='Radiohead')
print(result)
# Out:
# {'artist-list': [{'id': 'a74b1b7f-71a5-4011-9441-d0b5e4122711', 'type': 'Group', 'ext:score': '100', 'name': 'Radiohead', 'sort-name': 'Radiohead', 'country': 'GB', 'area': {'id': '8a754a16-0027-3a29-b6d7-2b40ea0481ed', 'type': 'Country', 'name': 'United Kingdom', 'sort-name': 'United Kingdom', 'life-span': {'ended': 'false'}}, 'begin-area': {'id': 'd840d4b3-8987-4626-928b-398de760cc24', 'type': 'City', 'name': 'Abingdon-on-Thames', 'sort-name': 'Abingdon-on-Thames', 'life-span': {'ended': 'false'}}, 'isni-list': ['0000000115475162'], 'life-span': {'begin': '1991', 'ended': 'false'}, 'alias-list': [{'sort-name': 'r/head', 'type': 'Search hint', 'alias': 'r/head'}, {'locale': 'zh', 'sort-name': '电台司令', 'type': 'Artist name', 'primary': 'primary', 'alias': '电台司令'}, {'locale': 'ja', 'sort-name': 'れでぃおへっど', 'type': 'Artist name', 'primary': 'primary', 'alias': 'レディオヘッド'}, {'sort-name': 'Radiohead & Thom Yorke', 'type': 'Search hint', 'alias': 'Radiohead & Thom Yorke'}, {'sort-name': 'Radio Head', 'type': 'Search hint', 'alias': 'Radio Head'}], 'tag-list': [{'count': '13', 'name': 'rock'}, {'count': '9', 'name': 'electronic'}, {'count': '-1', 'name': 'post-rock'}, {'count': '31', 'name': 'alternative rock'}, {'count': '12', 'name': 'british'}, {'count': '-1', 'name': 'grunge'}, {'count': '0', 'name': 'idm'}, {'count': '0', 'name': 'uk'}, {'count': '-1', 'name': 'britannique'}, {'count': '3', 'name': 'indie rock'}, {'count': '1', 'name': 'alternative'}, {'count': '1', 'name': 'britpop'}, {'count': '21', 'name': 'art rock'}, {'count': '1', 'name': 'post-grunge'}, {'count': '8', 'name': 'experimental rock'}, {'count': '0', 'name': 'english'}, {'count': '0', 'name': 'chamber pop'}, {'count': '-1', 'name': 'parlophone'}, {'count': '-2', 'name': 'england'}, {'count': '0', 'name': 'indietronica'}, {'count': '-1', 'name': 'melancholic'}, {'count': '0', 'name': 'oxford'}, {'count': '0', 'name': 'crossover prog'}, {'count': '-1', 'name': 'bootleg'}, {'count': '-1', 'name': 'rock and indie'}, {'count': '0', 'name': 'britrock'}, {'count': '1', 'name': 'electronic rock'}, {'count': '0', 'name': 'ambient pop'}, {'count': '-2', 'name': 'c’était mieux avant'}, {'count': '3', 'name': 'art pop'}, {'count': '-1', 'name': 'nude'}, {'count': '0', 'name': 'trap edm'}, {'count': '-2', 'name': 'sacred cows'}, {'count': '-1', 'name': 'lolicore'}, {'count': '2', 'name': 'post-britpop'}, {'count': '-2', 'name': '1992-1998'}, {'count': '-1', 'name': 'new grave'}]}, {'id': '3ecaa799-94ae-45cd-9ad1-bcabae4073e1', 'ext:score': '57', 'name': 'radiohead 3', 'sort-name': 'radiohead 3', 'disambiguation': 'Capsmusic LTD. artist', 'life-span': {'ended': 'false'}}, {'id': 'e48fc8b3-e8ab-4dd4-9dc8-6b0f06ef07d6', 'ext:score': '53', 'name': 'Radiohead Cover Brasil', 'sort-name': 'Radiohead Cover Brasil', 'area': {'id': '33e0f86c-d709-448d-a484-d55778913af1', 'type': 'City', 'name': 'São Paulo', 'sort-name': 'São Paulo', 'life-span': {'ended': 'false'}}, 'life-span': {'ended': 'false'}}, {'id': 'b21ab3cc-88ed-4d2b-bd01-6edb83c37900', 'type': 'Group', 'ext:score': '53', 'name': 'Fake Plastic Radiohead', 'sort-name': 'Fake Plastic Radiohead', 'begin-area': {'id': '806b9b3b-5daf-4eaa-807d-7a2a29cde0da', 'type': 'City', 'name': 'Leicester', 'sort-name': 'Leicester', 'life-span': {'ended': 'false'}}, 'life-span': {'begin': '2021-09-25', 'ended': 'false'}}, {'id': '1545e981-65ca-4123-9223-ae8efd72cf54', 'type': 'Group', 'ext:score': '50', 'name': 'An Evening of Radiohead', 'sort-name': 'An Evening of Radiohead', 'area': {'id': '6658f787-692d-417f-852c-dcca728d5849', 'type': 'City', 'name': 'Edinburgh', 'sort-name': 'Edinburgh', 'life-span': {'ended': 'false'}}, 'disambiguation': 'Radiohead Cover Band', 'life-span': {'begin': '2024-01-01', 'ended': 'false'}}], 'artist-count': 5}

# %%
#Aqui tenemos la búsqueda de un artista. Trabajando con la librería. 
artistas_2019_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_2019:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_2019_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_2019_mb["artista"].append("no data")
    try:
        artistas_2019_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_2019_mb["pais de origen"].append("no data")
    try:
        artistas_2019_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_2019_mb["area de origen"].append("no data") 
    try:
        artistas_2019_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"])
    except:
        artistas_2019_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_2019_mb["fin de actividad"].append("no activo")
        else:
            artistas_2019_mb["fin de actividad"].append("activo")
    except:
        artistas_2019_mb["fin de actividad"].append("no data")

# %%
pd.DataFrame(artistas_2019_mb)
# Out:
#             artista pais de origen   area de origen fecha inicio actividad  \
# 0           mxmtoon  United States          Oakland             2000-07-09
# 1             Migos  United States    Lawrenceville                   2008
# 2       Andrew Gold  United States          Burbank             1951-08-02
# 3      Kenny Rogers  United States          Houston             1938-08-21
# 4          Doja Cat  United States          Tarzana             1995-10-21
# ..              ...            ...              ...                    ...
# 215  Camila Cabello  United States          Cojímar             1997-03-03
# 216       awfultune  United States           Ithaca             1998-07-02
# 217             Y2K  United States          no data                no data
# 218       Lady Gaga  United States  Upper East Side             1986-03-28
# 219       Sam Feldt    Netherlands        Amsterdam             1993-08-01
#
#     fin de actividad
# 0             activo
# 1             activo
# 2             activo
# 3             activo
# 4             activo
# ..               ...
# 215           activo
# 216           activo
# 217           activo
# 218           activo
# 219           activo
#
# [220 rows x 5 columns]

# %%
artistas_2019_mb
# Out:
# {'artista': ['mxmtoon',
#   'Migos',
#   'Andrew Gold',
#   'Kenny Rogers',
#   'Doja Cat',
#   'MAMAMOO',
#   'Will Smith',
#   'Dreamville',
#   'Ben Webster',
#   'Ruel',
#   'Loud Luxury',
#   'WILLOW',
#   'Jaden',
#   'Eddie Meduza',
#   'Tory Lanez',
#   'Duster',
#   'DJ Snake',
#   'Katy Perry',
#   'Tones and I',
#   'Offset',
#   'Mustard',
#   'The Beatles',
#   'Ruby Haunt',
#   'Taylor Swift',
#   'Miley Cyrus',
#   'Black Eyed Peas',
#   'Fruit Bats',
#   'mgk',
#   'Rotimi',
#   'Cuco Sánchez',
#   'Post Malone',
#   'Melanie Martinez',
#   'Maluma',
#   'Sub Urban',
#   'Dua Lipa',
#   'Dove Cameron',
#   'Hopsin',
#   'Liam Payne',
#   'Julia Michaels',
#   'Vendredi sur Mer',
#   'Shawn Mendes',
#   'Buddy Guy',
#   'Duncan Laurence',
#   'Glenn Miller',
#   'Wale',
#   'MarMar Oso',
#   'Nipsey Hussle',
#   'ROSALÍA',
#   'Charlie Parker',
#   'Mrs. GREEN APPLE',
#   'YG',
#   'Faouzia',
#   'Zedd',
#   'Tainy',
#   'HIXTAPE',
#   'Regard',
#   'Logic',
#   'Diego & Victor Hugo',
#   'wave to earth',
#   'Mabel',
#   'Marshmello',
#   'BLACKPINK',
#   'Avicii',
#   'Red Velvet',
#   'Wabie',
#   'ScHoolboy Q',
#   'Dermot Kennedy',
#   'Vampire Weekend',
#   'BTS',
#   'Tech N9ne',
#   'Zero‐G',
#   'Fitz and the Tantrums',
#   'R3HAB',
#   'Olivia Rodrigo',
#   'Rex Orange County',
#   'Tyga',
#   'Whitney Houston',
#   'Freya Ridings',
#   'Cardi B',
#   'Martin Garrix',
#   'Sia',
#   'Normani',
#   'Cigarettes After Sex',
#   'Luh Kel',
#   'Topic',
#   'DaBaby',
#   'Rudimental',
#   'dhruv',
#   'Sir Arthur Conan Doyle',
#   'Magdalena Bay',
#   'Françoise Hardy',
#   'Kehlani',
#   'BENEE',
#   'Green Day',
#   'Lizzo',
#   'Sofia Carson',
#   'Muscadine Bloodline',
#   'Lewis Capaldi',
#   'Bryce Vine',
#   'BabyJake',
#   'Sam Cooke',
#   'Drew Baldridge',
#   'Sam Smith',
#   'Sabrina Carpenter',
#   'Mick Jagger',
#   'Boyscott',
#   'Morningsiders',
#   'SAULT',
#   'Megan Thee Stallion',
#   'Dreamer Isioma',
#   'The Head and the Heart',
#   'Ciara',
#   'Leon Russell',
#   'Quinn XCII',
#   'Danny Elfman',
#   'Ariana Grande',
#   'FINNEAS',
#   'Lontalius',
#   'Kelly Clarkson',
#   'Charles Wesley Godwin',
#   'Luis Fonsi',
#   'Ozuna',
#   'WayV-KUN&XIAOJUN',
#   'Local Natives',
#   'Labrinth',
#   '24kGoldn',
#   'James Brown',
#   'BANNERS',
#   'BETWEEN FRIENDS',
#   'Khaled',
#   'Fletcher Henderson',
#   'Yot Club',
#   'Clairo',
#   'Sir Arthur Conan Doyle',
#   '5 Seconds of Summer',
#   'TWICE',
#   'Confetti’s',
#   'dodie',
#   'Lykke Li',
#   'Aventura',
#   'Rauw Alejandro',
#   'Julia Jacklin',
#   'Jack Harlow',
#   'The Red Clay Strays',
#   'Andy Grammer',
#   'Ed Sheeran',
#   'Mau y Ricky',
#   'Sech',
#   'Erika Lundmoen',
#   'The Beatles',
#   'Manuel Turizo',
#   'Cordae',
#   'Lana Del Rey',
#   'Koe Wetzel',
#   'Djo',
#   'JP Saxe',
#   'girl in red',
#   'Khalid',
#   'Waterparks',
#   'beabadoobee',
#   'IV Of Spades',
#   'Matt Stell',
#   'YOASOBI',
#   'Billie Eilish',
#   'Lola Blanc',
#   'Panic! at the Disco',
#   'Suki Waterhouse',
#   'Vansire',
#   'Caroline Polachek',
#   'SYML',
#   'Orla Gartland',
#   'Kygo',
#   'Glen Campbell',
#   'Natti Natasha',
#   'Ellie Goulding',
#   'Halsey',
#   'Noah Kahan',
#   'Johann Jakob Froberger',
#   'James Brown',
#   'Weyes Blood',
#   'Gryffin',
#   'Sinéad Harnett',
#   'Surf Mesa',
#   'Dean Martin',
#   'Florida Georgia Line',
#   'Cody Johnson',
#   'Bazzi',
#   'Mark Ronson',
#   'Benny Goodman',
#   'Jacquees',
#   'Melvitto',
#   'NF',
#   'Drake',
#   'Eyedress',
#   'JACKBOYS',
#   'Kevin Gates',
#   'Romeo Santos',
#   'Harry Styles',
#   'Still Woozy',
#   'Arizona Zervas',
#   'ILLENIUM',
#   'Men I Trust',
#   'Reik',
#   'Hozier',
#   'Pecos & the Rooftops',
#   'Dean Martin',
#   'Scott Lawlor',
#   'antihoney',
#   'Jelly Roll Morton',
#   'A$AP Ferg',
#   'Blood Orange',
#   'Johann Sebastian Bach',
#   'Jonas Brothers',
#   'Sleeping At Last',
#   'Cavetown',
#   'Camila Cabello',
#   'awfultune',
#   'Y2K',
#   'Lady Gaga',
#   'Sam Feldt'],
#  'pais de origen': ['United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'South Korea',
#   'United States',
#   'United States',
#   'United States',
#   'Australia',
#   'Canada',
#   'United States',
#   'United States',
#   'Sweden',
#   'Canada',
#   'United States',
#   'France',
#   'United States',
#   'Australia',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'no data',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Mexico',
#   'United States',
#   'United States',
#   'Colombia',
#   'New Jersey',
#   'England',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'Genève',
#   'Canada',
#   'United States',
#   'Netherlands',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Spain',
#   'United States',
#   'Japan',
#   'United States',
#   'Canada',
#   'Germany',
#   'Puerto Rico',
#   'United States',
#   'New York',
#   'United States',
#   'Brazil',
#   'South Korea',
#   'England',
#   'United States',
#   'South Korea',
#   'Sweden',
#   'South Korea',
#   'no data',
#   'Los Angeles',
#   'Ireland',
#   'United States',
#   'South Korea',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'Netherlands',
#   'United States',
#   'England',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'Netherlands',
#   'Australia',
#   'United States',
#   'United States',
#   'United States',
#   'Germany',
#   'United States',
#   'United Kingdom',
#   'no data',
#   'United Kingdom',
#   'United States',
#   'France',
#   'United States',
#   'New Zealand',
#   'United States',
#   'United States',
#   'United States',
#   'no data',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'United Kingdom',
#   'no data',
#   'New York',
#   'London',
#   'United States',
#   'no data',
#   'United States',
#   'Atlanta',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'no data',
#   'United States',
#   'West Virginia',
#   'Puerto Rico',
#   'Puerto Rico',
#   'China',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'Liverpool',
#   'Los Angeles',
#   'Algeria',
#   'United States',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'Australia',
#   'South Korea',
#   'Belgium',
#   'Enfield',
#   'Sweden',
#   'United States',
#   'Puerto Rico',
#   'Australia',
#   'United States',
#   'Mobile',
#   'United States',
#   'United Kingdom',
#   'Venezuela',
#   'Panama',
#   'Russia',
#   'United Kingdom',
#   'Colombia',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Canada',
#   'Norway',
#   'United States',
#   'Houston',
#   'England',
#   'Philippines',
#   'no data',
#   'Japan',
#   'United States',
#   'United States',
#   'United States',
#   'no data',
#   'Rochester',
#   'United States',
#   'United States',
#   'Ireland',
#   'Norway',
#   'United States',
#   'Dominican Republic',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'Germany',
#   'United States',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'United States',
#   'Canada',
#   'Philippines',
#   'United States',
#   'United States',
#   'United States',
#   'England',
#   'United States',
#   'United States',
#   'United States',
#   'Canada',
#   'Mexico',
#   'Ireland',
#   'Lubbock',
#   'United States',
#   'United States',
#   'Japan',
#   'United States',
#   'United States',
#   'United Kingdom',
#   'Germany',
#   'United States',
#   'United States',
#   'England',
#   'United States',
#   'United States',
#   'United States',
#   'United States',
#   'Netherlands'],
#  'area de origen': ['Oakland',
#   'Lawrenceville',
#   'Burbank',
#   'Houston',
#   'Tarzana',
#   'Seoul',
#   'Philadelphia',
#   'no data',
#   'Kansas City',
#   'Isleworth',
#   'London',
#   'Los Angeles',
#   'Malibu',
#   'Gothenburg',
#   'Brampton',
#   'San Jose',
#   'Paris',
#   'Santa Barbara',
#   'Shire of Mornington Peninsula',
#   'Lawrenceville',
#   'Los Angeles',
#   'Liverpool',
#   'Los Angeles',
#   'West Reading',
#   'Franklin',
#   'Los Angeles',
#   'Chicago',
#   'Houston',
#   'Maplewood',
#   'no data',
#   'Syracuse',
#   'Astoria',
#   'Medellín',
#   'New Jersey',
#   'London',
#   'Bainbridge Island',
#   'Los Angeles',
#   'Wolverhampton',
#   'Davenport',
#   'Genève',
#   'Pickering',
#   'Lettsworth',
#   'Spijkenisse',
#   'Clarinda',
#   'Washington, D.C.',
#   'Honolulu',
#   'Los Angeles',
#   'Sant Esteve Sesrovires',
#   'Kansas City',
#   'no data',
#   'Compton',
#   'Casablanca',
#   'Saratov',
#   'San Juan',
#   'no data',
#   'no data',
#   'Gaithersburg',
#   'Brazil',
#   'Seoul',
#   'Alhaurín el Grande',
#   'Philadelphia',
#   'Seoul',
#   'Stockholm',
#   'Seoul',
#   'no data',
#   'Wiesbaden',
#   'Tallaght',
#   'New York',
#   'Seoul',
#   'Kansas City',
#   'no data',
#   'Los Angeles',
#   'Breda',
#   'Murrieta',
#   'Haslemere',
#   'Compton',
#   'Newark',
#   'London',
#   'The Bronx',
#   'Amstelveen',
#   'Adelaide',
#   'Atlanta',
#   'El Paso',
#   'St. Louis',
#   'Solingen',
#   'Cleveland',
#   'Hackney',
#   'India',
#   'Edinburgh',
#   'Los Angeles',
#   'Paris',
#   'Oakland',
#   'Auckland',
#   'Berkeley',
#   'Detroit',
#   'Fort Lauderdale',
#   'no data',
#   'Glasgow',
#   'New York',
#   'Fort Myers',
#   'Clarksdale',
#   'no data',
#   'London',
#   'Bucks County',
#   'Dartford',
#   'no data',
#   'no data',
#   'no data',
#   'San Antonio',
#   'no data',
#   'Seattle',
#   'Austin',
#   'Lawton',
#   'Michigan',
#   'Los Angeles',
#   'Boca Raton',
#   'Los Angeles',
#   'Wellington',
#   'Fort Worth',
#   'no data',
#   'San Juan',
#   'San Juan',
#   'no data',
#   'Silver Lake',
#   'Hackney',
#   'San Francisco',
#   'Barnwell',
#   'no data',
#   'Los Angeles',
#   'Oran',
#   'Cuthbert',
#   'no data',
#   'Atlanta',
#   'Edinburgh',
#   'Sydney',
#   'Seoul',
#   'Brasschaat',
#   'Enfield',
#   'Ystad',
#   'The Bronx',
#   'San Juan',
#   'New South Wales',
#   'Louisville',
#   'Mobile',
#   'Los Angeles',
#   'Halifax',
#   'no data',
#   'Colón',
#   'Oslo',
#   'Liverpool',
#   'Córdoba',
#   'Raleigh',
#   'Manhattan',
#   'Pittsburg',
#   'Newburyport',
#   'Toronto',
#   'Horten',
#   'Fort Stewart',
#   'Houston',
#   'Iloilo City',
#   'Philippines',
#   'no data',
#   'no data',
#   'Los Angeles',
#   'Augsburg',
#   'Las Vegas',
#   'Hammersmith',
#   'no data',
#   'Manhattan',
#   'Issaquah',
#   'Dublin',
#   'Singapore',
#   'Delight',
#   'Santiago de los Caballeros',
#   'Hereford',
#   'Washington',
#   'Strafford',
#   'Stuttgart',
#   'Barnwell',
#   'Santa Monica',
#   'San Francisco',
#   'Hat Yai',
#   'Seattle',
#   'Steubenville',
#   'Nashville',
#   'no data',
#   'Dearborn',
#   "St John's Wood",
#   'Chicago',
#   'Atlanta',
#   'no data',
#   'Gladwin',
#   'Toronto',
#   'Manila',
#   'no data',
#   'New Orleans',
#   'The Bronx',
#   'Redditch',
#   'Oakland',
#   'Hagerstown',
#   'Chicago',
#   'Montréal',
#   'Mexicali',
#   'Bray',
#   'no data',
#   'Steubenville',
#   'no data',
#   'no data',
#   'New Orleans',
#   'Harlem',
#   'Ilford',
#   'Eisenach',
#   'Wyckoff',
#   'Wheaton',
#   'Oxford',
#   'Cojímar',
#   'Ithaca',
#   'no data',
#   'Upper East Side',
#   'Amsterdam'],
#  'fecha inicio actividad': ['2000-07-09',
#   '2008',
#   '1951-08-02',
#   '1938-08-21',
#   '1995-10-21',
#   '2014-06-18',
#   '1968-09-25',
#   '2007',
#   '1909-03-27',
#   '2002-10-29',
#   '2012',
#   '2000-10-31',
#   '1998-07-08',
#   '1948-06-17',
#   '1992-07-27',
#   '1996',
#   '1986-06-13',
#   '1984-10-25',
#   '1998-05-13',
#   '1991-12-14',
#   '1990-06-05',
#   '1960',
#   'no data',
#   '1989-12-13',
#   '1992-11-23',
#   '1995',
#   '1997',
#   '1990-04-22',
#   '1988-11-30',
#   '1921-05-03',
#   '1995-07-04',
#   '1995-04-28',
#   '1994-01-28',
#   'no data',
#   '1995-08-22',
#   '1996-01-15',
#   '1985-07-18',
#   '1993-08-29',
#   '1993-11-13',
#   '1995-04-20',
#   '1998-08-08',
#   '1936-07-30',
#   '1994-04-11',
#   '1904-03-01',
#   '1984-09-21',
#   '1999',
#   '1985-08-15',
#   '1992-09-25',
#   '1920-08-29',
#   '2013',
#   '1990-03-09',
#   '2000-07-05',
#   '1989-09-02',
#   '1989-08-09',
#   'no data',
#   '1993',
#   '1990-01-22',
#   '2009-01-01',
#   '2019',
#   '1996-02-20',
#   '1992-05-19',
#   '2016-08-08',
#   '1989-09-08',
#   '2014-08-01',
#   'no data',
#   '1986-10-26',
#   '1991-12-13',
#   '2006-02-06',
#   '2013-06-13',
#   '1971-11-08',
#   '1990',
#   '2008',
#   '1986-04-02',
#   '2003-02-20',
#   '1998-05-04',
#   '1989-11-19',
#   '1963-08-09',
#   '1994-04-19',
#   '1992-10-11',
#   '1996-05-15',
#   '1975-12-18',
#   '1996-05-31',
#   '2008',
#   '2002-05-20',
#   '1992-03-23',
#   '1991-12-22',
#   '2010',
#   'no data',
#   '1859-05-22',
#   '2016',
#   '1944-01-17',
#   '1995-04-24',
#   '2000-01-30',
#   '1989',
#   '1988-04-27',
#   '1993-04-10',
#   'no data',
#   '1996-10-17',
#   '1988-06-16',
#   'no data',
#   '1931-01-22',
#   'no data',
#   '1992-05-19',
#   '1999-05-11',
#   '1943-07-26',
#   'no data',
#   'no data',
#   '2019',
#   '1995-02-15',
#   'no data',
#   '2009',
#   '1985-10-25',
#   '1942-04-02',
#   '1992-05-06',
#   '1953-05-29',
#   '1993-06-26',
#   '1997-07-30',
#   'no data',
#   '1982-04-24',
#   'no data',
#   '1978-04-15',
#   '1992-03-13',
#   '2021-06-11',
#   '2003',
#   '1989-01-04',
#   '2000-11-13',
#   '1933-05-03',
#   'no data',
#   '2017',
#   '1960-02-29',
#   '1897-12-18',
#   'no data',
#   '1998-08-18',
#   '1859-05-22',
#   '2011',
#   '2015-07-07',
#   '1988',
#   '1995-04-11',
#   '1986-03-18',
#   '1994',
#   '1993-01-10',
#   '1990-08-30',
#   '1998-03-13',
#   'no data',
#   '1983-12-03',
#   '1991-02-17',
#   'no data',
#   '1993-12-03',
#   '1997-09-21',
#   '1960',
#   '2000-04-12',
#   '1997-08-26',
#   '1985-06-21',
#   '1992-07-14',
#   '1992-04-24',
#   '1994-03-23',
#   '1999-02-16',
#   '1998-02-11',
#   '2011',
#   '2000-06-03',
#   '2014',
#   'no data',
#   '2019-09-30',
#   '2001-12-18',
#   '1987-12-20',
#   '2004',
#   '1992-01-05',
#   'no data',
#   '1985-06-20',
#   '1983-01-16',
#   '1995-02-03',
#   '1991-09-11',
#   '1936-04-22',
#   '1986-12-10',
#   '1986-12-30',
#   '1994-09-29',
#   '1997-01-01',
#   '1616-05-18',
#   '1933-05-03',
#   '1988-06-11',
#   '1987-09-29',
#   '1989-10-12',
#   '2000-04-10',
#   '1917-06-07',
#   '2010',
#   '1987-05-21',
#   '1997-08-28',
#   '1975-09-04',
#   '1909-05-30',
#   '1994-04-15',
#   'no data',
#   '1991-03-30',
#   '1986-10-24',
#   '1990-05-28',
#   '2019',
#   '1986-02-05',
#   '1981-07-21',
#   '1994-02-01',
#   '1992-06-23',
#   '1995-04-19',
#   '1990-12-26',
#   '2014-02-06',
#   '2003',
#   '1990-03-17',
#   '2019',
#   '1917-06-07',
#   'no data',
#   'no data',
#   '1885-10-20',
#   '1988-10-20',
#   '1985-12-23',
#   '1685-03-21',
#   '2005',
#   '1998',
#   '1998-12-15',
#   '1997-03-03',
#   '1998-07-02',
#   'no data',
#   '1986-03-28',
#   '1993-08-01'],
#  'fin de actividad': ['activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo',
#   'activo']}

# %% [markdown]
# ### ARTISTAS POP 2020

# %%
set_artistas_2020= set(dict_tracks_pop_2020['artistas'])  # Convertir el valor asociado a la clave 'artistas' en un set para limpiar los artistas repetidos
print(set_artistas_2020)
# Out:
# {'Feid', 'VOILÀ', 'Migos', 'Frances Forever', 'Doja Cat', 'The Marías', 'Calvin Harris', 'The Neighbourhood', 'MEDUZA', 'Tory Lanez', 'Duomo', 'Penelope Scott', 'Jason Derulo', 'RAC', 'Katy Perry', 'Ian Munsick', 'Duke Dumont', 'Sebastian Ingrosso', 'Taylor Swift', 'Miley Cyrus', 'Black Eyed Peas', 'mgk', 'HWASA', 'Cuco', 'Diego Torres', 'Maluma', 'Melanie Martinez', 'Dua Lipa', 'Sub Urban', 'Ovy On The Drums', 'The 1975', 'Remi Wolf', 'twocolors', 'Jameson Rodgers', 'Grimes', 'Duncan Laurence', 'Shawn Mendes', 'Joyner Lucas', 'ROSALÍA', 'Parker McCollum', 'TOMORROW X TOGETHER', 'Joel Corry', 'Point North', 'LiSA', 'Sean Kingston', 'Chappell Roan', 'Switch', 'Omar Apollo', 'Tems', 'Lady Gaga', 'K/DA', 'Hotel Ugly', 'wave to earth', 'Conan Gray', 'Leanna Crawford', 'Spencer Crandall', 'Dominic Fike', 'Marshmello', 'NEEDTOBREATHE', 'The Weeknd', 'Wizkid', 'BLACKPINK', 'Justin Champagne', 'ITZY', 'Hot Mulligan', 'Diplo', 'Tate McRae', 'BTS', 'Internet Money', 'Jawsh 685', 'Alexander 23', 'Olivia Rodrigo', 'Kevin Ross', 'PALASTIC', 'Cigarettes After Sex', 'blackbear', 'Jung Kook', 'Ingrid Andress', 'Kidd G', 'DaBaby', 'UPSAHL', 'Magdalena Bay', 'Bennett Coast', 'Kali Uchis', 'HARDY', 'Matt Hartke', 'Wande Coal', 'Lil Durk', 'Ritt Momney', 'Big Sean', 'Kehlani', 'Claire Rosinkranz', 'Jeremy Zucker', 'Jerry Di', 'Kid Cudi', 'Forest Blakk', 'Zoe Wees', 'Muscadine Bloodline', 'BabyJake', 'Sam Smith', 'Stellar', 'Wild Rivers', 'Boza', 'SAULT', 'flora cash', 'Joji', 'Megan Thee Stallion', 'Sam Hunt', 'Dreamer Isioma', 'Stray Kids', 'Glass Animals', 'Fiona Apple', 'Quinn XCII', 'Ariana Grande', 'Tiësto', 'JAWNY', 'Tenille Arts', 'Ozuna', 'Camilo', 'Nicki Minaj', 'Cautious Clay', 'Snoop Dogg', 'Wiz Khalifa', 'Russ', 'Selena Gomez', 'Ava Max', 'DJ Khaled', 'FLETCHER', 'Beach Bunny', 'GFRIEND', 'Panchiko', 'KAI', 'Adrianne Lenker', '5 Seconds of Summer', 'Fujii Kaze', 'TWICE', 'Livingston', 'The Church Will Sing', 'IU', 'Aly & AJ', 'Phoebe Bridgers', 'Blxst', 'Rauw Alejandro', 'Jack Harlow', 'Trey Lewis', 'Lauv', 'ENHYPEN', 'Andy Grammer', 'Ed Sheeran', 'Miracle Of Sound', 'Sech', 'Lil Wayne', 'Niall Horan', 'Zara Larsson', 'Brye', 'Manuel Turizo', 'SZA', 'Eden Prince', 'Chri$tian Gate$', 'Koe Wetzel', 'Maxine Nightingale', 'Orion Sun', 'Sara Kays', 'Lincoln', 'Khalid', 'Justin Bieber', 'Dean Blunt', '49th & Main', 'Vedo', 'Billie Eilish', 'Noah Cyrus', 'Twenty One Pilots', 'Freak Slug', 'Jessie Reyez', 'Vansire', 'Nelly', 'Kygo', 'Halsey', 'Lizzy McAlpine', 'Ellie Goulding', 'Ty Dolla $ign', 'Noah Kahan', 'Charli xcx', 'All Time Low', 'MisterWives', 'Teyana Taylor', 'Drake', 'Shelly', 'Eyedress', 'Bruno Major', 'Kevin Gates', 'Josh Meloy', 'Royal & the Serpent', 'THE ANXIETY', 'iyla', 'Willie Nelson', 'Lane 8', 'ILLENIUM', 'Matt Maltese', 'Reik', 'Ski Mask The Slump God', 'Sir Chloe', 'ROLE MODEL', 'Pecos & the Rooftops', 'DANIEL', 'AViVA', 'Jelly Roll', 'Jonas Brothers', 'Cavetown', 'brb.', 'Jin', 'Alec Benjamin'}

# %%
lista_artistas_2020 = list(set_artistas_2020) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_2020)
# Out:
# 212

# %%
#Aqui tenemos la búsqueda de un artista. Trabajando con la librería. 
artistas_2020_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_2020:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_2020_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_2020_mb["artista"].append("no data")
    try:
        artistas_2020_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_2020_mb["pais de origen"].append("no data")
    try:
        artistas_2020_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_2020_mb["area de origen"].append("no data") 
    try:
        artistas_2020_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"])
    except:
        artistas_2020_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_2020_mb["fin de actividad"].append("no activo")
        else:
            artistas_2020_mb["fin de actividad"].append("activo")
    except:
        artistas_2020_mb["fin de actividad"].append("no data")

# %%
pd.DataFrame(artistas_2020_mb)
# Out:
#               artista  pais de origen area de origen fecha inicio actividad  \
# 0                Feid        Colombia       Medellín             1992-08-19
# 1               VOILÀ   United States    Los Angeles             2018-01-12
# 2               Migos   United States  Lawrenceville                   2008
# 3     Frances Forever   United States        no data             1999-06-17
# 4            Doja Cat   United States        Tarzana             1995-10-21
# ..                ...             ...            ...                    ...
# 207    Jonas Brothers   United States        Wyckoff                   2005
# 208          Cavetown         England         Oxford             1998-12-15
# 209              brb.         no data        no data                   2018
# 210            MC Jin   United States          Miami             1982-06-04
# 211  Benjamin Britten  United Kingdom      Lowestoft             1913-11-22
#
#     fin de actividad
# 0             activo
# 1             activo
# 2             activo
# 3             activo
# 4             activo
# ..               ...
# 207           activo
# 208           activo
# 209           activo
# 210           activo
# 211           activo
#
# [212 rows x 5 columns]
