# %%
#%pip install spotipy

# %%
import requests
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = "9ba747b4cd1a426c826e14373c7648a1"
api_key = "4c67909da02740418998f8277a500767"

auth_manager = SpotifyClientCredentials( client_id, api_key)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
canciones = sp.search(q="genre:pop year:2019", type="track", limit=50, offset=0)

# %%
canciones.keys()
# Out:
# dict_keys(['tracks'])

# %%
canciones["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
canciones["tracks"]["items"][0]["album"]["release_date"]
# Out:
# '2019-08-23'

# %%
canciones["tracks"]["items"][0]["artists"][0]["name"]
canciones["tracks"]["items"][0]["artists"][0]["name"]
# Out:
# 'Taylor Swift'

# %% [markdown]
# ## CANCIONES POP 2019

# %%
#LISTA DE CANCIONES POP 2019
dict_tracks_pop_2019 ={"canciones":[], "artistas": [], "género": "Pop", "tipo": "track", "año lanzamiento": []}
for offset in range(0,500,50):
    canciones_2019 = sp.search(q="genre:pop year:2019", type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_pop_2019["canciones"].append(canciones_2019["tracks"]["items"][i]["name"])
        

print(dict_tracks_pop_2019)    
len(dict_tracks_pop_2019)
# Out:
# {'canciones': ['Cruel Summer', 'Jealous', 'Circles', 'Cry', 'Sunflower - Spider-Man: Into the Spider-Verse', 'Lover', "when the party's over", 'Would That I', 'Someone You Loved', 'Bags', 'Dreams, Fairytales, Fantasies (feat. Brent Faiyaz & Salaam Remi)', 'Mrs Magic', 'YKWIM?', 'Almost (Sweet Music)', 'Kingston', 'Streets', 'The Man', 'everything i wanted', 'Sofia', 'Cinnamon Girl', 'Wow.', 'bad guy', 'i love you', 'Watermelon Sugar', '7 rings', 'One Thing Right', 'Before You Go', 'You Need To Calm Down', 'Trust Issues', 'Heavenly', 'Looking at Me', 'Adore You', 'Right Side of My Neck', 'There Was This Girl', 'you should see me in a crown', 'Miss Americana & The Heartbreak Prince', 'Take What You Want (feat. Ozzy Osbourne & Travis Scott)', "Where's My Love", 'Fine Line', 'Shameless', 'Bruises', "Doin' Time", "Don't Give Up On Me", 'Falling', 'Money In The Grave (Drake ft. Rick Ross)', 'ONE BEER (feat. Lauren Alaina & Devin Dawson)', 'Spooky, Scary Skeletons - Undead Tombstone Remix',
# ...

# %% [markdown]
# ### ARTISTAS POP 2019

# %%
#ARTISTAS DE CANCIONES POP 2019

for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"pop" year:2019', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_pop_2019["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_pop_2019)
len(dict_tracks_pop_2019)
# Out:
# {'canciones': ['Cruel Summer', 'Jealous', 'Circles', 'Cry', 'Sunflower - Spider-Man: Into the Spider-Verse', 'Lover', "when the party's over", 'Would That I', 'Someone You Loved', 'Bags', 'Dreams, Fairytales, Fantasies (feat. Brent Faiyaz & Salaam Remi)', 'Mrs Magic', 'YKWIM?', 'Almost (Sweet Music)', 'Kingston', 'Streets', 'The Man', 'everything i wanted', 'Sofia', 'Cinnamon Girl', 'Wow.', 'bad guy', 'i love you', 'Watermelon Sugar', '7 rings', 'One Thing Right', 'Before You Go', 'You Need To Calm Down', 'Trust Issues', 'Heavenly', 'Looking at Me', 'Adore You', 'Right Side of My Neck', 'There Was This Girl', 'you should see me in a crown', 'Miss Americana & The Heartbreak Prince', 'Take What You Want (feat. Ozzy Osbourne & Travis Scott)', "Where's My Love", 'Fine Line', 'Shameless', 'Bruises', "Doin' Time", "Don't Give Up On Me", 'Falling', 'Money In The Grave (Drake ft. Rick Ross)', 'ONE BEER (feat. Lauren Alaina & Devin Dawson)', 'Spooky, Scary Skeletons - Undead Tombstone Remix',
# ...

# %% [markdown]
# ### AÑO LANZAMIENTO 2019

# %%
#AÑO DE LANZAMIENTO
for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"pop" year:2019', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_pop_2019["año lanzamiento"].append(track["album"]['release_date'].split("-")[0])
print(dict_tracks_pop_2019)
len(dict_tracks_pop_2019)
# Out:
# {'canciones': ['Cruel Summer', 'Jealous', 'Circles', 'Cry', 'Sunflower - Spider-Man: Into the Spider-Verse', 'Lover', "when the party's over", 'Would That I', 'Someone You Loved', 'Bags', 'Dreams, Fairytales, Fantasies (feat. Brent Faiyaz & Salaam Remi)', 'Mrs Magic', 'YKWIM?', 'Almost (Sweet Music)', 'Kingston', 'Streets', 'The Man', 'everything i wanted', 'Sofia', 'Cinnamon Girl', 'Wow.', 'bad guy', 'i love you', 'Watermelon Sugar', '7 rings', 'One Thing Right', 'Before You Go', 'You Need To Calm Down', 'Trust Issues', 'Heavenly', 'Looking at Me', 'Adore You', 'Right Side of My Neck', 'There Was This Girl', 'you should see me in a crown', 'Miss Americana & The Heartbreak Prince', 'Take What You Want (feat. Ozzy Osbourne & Travis Scott)', "Where's My Love", 'Fine Line', 'Shameless', 'Bruises', "Doin' Time", "Don't Give Up On Me", 'Falling', 'Money In The Grave (Drake ft. Rick Ross)', 'ONE BEER (feat. Lauren Alaina & Devin Dawson)', 'Spooky, Scary Skeletons - Undead Tombstone Remix',
# ...

# %%
df_2019 = pd.DataFrame(dict_tracks_pop_2019)
df_2019
# Out:
#                                          canciones              artistas  \
# 0                                     Cruel Summer          Taylor Swift
# 1                                          Jealous              Eyedress
# 2                                          Circles           Post Malone
# 3                                              Cry  Cigarettes After Sex
# 4    Sunflower - Spider-Man: Into the Spider-Verse           Post Malone
# ..                                             ...                   ...
# 495     All You Need To Know (feat. Calle Lehmann)               Gryffin
# 496                                      You and I                 Jakob
# 497                                     fake smile         Ariana Grande
# 498                                       Allergic           Post Malone
# 499                                         Dembow           Danny Ocean
#
#     género   tipo año lanzamiento
# 0      Pop  track            2019
# ...

# %%
df_2019.to_csv("dict_tracks_pop_2019.csv", index=False)

# %%
df_2019.describe(include="object")
# Out:
#                                         canciones      artistas género   tipo  \
# count                                         500           500    500    500
# unique                                        486           221      1      1
# top     Good Things Fall Apart (with Jon Bellion)  Taylor Swift    Pop  track
# freq                                            2            16    500    500
#
#        año lanzamiento
# count              500
# unique               1
# top               2019
# freq               500

# %% [markdown]
# ## CANCIONES POP 2020

# %%
#LISTA DE CANCIONES POP 2020

dict_tracks_pop_2020 ={"canciones":[], "artistas": [], "género": "Pop", "tipo": "track", "año lanzamiento": []}
for offset in range(0,500,50):
    canciones_2020 = sp.search(q="genre:pop year:2020", type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_pop_2020["canciones"].append(canciones_2020["tracks"]["items"][i]["name"])
        

print(dict_tracks_pop_2020)    
len(dict_tracks_pop_2020)
# Out:
# {'canciones': ['Shut up My Moms Calling', 'Heartless (feat. Morgan Wallen)', 'Blinding Lights', 'august', 'Heat Waves', 'Romantic Lover', 'cardigan', 'telepatía', 'anything', 'Maine', 'Heather', 'Save Your Tears', 'Mirage', 'The Thrill', "Don't Start Now", 'not a lot, just forever', 'Sweet but Psycho', 'Chicago Freestyle (feat. Giveon)', 'forwards beckon rebound', 'Levitating (feat. DaBaby)', 'Broke In A Minute', 'half return', 'Lemonade (feat. NAV)', 'Steeeam', 'Body Like A Back Road', 'Heartless', 'WHATS POPPIN', 'seasons', 'Pain 1993 (with Playboi Carti)', 'Maniac', 'illicit affairs', 'Love Me Anyway', 'Figure You Out', 'Glue Myself Shut', 'Good Days', 'Teeth', 'GIVE HEAVEN SOME HELL', 'Why', 'Pieces', 'the 1', 'Not You Too (feat. Chris Brown)', 'Dile a El', "my ex's best friend (with blackbear)", 'I Know The End', 'After Hours', "Thinking 'Bout Love", 'invisible string', 'Pretty Boy', 'hot girl bummer', 'Good Die Young', 'positions', 'Kings & Queens', 'Save Me', 'Laugh Now Cry La
# ...

# %% [markdown]
# ### ARTISTAS POP 2020

# %%
#ARTISTAS DE CANCIONES POP 2020
for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"pop" year:2020', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_pop_2020["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_pop_2020)
len(dict_tracks_pop_2020)
# Out:
# {'canciones': ['Shut up My Moms Calling', 'Heartless (feat. Morgan Wallen)', 'Blinding Lights', 'august', 'Heat Waves', 'Romantic Lover', 'cardigan', 'telepatía', 'anything', 'Maine', 'Heather', 'Save Your Tears', 'Mirage', 'The Thrill', "Don't Start Now", 'not a lot, just forever', 'Sweet but Psycho', 'Chicago Freestyle (feat. Giveon)', 'forwards beckon rebound', 'Levitating (feat. DaBaby)', 'Broke In A Minute', 'half return', 'Lemonade (feat. NAV)', 'Steeeam', 'Body Like A Back Road', 'Heartless', 'WHATS POPPIN', 'seasons', 'Pain 1993 (with Playboi Carti)', 'Maniac', 'illicit affairs', 'Love Me Anyway', 'Figure You Out', 'Glue Myself Shut', 'Good Days', 'Teeth', 'GIVE HEAVEN SOME HELL', 'Why', 'Pieces', 'the 1', 'Not You Too (feat. Chris Brown)', 'Dile a El', "my ex's best friend (with blackbear)", 'I Know The End', 'After Hours', "Thinking 'Bout Love", 'invisible string', 'Pretty Boy', 'hot girl bummer', 'Good Die Young', 'positions', 'Kings & Queens', 'Save Me', 'Laugh Now Cry La
# ...

# %% [markdown]
# ## AÑO LANZAMIENTO 2020

# %%
#AÑO DE LANZAMIENTO
for offset in range(0, 500, 50):
    canciones = sp.search(q='genre:"pop" year:2020', type='track', limit=50, offset=offset)
    for track in canciones['tracks']['items']:
        dict_tracks_pop_2020["año lanzamiento"].append(track["album"]['release_date'].split("-")[0])
print(dict_tracks_pop_2020)
len(dict_tracks_pop_2020)
# Out:
# {'canciones': ['Shut up My Moms Calling', 'Heartless (feat. Morgan Wallen)', 'Blinding Lights', 'august', 'Heat Waves', 'Romantic Lover', 'cardigan', 'telepatía', 'anything', 'Maine', 'Heather', 'Save Your Tears', 'Mirage', 'The Thrill', "Don't Start Now", 'not a lot, just forever', 'Sweet but Psycho', 'Chicago Freestyle (feat. Giveon)', 'forwards beckon rebound', 'Levitating (feat. DaBaby)', 'Broke In A Minute', 'half return', 'Lemonade (feat. NAV)', 'Steeeam', 'Body Like A Back Road', 'Heartless', 'WHATS POPPIN', 'seasons', 'Pain 1993 (with Playboi Carti)', 'Maniac', 'illicit affairs', 'Love Me Anyway', 'Figure You Out', 'Glue Myself Shut', 'Good Days', 'Teeth', 'GIVE HEAVEN SOME HELL', 'Why', 'Pieces', 'the 1', 'Not You Too (feat. Chris Brown)', 'Dile a El', "my ex's best friend (with blackbear)", 'I Know The End', 'After Hours', "Thinking 'Bout Love", 'invisible string', 'Pretty Boy', 'hot girl bummer', 'Good Die Young', 'positions', 'Kings & Queens', 'Save Me', 'Laugh Now Cry La
# ...

# %%
df_2020 = pd.DataFrame(dict_tracks_pop_2020)
df_2020
# Out:
#                            canciones       artistas género   tipo  \
# 0            Shut up My Moms Calling     Hotel Ugly    Pop  track
# 1    Heartless (feat. Morgan Wallen)          Diplo    Pop  track
# 2                    Blinding Lights     The Weeknd    Pop  track
# 3                             august   Taylor Swift    Pop  track
# 4                         Heat Waves  Glass Animals    Pop  track
# ..                               ...            ...    ...    ...
# 495                          my type           brb.    Pop  track
# 496             Color Esperanza 2020   Diego Torres    Pop  track
# 497           Potential Breakup Song       Aly & AJ    Pop  track
# 498                       CRY FOR ME          TWICE    Pop  track
# 499               Head In The Clouds       BabyJake    Pop  track
#
#     año lanzamiento
# 0              2020
# 1              2020
# 2              2020
# 3              2020
# 4              2020
# ..              ...
# 495            2020
# ...

# %%
df_2020.to_csv("dict_tracks_pop_2020.csv", index=False)

# %%
df_2020.describe(include="object")
# Out:
#        canciones      artistas género   tipo año lanzamiento
# count        500           500    500    500             500
# unique       475           210      1      1               1
# top        seven  Taylor Swift    Pop  track            2020
# freq           2            40    500    500             500

# %% [markdown]
# # MUSICBRAINZ

# %%
#pip install musicbrainzngs   #Instalamos la libreria

# %%
#Importamos la libreria 
import musicbrainzngs

# %%
#Configuramos el usuario 
musicbrainzngs.set_useragent("MusicStream", "1.0", "psainzpc@hotmail.com")

# %% [markdown]
# ### ARTISTAS POP 2019

# %%
set_artistas_2019= set(dict_tracks_pop_2019['artistas'])  # Convertir el valor asociado a la clave 'artistas' en un set para limpiar los artistas repetidos
print(set_artistas_2019)
# Out:
# {'Djo', 'BANNERS', 'Orla Gartland', 'Sub Urban', 'Danny Ocean', 'Julia Jacklin', 'The Head And The Heart', 'Jack Harlow', 'LÉON', 'Melanie Martinez', 'Jervis Campbell', 'Erika Lundmoen', 'Reik', 'DJ Khaled', 'Suki Waterhouse', 'Drew Baldridge', 'Cigarettes After Sex', 'Eyedress', 'Wabie', 'SiR', 'Sabrina Carpenter', 'wave to earth', 'Olivia Rodrigo', 'Camila Cabello', 'Sam Fischer', 'Manuel Turizo', 'Julia Michaels', 'Becky G', 'WILLOW', 'Post Malone', 'Jakob', 'Megan Thee Stallion', 'Dean Lewis', 'Rauw Alejandro', 'Sia', 'Faouzia', 'YG', 'Blood Orange', 'Magdalena Bay', 'Red Velvet', 'Fruit Bats', 'Olivia Dean', 'Caroline Polachek', 'The Lumineers', 'Dua Lipa', 'James Blake', 'Freya Ridings', 'BabyJake', 'Ellie Goulding', 'mxmtoon', 'benny blanco', 'Maluma', 'Diego & Victor Hugo', 'Romeo Santos', 'Cordae', 'Loud Luxury', 'antihoney', 'Mabel', 'Andy Grammer', 'BETWEEN FRIENDS', 'Ronnie Milsap', 'TWICE', 'Bea Miller', 'Matt Stell', 'ScHoolboy Q', 'MAMAMOO', 'WayV', 'Sam Smith', 'ROSAL
# ...

# %%
lista_artistas_2019 = list(set_artistas_2019) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_2019)
# Out:
# 221

# %%
#ejemplo de como muestra los resultados:
result = musicbrainzngs.search_artists(artist='Radiohead')
print(result)
# Out:
# {'artist-list': [{'id': 'a74b1b7f-71a5-4011-9441-d0b5e4122711', 'type': 'Group', 'ext:score': '100', 'name': 'Radiohead', 'sort-name': 'Radiohead', 'country': 'GB', 'area': {'id': '8a754a16-0027-3a29-b6d7-2b40ea0481ed', 'type': 'Country', 'name': 'United Kingdom', 'sort-name': 'United Kingdom', 'life-span': {'ended': 'false'}}, 'begin-area': {'id': 'd840d4b3-8987-4626-928b-398de760cc24', 'type': 'City', 'name': 'Abingdon-on-Thames', 'sort-name': 'Abingdon-on-Thames', 'life-span': {'ended': 'false'}}, 'isni-list': ['0000000115475162'], 'life-span': {'begin': '1991', 'ended': 'false'}, 'alias-list': [{'sort-name': 'r/head', 'type': 'Search hint', 'alias': 'r/head'}, {'locale': 'zh', 'sort-name': '电台司令', 'type': 'Artist name', 'primary': 'primary', 'alias': '电台司令'}, {'locale': 'ja', 'sort-name': 'れでぃおへっど', 'type': 'Artist name', 'primary': 'primary', 'alias': 'レディオヘッド'}, {'sort-name': 'Radiohead & Thom Yorke', 'type': 'Search hint', 'alias': 'Radiohead & Thom Yorke'}, {'sort-name': 'Rad
# ...

# %%
#Aqui tenemos la búsqueda de un artista. Trabajando con la librería. 
artistas_2019_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_2019:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_2019_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_2019_mb["artista"].append("no data")
    try:
        artistas_2019_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_2019_mb["pais de origen"].append("no data")
    try:
        artistas_2019_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_2019_mb["area de origen"].append("no data") 
    try:
        artistas_2019_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"].split("-")[0])
    except:
        artistas_2019_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_2019_mb["fin de actividad"].append("no activo")
        else:
            artistas_2019_mb["fin de actividad"].append("activo")
    except:
        artistas_2019_mb["fin de actividad"].append("no data")

# %%
df_mb_2019 = pd.DataFrame(artistas_2019_mb)
df_mb_2019
# Out:
#               artista pais de origen     area de origen  \
# 0                 Djo  United States        Newburyport
# 1             BANNERS      Liverpool            no data
# 2       Orla Gartland        Ireland             Dublin
# 3           Sub Urban     New Jersey         New Jersey
# 4        Danny Elfman  United States        Los Angeles
# ..                ...            ...                ...
# 216    Jonas Brothers  United States            Wyckoff
# 217             Topic        Germany           Solingen
# 218           Mustard  United States        Los Angeles
# 219      Dove Cameron  United States  Bainbridge Island
# 220  Mrs. GREEN APPLE          Japan            no data
#
#     fecha inicio actividad fin de actividad
# 0                     1992           activo
# 1                  no data           activo
# 2                     1995           activo
# 3                  no data           activo
# 4                     1953           activo
# ...

# %%
df_mb_2019.to_csv("artistas_2019_mb.csv", index=False)

# %%
artistas_2019_mb
# Out:
# {'artista': ['Djo',
#   'BANNERS',
#   'Orla Gartland',
#   'Sub Urban',
#   'Danny Elfman',
#   'Julia Jacklin',
#   'The Head and the Heart',
#   'Jack Harlow',
#   'Leon Russell',
#   'Melanie Martinez',
#   'Glen Campbell',
#   'Erika Lundmoen',
#   'Reik',
#   'Khaled',
#   'Suki Waterhouse',
#   'Drew Baldridge',
#   'Cigarettes After Sex',
#   'Eyedress',
#   'Wabie',
#   'Sir Arthur Conan Doyle',
#   'Sabrina Carpenter',
#   'wave to earth',
#   'Olivia Rodrigo',
#   'Camila Cabello',
#   'Sam Cooke',
#   'Manuel Turizo',
#   'Julia Michaels',
#   'Zero‐G',
#   'WILLOW',
#   'Post Malone',
#   'Johann Jakob Froberger',
#   'Megan Thee Stallion',
#   'Dean Martin',
#   'Rauw Alejandro',
#   'Sia',
#   'Faouzia',
#   'YG',
#   'Blood Orange',
#   'Magdalena Bay',
#   'Red Velvet',
#   'Fruit Bats',
#   'Dean Martin',
#   'Caroline Polachek',
#   'The Beatles',
#   'Dua Lipa',
#   'James Brown',
#   'Freya Ridings',
#   'BabyJake',
#   'Ellie Goulding',
#   'mxmtoon',
# ...

# %% [markdown]
# ### ARTISTAS POP 2020

# %%
set_artistas_2020= set(dict_tracks_pop_2020['artistas'])  # Convertir el valor asociado a la clave 'artistas' en un set para limpiar los artistas repetidos
print(set_artistas_2020)
# Out:
# {'The Neighbourhood', 'The Weeknd', 'Wande Coal', 'Sub Urban', 'Freak Slug', 'Jessie Reyez', 'Lady Gaga', 'Sam Hunt', 'Jack Harlow', 'Melanie Martinez', 'Duomo', 'DJ Khaled', 'Reik', 'Penelope Scott', 'Snoop Dogg', 'KAI', 'iyla', 'Spencer Crandall', 'Cigarettes After Sex', 'Eyedress', 'Fiona Apple', 'Remi Wolf', 'wave to earth', 'All Time Low', 'Olivia Rodrigo', 'Manuel Turizo', 'Hot Mulligan', 'Forest Blakk', 'Livingston', 'VOILÀ', 'Teyana Taylor', 'Duke Dumont', 'Megan Thee Stallion', 'Rauw Alejandro', 'Trey Lewis', 'Justin Bieber', 'Magdalena Bay', 'Internet Money', 'Willie Nelson', 'Shelly', 'Tate McRae', 'Ian Munsick', 'Kevin Ross', 'Dua Lipa', 'Ingrid Andress', 'BabyJake', 'Ellie Goulding', 'Adrianne Lenker', 'Switch', 'Maluma', 'twocolors', 'Joel Corry', 'Phoebe Bridgers', 'Stray Kids', 'The Church Will Sing', 'Sara Kays', 'Dominic Fike', 'Lincoln', 'Charli xcx', 'Wild Rivers', 'Camilo', 'IU', 'Lizzy McAlpine', 'Bruno Major', 'Ty Dolla $ign', 'TWICE', 'Leanna Crawford', 'Alec 
# ...

# %%
lista_artistas_2020 = list(set_artistas_2020) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_2020)
# Out:
# 210

# %%
#Aqui tenemos la búsqueda de un artista. Trabajando con la librería. 
artistas_2020_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_2020:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_2020_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_2020_mb["artista"].append("no data")
    try:
        artistas_2020_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_2020_mb["pais de origen"].append("no data")
    try:
        artistas_2020_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_2020_mb["area de origen"].append("no data") 
    try:
        artistas_2020_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"].split("-")[0])
    except:
        artistas_2020_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_2020_mb["fin de actividad"].append("no activo")
        else:
            artistas_2020_mb["fin de actividad"].append("activo")
    except:
        artistas_2020_mb["fin de actividad"].append("no data")

# %%
df_mb_2020 = pd.DataFrame(artistas_2020_mb)
df_mb_2020
# Out:
#              artista  pais de origen    area de origen fecha inicio actividad  \
# 0        The Beatles  United Kingdom         Liverpool                   1960
# 1         The Weeknd          Canada       Scarborough                   1990
# 2         Wande Coal         Nigeria             Lagos                   1985
# 3          Sub Urban      New Jersey        New Jersey                no data
# 4         Freak Slug  United Kingdom           no data                no data
# ..               ...             ...               ...                    ...
# 205  Black Eyed Peas   United States       Los Angeles                   1995
# 206     Tony Bennett   United States  Long Island City                   1926
# 207         Kid Cudi   United States         Cleveland                   1984
# 208   Jonas Brothers   United States           Wyckoff                   2005
# 209        Jung Kook     South Korea             Busan                   1997
#
#     fin de actividad
# ...

# %%
df_mb_2020.to_csv("artistas_2020_mb.csv", index=False)

# %% [markdown]
# # LASTFM

# %%
api_key= "cce24bdeb4a50d132f3b117a6dbf6dab"

# %%
dic_artistas_2019_LFM = {"Artista":[], "Biografia":[], "Listeners":[], "Playcount":[], "Artistas Similares":[]}
for a in lista_artistas_2019:
    params_info = {
        'method': 'artist.getinfo',
        'artist': a,
        'api_key': api_key,
        'format': 'json'
        }
    url = f"http://ws.audioscrobbler.com/2.0/"
    respuesta = requests.get(url, params=params_info)
    artista = respuesta.json()
    try:
        dic_artistas_2019_LFM['Artista'].append(artista["artist"]["name"])
    except:
        dic_artistas_2019_LFM["Artista"].append(None)
    try:
        dic_artistas_2019_LFM["Biografia"].append(artista["artist"]["bio"]["summary"])
    except:
        dic_artistas_2019_LFM["Biografia"].append(None)
    try:
        dic_artistas_2019_LFM["Listeners"].append(artista["artist"]["stats"]["listeners"])
    except:
        dic_artistas_2019_LFM["Listeners"].append(None)
    try:
        dic_artistas_2019_LFM["Playcount"].append(artista["artist"]["stats"]["playcount"])
    except:
        dic_artistas_2019_LFM["Playcount"].append(None)
    try:
        dic_artistas_2019_LFM["Artistas Similares"].append(artista["artist"]["similar"]["artist"][0]["name"])
    except:
        dic_artistas_2019_LFM["Artistas Similares"].append(None)
print((dic_artistas_2019_LFM["Artista"]))
print((dic_artistas_2019_LFM["Biografia"]))
print((dic_artistas_2019_LFM["Listeners"]))
print((dic_artistas_2019_LFM["Playcount"]))
print((dic_artistas_2019_LFM["Artistas Similares"]))
# Out:
# ['Djo', 'Banners', 'Orla Gartland', 'sub urban', 'Danny Ocean', 'Julia Jacklin', 'The Head and the Heart', 'Jack Harlow', 'Léon', 'Melanie Martinez', 'Jervis Campbell', 'Erika Lundmoen', 'Reik', 'DJ Khaled', 'Suki Waterhouse', 'Drew Baldridge', 'Cigarettes After Sex', 'Eyedress', 'Wabie', 'Sir', 'Sabrina Carpenter', 'wave to earth', 'Olivia Rodrigo', 'Camila Cabello', 'Sam Fischer', 'Manuel Turizo', 'Julia Michaels', 'Becky G', 'Willow', 'Post Malone', 'Jakob', 'Megan Thee Stallion', 'Dean Lewis', 'Rauw Alejandro', 'Sia', 'FAOUZIA', 'YG', 'Blood Orange', 'MAGDALENA BAY', 'Red Velvet', 'Fruit Bats', 'Olivia Dean', 'Caroline Polachek', 'The Lumineers', 'Dua Lipa', 'James Blake', 'Freya Ridings', 'BabyJake', 'Ellie Goulding', 'mxmtoon', 'Benny Blanco', 'Maluma', 'Diego & Victor Hugo', 'Romeo Santos', 'Cordae', 'Loud Luxury', 'antihoney', 'Mabel', 'Andy Grammer', 'Between Friends', 'Ronnie Milsap', 'TWICE', 'Bea Miller', 'Matt Stell', 'ScHoolboy Q', 'MAMAMOO', 'WAYV', 'Sam Smith', 'Rosal
# ...

# %%
df_lfm_2019 = pd.DataFrame(dic_artistas_2019_LFM)
df_lfm_2019
# Out:
#               Artista                                          Biografia  \
# 0                 Djo  Djo is the musical moniker of American actor/m...
# 1             Banners  BANNERS, the stage name of English musician Mi...
# 2       Orla Gartland  Orla Gartland (born 3 February 1995) is an Iri...
# 3           sub urban  Daniel Virgil Maisonneuve (Sub Urban)  was bor...
# 4         Danny Ocean  \nDaniel Morales, better known as Danny Ocean ...
# ..                ...                                                ...
# 216    Jonas Brothers  The Jonas Brothers are an American pop rock ba...
# 217             Topic  There are several artists with the name Topic....
# 218           Mustard  There are several artists using this name:\n\n...
# 219      Dove Cameron  Dove Cameron (born Chloe Celeste Hosterman; Ja...
# 220  Mrs. GREEN APPLE  Mrs. GREEN APPLE (ミセスグリーンアップル) is a 3, formerl...
#
#     Listeners Playcount Artistas Similares
# 0     1403804  38470901        Tame Impala
# ...

# %%
df_lfm_2019.to_csv("dic_artistas_2019_LFM.csv", index=False)

# %%
dic_artistas_2020_LFM = {"Artista":[], "Biografia":[], "Listeners":[], "Playcount":[], "Artistas Similares":[]}
for a in lista_artistas_2020:
    params_info = {
        'method': 'artist.getinfo',
        'artist': a,
        'api_key': api_key,
        'format': 'json'
        }
    url = f"http://ws.audioscrobbler.com/2.0/"
    respuesta = requests.get(url, params=params_info)
    artista = respuesta.json()
    try:
        dic_artistas_2020_LFM['Artista'].append(artista["artist"]["name"])
    except:
        dic_artistas_2020_LFM["Artista"].append(None)
    try:
        dic_artistas_2020_LFM["Biografia"].append(artista["artist"]["bio"]["summary"])
    except:
        dic_artistas_2020_LFM["Biografia"].append(None)
    try:
        dic_artistas_2020_LFM["Listeners"].append(artista["artist"]["stats"]["listeners"])
    except:
        dic_artistas_2020_LFM["Listeners"].append(None)
    try:
        dic_artistas_2020_LFM["Playcount"].append(artista["artist"]["stats"]["playcount"])
    except:
        dic_artistas_2020_LFM["Playcount"].append(None)
    try:
        dic_artistas_2020_LFM["Artistas Similares"].append(artista["artist"]["similar"]["artist"][0]["name"])
    except:
        dic_artistas_2020_LFM["Artistas Similares"].append(None)
print((dic_artistas_2020_LFM["Artista"]))
print((dic_artistas_2020_LFM["Biografia"]))
print((dic_artistas_2020_LFM["Listeners"]))
print((dic_artistas_2020_LFM["Playcount"]))
print((dic_artistas_2020_LFM["Artistas Similares"]))
# Out:
# ['The Neighbourhood', 'The Weeknd', 'Wande Coal', 'sub urban', 'Freak Slug', 'Jessie Reyez', 'Lady Gaga', 'Sam Hunt', 'Jack Harlow', 'Melanie Martinez', 'Duomo', 'DJ Khaled', 'Reik', 'Penelope Scott', 'Snoop Dogg', 'Kai', 'Iyla', 'Spencer Crandall', 'Cigarettes After Sex', 'Eyedress', 'Fiona Apple', 'Remi Wolf', 'wave to earth', 'All Time Low', 'Olivia Rodrigo', 'Manuel Turizo', 'Hot Mulligan', 'Forest Blakk', 'Livingston', 'Voilà', 'Teyana Taylor', 'Duke Dumont', 'Megan Thee Stallion', 'Rauw Alejandro', 'Trey Lewis', 'Justin Bieber', 'MAGDALENA BAY', 'Internet Money', 'Willie Nelson', 'Shelly', 'Tate McRae', 'Ian Munsick', 'Kevin Ross', 'Dua Lipa', 'Ingrid Andress', 'BabyJake', 'Ellie Goulding', 'AdriAnne Lenker', 'Switch', 'Maluma', 'twocolors', 'Joel Corry', 'Phoebe Bridgers', 'STRAY KIDS', 'The Church Will Sing', 'Sara Kays', 'Dominic Fike', 'Lincoln', 'Charli XCX', 'Wild Rivers', 'Camilo', 'IU', 'Lizzy McAlpine', 'Bruno Major', 'Ty Dolla $ign', 'TWICE', 'Leanna Crawford', 'Alec 
# ...

# %%
df_lfm_2020 = pd.DataFrame(dic_artistas_2020_LFM)
df_lfm_2020
# Out:
#                Artista                                          Biografia  \
# 0    The Neighbourhood  The Neighbourhood is an American alternative r...
# 1           The Weeknd  Abel Makkonen Tesfaye, popularly known as The ...
# 2           Wande Coal  Born Wande Ojosipe on the 18th of October 1985...
# 3            sub urban  Daniel Virgil Maisonneuve (Sub Urban)  was bor...
# 4           Freak Slug   <a href="https://www.last.fm/music/Freak+Slug...
# ..                 ...                                                ...
# 205    Black Eyed Peas  Black Eyed Peas is an American hip hop/pop gro...
# 206      Bennett Coast  Guided by his ever-enduring mission to capture...
# 207           Kid Cudi  Scott Ramon Seguro Mescudi (born January 30, 1...
# 208     Jonas Brothers  The Jonas Brothers are an American pop rock ba...
# 209          Jung Kook  Jeon Jung Kook (Korean/Hangul: 전정국; born Septe...
#
#     Listeners  Playcount         Artistas Similares
# ...

# %%
df_lfm_2020.to_csv("dic_artistas_2020_LFM.csv", index=False)
