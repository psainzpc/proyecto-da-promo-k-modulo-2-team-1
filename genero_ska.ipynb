# %%
#%pip install spotipy

# %%
import requests
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = 'c5bed5700dd2418f96eb69cf35bddfdc'
api_key = '65d6968e077446208479c948cad8bffe'

auth_manager = SpotifyClientCredentials( client_id, api_key)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
canciones = sp.search(q="genre:ska year:2019", type="track", limit=50, offset=0)

# %%
canciones.keys()
# Out:
# dict_keys(['tracks'])

# %%
canciones["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
canciones["tracks"]["items"][0]["album"]["release_date"]
# Out:
# '2019-01-11'

# %%
canciones["tracks"]["items"][0]["artists"][0]["name"]
canciones["tracks"]["items"][0]["artists"][0]["name"]
# Out:
# '88 Fingers Louie'

# %% [markdown]
# CANCIONES SKA 2019

# %%
dict_tracks_ska_2019={"canciones":[],"artistas": [], "género": "ska", "tipo": "track", "año lanzamiento": []}
for offset in range (0,500,50):
    canciones_ska_2019 = sp.search(q='genre:"ska" year:2019', type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_ska_2019["canciones"].append(canciones_ska_2019["tracks"]["items"][i]["name"])
        
print(dict_tracks_ska_2019)
len(dict_tracks_ska_2019)
# Out:
# {'canciones': ['100 Proof', 'Bad Guy', 'All My Friends Are Nobodies', 'Anna', 'Tomorrow Starts Today', "America (You're Freaking Me Out)", 'Say What - Pisk Electro Swing Remix', 'I’ve Won', 'Selfish Means', 'Strangers Forever', 'El Último Ska', 'My Sanity', 'Summer Photos', 'Strain Your Memory', 'Punk Rock Rulebook', 'I Hate Myself', 'The Perfect Crime', 'Outright Lies', 'High School Friend', 'Holding Back', 'Blink', 'Last To Know', 'Huellas - Live / Remastered', 'Chaos From Within', 'Worst Man Won', 'We’re Not Alright', 'Do The Paranoid Style', 'Candidate', 'State', 'If I Could Only Listen to My Heart', 'I Wanna Be a Dog', 'All My Friends Are Nobodies', 'Last Ride', 'The Approach', 'Hello Exile', "Tonight We're Gonna Give It 35%", 'Too Much Information', "Can't Stop", 'Hauch mich mal an', 'When Both Sides Suck, We’re All Winners', 'Super Show (Theme Song!)', "Elmer's", 'Portland', "You're Gonna Go Far, Kid", 'Beyond The Veil', 'The Disco Before the Breakdown', "I Can't Stop Drinking
# ...

# %% [markdown]
# ARTISTAS SKA 2019

# %%
for offset in range(0, 500, 50):
    canciones_ska_2019 = sp.search(q='genre:"ska" year:2019', type="track", limit=50, offset=offset)
    for track in canciones_ska_2019['tracks']['items']:
        dict_tracks_ska_2019["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_ska_2019)
len(dict_tracks_ska_2019)
# Out:
# {'canciones': ['100 Proof', 'Bad Guy', 'All My Friends Are Nobodies', 'Anna', 'Tomorrow Starts Today', "America (You're Freaking Me Out)", 'Say What - Pisk Electro Swing Remix', 'I’ve Won', 'Selfish Means', 'Strangers Forever', 'El Último Ska', 'My Sanity', 'Summer Photos', 'Strain Your Memory', 'Punk Rock Rulebook', 'I Hate Myself', 'The Perfect Crime', 'Outright Lies', 'High School Friend', 'Holding Back', 'Blink', 'Last To Know', 'Huellas - Live / Remastered', 'Chaos From Within', 'Worst Man Won', 'We’re Not Alright', 'Do The Paranoid Style', 'Candidate', 'State', 'If I Could Only Listen to My Heart', 'I Wanna Be a Dog', 'All My Friends Are Nobodies', 'Last Ride', 'The Approach', 'Hello Exile', "Tonight We're Gonna Give It 35%", 'Too Much Information', "Can't Stop", 'Hauch mich mal an', 'When Both Sides Suck, We’re All Winners', 'Super Show (Theme Song!)', "Elmer's", 'Portland', "You're Gonna Go Far, Kid", 'Beyond The Veil', 'The Disco Before the Breakdown', "I Can't Stop Drinking
# ...

# %% [markdown]
# AÑO DE LANZAMIENTO

# %%
for offset in range(0, 500, 50):
    canciones_ska_2019 = sp.search(q='genre:"ska" year:2019', type='track', limit=50, offset=offset)
    for track in canciones_ska_2019['tracks']['items']:
        dict_tracks_ska_2019["año lanzamiento"].append(track["album"]['release_date'])
print(dict_tracks_ska_2019)
len(dict_tracks_ska_2019)
# Out:
# {'canciones': ['100 Proof', 'Bad Guy', 'All My Friends Are Nobodies', 'Anna', 'Tomorrow Starts Today', "America (You're Freaking Me Out)", 'Say What - Pisk Electro Swing Remix', 'I’ve Won', 'Selfish Means', 'Strangers Forever', 'El Último Ska', 'My Sanity', 'Summer Photos', 'Strain Your Memory', 'Punk Rock Rulebook', 'I Hate Myself', 'The Perfect Crime', 'Outright Lies', 'High School Friend', 'Holding Back', 'Blink', 'Last To Know', 'Huellas - Live / Remastered', 'Chaos From Within', 'Worst Man Won', 'We’re Not Alright', 'Do The Paranoid Style', 'Candidate', 'State', 'If I Could Only Listen to My Heart', 'I Wanna Be a Dog', 'All My Friends Are Nobodies', 'Last Ride', 'The Approach', 'Hello Exile', "Tonight We're Gonna Give It 35%", 'Too Much Information', "Can't Stop", 'Hauch mich mal an', 'When Both Sides Suck, We’re All Winners', 'Super Show (Theme Song!)', "Elmer's", 'Portland', "You're Gonna Go Far, Kid", 'Beyond The Veil', 'The Disco Before the Breakdown', "I Can't Stop Drinking
# ...

# %%
df_2019 = pd.DataFrame(dict_tracks_ska_2019)
df_2019
# Out:
#                         canciones          artistas género   tipo  \
# 0                       100 Proof  88 Fingers Louie    ska  track
# 1                         Bad Guy  The Interrupters    ska  track
# 2     All My Friends Are Nobodies         zebrahead    ska  track
# 3                            Anna    The Menzingers    ska  track
# 4           Tomorrow Starts Today  88 Fingers Louie    ska  track
# ..                            ...               ...    ...    ...
# 495                       No Case   Masked Intruder    ska  track
# 496  I Won't Say I'm Sorry - Live      Face To Face    ska  track
# 497            Ichi, Ni, San, Shi         zebrahead    ska  track
# 498                       Miradas    Panteon Rococo    ska  track
# 499                  Already Gone           Catbite    ska  track
#
#     año lanzamiento
# 0        2019-01-11
# 1        2019-10-04
# 2        2019-08-09
# 3        2019-10-04
# 4        2019-01-11
# ..              ...
# 495      2019-03-01
# ...

# %%
df_2019.describe(include="object")
# Out:
#                           canciones   artistas género   tipo año lanzamiento
# count                           500        500    500    500             500
# unique                          453        116      1      1              93
# top     All My Friends Are Nobodies  zebrahead    ska  track      2019-08-09
# freq                              4         42    500    500              47

# %% [markdown]
# CANCIONES SKA 2020

# %%
dict_tracks_ska_2020={"canciones":[],"artistas": [], "género": "ska", "tipo": "track", "año lanzamiento": []}
for offset in range (0,500,50):
    canciones_ska_2020 = sp.search(q='genre:"ska" year:2020', type="track", limit=50, offset=offset)
    for i in range(0,50,1):
        dict_tracks_ska_2020["canciones"].append(canciones_ska_2019["tracks"]["items"][i]["name"])
        
print(dict_tracks_ska_2020)
len(dict_tracks_ska_2020)
# Out:
# {'canciones': ['Old Town Road', 'Manant! Fight!', "Can't Hardly Wait - Acoustic Version", 'Soul Rebel (Instrumental)', 'Echoes', 'Anti-Social Media', 'No Authority - Live', 'Double Crossed - Live', 'Mordan', "Dead Man's Party", 'Disappearing City', 'Otets', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Mágico - Live / Remastered', 'Jump in the Line', "Doin' Time", 'I Want to Kill Clint Carlin', '¿Por Que No Se Van? (En Vivo) - 2019 Remasterizado', "Who's That?", 'The Good Life!', 'Evils Cry Sometimes', 'Feet off the Ground', 'Fatlip', "Beat Fishin'!", 'No Safe Place', 'I Wanna Be a Dog', 'Party on the Dancefloor', 'Take a Deep Breath (And Go Fuck Yourself)', 'Kaboom!', 'Healthy Body Sick Mind', 'Billy V. Veronica', 'So Jah Say (Dub)', 'New Kind of Friend', 'Perro Chico', 'Cowboy Android Theme!', 'Anthem', 'From Here on In', 'Gutter (I Should Start Listening)', 'Diamonds and Gold', 'Haffi Flow - Zapada', 'Paramar (En Vivo) - 2019 Remasterizado', 'Goron City', 'All My Friends A
# ...

# %% [markdown]
# ARTISTAS SKA 2020

# %%
for offset in range(0, 500, 50):
    canciones_ska_2020 = sp.search(q='genre:"ska" year:2020', type="track", limit=50, offset=offset)
    for track in canciones_ska_2020['tracks']['items']:
        dict_tracks_ska_2020["artistas"].append(track["artists"][0]['name'])
print(dict_tracks_ska_2020)
len(dict_tracks_ska_2020)
# Out:
# {'canciones': ['Old Town Road', 'Manant! Fight!', "Can't Hardly Wait - Acoustic Version", 'Soul Rebel (Instrumental)', 'Echoes', 'Anti-Social Media', 'No Authority - Live', 'Double Crossed - Live', 'Mordan', "Dead Man's Party", 'Disappearing City', 'Otets', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Mágico - Live / Remastered', 'Jump in the Line', "Doin' Time", 'I Want to Kill Clint Carlin', '¿Por Que No Se Van? (En Vivo) - 2019 Remasterizado', "Who's That?", 'The Good Life!', 'Evils Cry Sometimes', 'Feet off the Ground', 'Fatlip', "Beat Fishin'!", 'No Safe Place', 'I Wanna Be a Dog', 'Party on the Dancefloor', 'Take a Deep Breath (And Go Fuck Yourself)', 'Kaboom!', 'Healthy Body Sick Mind', 'Billy V. Veronica', 'So Jah Say (Dub)', 'New Kind of Friend', 'Perro Chico', 'Cowboy Android Theme!', 'Anthem', 'From Here on In', 'Gutter (I Should Start Listening)', 'Diamonds and Gold', 'Haffi Flow - Zapada', 'Paramar (En Vivo) - 2019 Remasterizado', 'Goron City', 'All My Friends A
# ...

# %% [markdown]
# AÑO LANZAMIENTO 2020

# %%
for offset in range(0, 500, 50):
    canciones_ska_2020 = sp.search(q='genre:"ska" year:2020', type='track', limit=50, offset=offset)
    for track in canciones_ska_2020['tracks']['items']:
        dict_tracks_ska_2020["año lanzamiento"].append(track["album"]['release_date'])
print(dict_tracks_ska_2020)
len(dict_tracks_ska_2020)
# Out:
# {'canciones': ['Old Town Road', 'Manant! Fight!', "Can't Hardly Wait - Acoustic Version", 'Soul Rebel (Instrumental)', 'Echoes', 'Anti-Social Media', 'No Authority - Live', 'Double Crossed - Live', 'Mordan', "Dead Man's Party", 'Disappearing City', 'Otets', 'Better Living Through Chemistry', 'Coffee & Sugar', 'Mágico - Live / Remastered', 'Jump in the Line', "Doin' Time", 'I Want to Kill Clint Carlin', '¿Por Que No Se Van? (En Vivo) - 2019 Remasterizado', "Who's That?", 'The Good Life!', 'Evils Cry Sometimes', 'Feet off the Ground', 'Fatlip', "Beat Fishin'!", 'No Safe Place', 'I Wanna Be a Dog', 'Party on the Dancefloor', 'Take a Deep Breath (And Go Fuck Yourself)', 'Kaboom!', 'Healthy Body Sick Mind', 'Billy V. Veronica', 'So Jah Say (Dub)', 'New Kind of Friend', 'Perro Chico', 'Cowboy Android Theme!', 'Anthem', 'From Here on In', 'Gutter (I Should Start Listening)', 'Diamonds and Gold', 'Haffi Flow - Zapada', 'Paramar (En Vivo) - 2019 Remasterizado', 'Goron City', 'All My Friends A
# ...

# %%
df_2020 = pd.DataFrame(dict_tracks_ska_2020)
df_2020
# Out:
#                                 canciones              artistas género   tipo  \
# 0                           Old Town Road           Alton Ellis    ska  track
# 1                          Manant! Fight!            Goldfinger    ska  track
# 2    Can't Hardly Wait - Acoustic Version     Screeching Weasel    ska  track
# 3               Soul Rebel (Instrumental)           The Wailers    ska  track
# 4                                  Echoes             Anti-Flag    ska  track
# ..                                    ...                   ...    ...    ...
# 495                               No Case           Alton Ellis    ska  track
# 496          I Won't Say I'm Sorry - Live    Voodoo Glow Skulls    ska  track
# 497                    Ichi, Ni, San, Shi                  Mest    ska  track
# 498                               Miradas  The Suicide Machines    ska  track
# 499                          Already Gone                  MxPx    ska  track
#
#     año lanzamiento
# ...

# %%
df_2020.describe(include="object")
# Out:
#             canciones           artistas género   tipo año lanzamiento
# count             500                500    500    500             500
# unique             50                115      1      1             106
# top     Old Town Road  Screeching Weasel    ska  track      2020-08-07
# freq               10                 34    500    500              36

# %% [markdown]
# MUSICBRAINZ

# %%
#!pip install musicbrainzngs

# %%
import musicbrainzngs

# %%
musicbrainzngs.set_useragent("MusicStream", "1.0", "martahh90@hotmail.com")

# %% [markdown]
# ARTISTAS SKA 2019

# %%
set_artistas_ska_2019 = set(dict_tracks_ska_2019['artistas'])  # Convertir el valor asociado a la clave 'artistas' en un set para limpiar los artistas repetidos
print(set_artistas_ska_2019)
# Out:
# {'Rehasher', 'Tommy Tornado', 'Inspector', 'The Skints', 'The Bombpops', 'H2O', 'The Paranoias', 'Buck-O-Nine', 'Just Say Nay', 'Kill Lincoln', 'MxPx', 'Big D and the Kids Table', '[spunge]', 'CLUB SANDINISTA!', 'Panteon Rococo', 'Tokyo Ska Paradise Orchestra', 'Face To Face', 'Tiger Army', 'Los Prisioneros', 'En Tol Sarmiento', 'South Central Skankers', 'Millencolin', 'The Offspring', 'Los Skagaleros', 'Tsunami Bomb', 'The Vandals', 'Pulley', 'Joey Cape', 'Stop the Presses', 'Much The Same', 'Half Past Two', '88 Fingers Louie', 'Cut Capers', 'Omnigone', 'Hub City Stompers', 'Jamaican Jazz Orchestra', 'The Menzingers', 'Joe Vasconcellos', 'FIVE STATE DRIVE', '2 minutos', 'The Cat Empire', 'Strung Out', 'The Living End', 'Tunnel Vision', 'Rude Tins', 'Quique Neira', 'Bad Cop, Bad Cop', 'Koers', '31 Minutos', 'K-Man & The 45s', 'Westbound Train', 'БИРТМАН', 'The Interrupters', 'La Fúmiga', 'Codename Colin', 'The Aggrolites', 'Los De Abajo', 'Bite Me Bambi', 'Sorry Sweetheart', 'Byron L
# ...

# %%
lista_artistas_ska_2019 = list(set_artistas_ska_2019) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_ska_2019)
# Out:
# 116

# %%
#ejemplo de como muestra los resultados:
result = musicbrainzngs.search_artists(artist='Inspector')
print(result)
# Out:
# {'artist-list': [{'id': 'b8711241-bd87-4f6f-ab22-fcdc3743544b', 'type': 'Group', 'ext:score': '100', 'name': 'Inspector', 'sort-name': 'Inspector', 'country': 'MX', 'area': {'id': '3e08b2cd-69f3-317c-b1e4-e71be581839e', 'type': 'Country', 'name': 'Mexico', 'sort-name': 'Mexico', 'life-span': {'ended': 'false'}}, 'begin-area': {'id': 'cfd1e529-4ca0-4377-bb35-c1762b653d50', 'type': 'City', 'name': 'Monterrey', 'sort-name': 'Monterrey', 'life-span': {'ended': 'false'}}, 'isni-list': ['0000000102359162'], 'life-span': {'begin': '1995-11', 'ended': 'false'}, 'tag-list': [{'count': '2', 'name': 'ska'}, {'count': '1', 'name': 'latin'}]}, {'id': '2ba6ead4-14f4-4802-a32c-84afdf30a680', 'type': 'Person', 'ext:score': '89', 'name': 'I.N.S.P.E.C.T.O.R.', 'sort-name': 'I.N.S.P.E.C.T.O.R.', 'gender': 'male', 'country': 'DE', 'area': {'id': '85752fda-13c4-31a3-bee5-0e5cb1f51dad', 'type': 'Country', 'name': 'Germany', 'sort-name': 'Germany', 'life-span': {'ended': 'false'}}, 'disambiguation': 'Ben E
# ...

# %%
artistas_ska_2019_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_ska_2019:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_ska_2019_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_ska_2019_mb["artista"].append("no data")
    try:
        artistas_ska_2019_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_ska_2019_mb["pais de origen"].append("no data")
    try:
        artistas_ska_2019_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_ska_2019_mb["area de origen"].append("no data") 
    try:
        artistas_ska_2019_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"])
    except:
        artistas_ska_2019_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_ska_2019_mb["fin de actividad"].append("no activo")
        else:
            artistas_ska_2019_mb["fin de actividad"].append("activo")
    except:
        artistas_ska_2019_mb["fin de actividad"].append("no data")

# %%
pd.DataFrame(artistas_ska_2019_mb)
# Out:
#                      artista  pais de origen  area de origen  \
# 0                   Rehasher   United States     Gainesville
# 1               Tommy Dorsey   United States      Shenandoah
# 2                  Inspector          Mexico       Monterrey
# 3                The Beatles  United Kingdom       Liverpool
# 4                The Beatles  United Kingdom       Liverpool
# ..                       ...             ...             ...
# 111     Teenage Bottlerocket   United States         Laramie
# 112           Boa Brass Band          France         no data
# 113  Riskee and The Ridicule         no data         no data
# 114                 Kameleba       Argentina  Villa Mercedes
# 115             Bad Religion   United States     Los Angeles
#
#     fecha inicio actividad fin de actividad
# 0                     2002           activo
# 1               1905-11-19           activo
# 2                  1995-11           activo
# 3                     1960           activo
# ...

# %%
artistas_ska_2019_mb
# Out:
# {'artista': ['Rehasher',
#   'Tommy Dorsey',
#   'Inspector',
#   'The Beatles',
#   'The Beatles',
#   'H2O',
#   'The Beatles',
#   'Nine Inch Nails',
#   'Just Say Nay',
#   'Kill Lincoln',
#   'MxPx',
#   'Big D and the Kids Table',
#   '[spunge]',
#   'Club Sandinista!',
#   'Panteón Rococó',
#   'Duke Ellington and His Orchestra',
#   'face to face',
#   'Tiger Army',
#   'Los Prisioneros',
#   'En Tol Sarmiento',
#   'South Central Skankers',
#   'Millencolin',
#   'The Offspring',
#   'Los Lobos',
#   'Tsunami Bomb',
#   'The Beatles',
#   'Pulley',
#   'Joey Cape',
#   'Stop The Presses',
#   'Much the Same',
#   'Half Past Two',
#   '88 Fingers Louie',
#   'Cut Capers',
#   'Omnigone',
#   'Hub City Stompers',
#   'Jamaican Jazz Orchestra',
#   'The Beatles',
#   'Joe Vasconcellos',
#   'Five State Drive',
#   '2 Minutos',
#   'The Cat Empire',
#   'Strung Out',
#   'The Living End',
#   'Sound Vision library',
#   'Rude Tins',
#   'Quique Neira',
#   'Bad Cop/Bad Cop',
# ...

# %%
set_artistas_ska_2020 = set(dict_tracks_ska_2020['artistas'])  # Convertir el valor asociado a la clave 'artistas' en un set para limpiar los artistas repetidos
print(set_artistas_ska_2020)
# Out:
# {'NOFX', 'Mango Wood', 'Rehasher', 'Crazy Baldhead', 'Sekta Core', 'Lord Creator', 'Inspector', 'Desmond Dekker', 'The Skints', 'The Bombpops', 'Faintest Idea', 'Kill Lincoln', 'Just Say Nay', 'MxPx', '[spunge]', 'We Are The Union', 'Panteon Rococo', 'Tokyo Ska Paradise Orchestra', 'Dope Times', 'Bersuit Vergarabat', 'Face To Face', 'Millie Manders and the Shutup', 'Los Prisioneros', 'Los Auténticos Decadentes', 'Alkaline Trio', 'The Bandulus', 'The Offspring', 'BAD OPERATION', 'Mephiskapheles', 'Alpheus', 'Tsunami Bomb', 'The Vandals', 'Grey Matter', 'Nonpalidece', 'Half Past Two', 'Cut Capers', 'Omnigone', 'Tequila & The Sunrise Gang', 'Slick Shoes', 'The Menzingers', 'The Distillers', 'Get Dead', 'Victor Rice', "Swingin' Utters", 'The English Beat', 'Bad Cop, Bad Cop', 'Something To Do', 'KLUB', '31 Minutos', 'La Mosca Tse-Tse', 'Hightime', 'Left Alone', 'Лампасы', 'The Inevitables', 'La Fúmiga', 'The Aggrolites', 'Chaser', 'The Meddlers', 'Bite Me Bambi', 'Balkan Paradise Orchest
# ...

# %%
lista_artistas_ska_2020 = list(set_artistas_ska_2020) # pasarlo a lista para poder iterar en el bucle for 
len(lista_artistas_ska_2020)
# Out:
# 115

# %%
result = musicbrainzngs.search_artists(artist='Rehasher')
print(result)
# Out:
# {'artist-list': [{'id': '09d346f5-5bff-4b75-aab8-2cc2ab646321', 'type': 'Group', 'ext:score': '100', 'name': 'Rehasher', 'sort-name': 'Rehasher', 'country': 'US', 'area': {'id': '489ce91b-6658-3307-9877-795b68554c98', 'type': 'Country', 'name': 'United States', 'sort-name': 'United States', 'life-span': {'ended': 'false'}}, 'begin-area': {'id': 'dbe53871-db21-47ea-a0c3-3ab58317a3ab', 'type': 'City', 'name': 'Gainesville', 'sort-name': 'Gainesville', 'life-span': {'ended': 'false'}}, 'isni-list': ['000000046898742X'], 'life-span': {'begin': '2002', 'ended': 'false'}}], 'artist-count': 1}

# %%
artistas_ska_2020_mb = {"artista": [], "pais de origen": [], "area de origen": [], "fecha inicio actividad": [], "fin de actividad": []} 
for a in lista_artistas_ska_2020:
    result = musicbrainzngs.search_artists(artist=a)
    try:
        artistas_ska_2020_mb["artista"].append(result["artist-list"][0]["name"])
    except:
        artistas_ska_2020_mb["artista"].append("no data")
    try:
        artistas_ska_2020_mb["pais de origen"].append(result["artist-list"][0]["area"]["name"])
    except:
        artistas_ska_2020_mb["pais de origen"].append("no data")
    try:
        artistas_ska_2020_mb["area de origen"].append(result["artist-list"][0]["begin-area"]["name"])
    except:
        artistas_ska_2020_mb["area de origen"].append("no data") 
    try:
        artistas_ska_2020_mb["fecha inicio actividad"].append(result["artist-list"][0]["life-span"]["begin"])
    except:
        artistas_ska_2020_mb["fecha inicio actividad"].append("no data")
    try:
        if result["artist-list"][0]["life-span"]["ended"] == False:
            artistas_ska_2020_mb["fin de actividad"].append("no activo")
        else:
            artistas_ska_2020_mb["fin de actividad"].append("activo")
    except:
        artistas_ska_2020_mb["fin de actividad"].append("no data")

# %%
pd.DataFrame(artistas_ska_2020_mb)
# Out:
#                      artista pais de origen       area de origen  \
# 0                       NOFX  United States          Los Angeles
# 1                      Mango          Italy            Lagonegro
# 2                   Rehasher  United States          Gainesville
# 3                Crazy Horse  United States          Los Angeles
# 4                 Sekta Core         Mexico  Ciudad López Mateos
# ..                       ...            ...                  ...
# 110              Descendents  United States      Manhattan Beach
# 111                 Adhesivo        no data              no data
# 112          Strike Anywhere  United States             Richmond
# 113  Victims of Circumstance  United States              no data
# 114             Bad Religion  United States          Los Angeles
#
#     fecha inicio actividad fin de actividad
# 0                     1983           activo
# 1               1954-11-06           activo
# 2                     2002           activo
# ...
